# %% [markdown]
# # 재무비율 분석 정리

# %% [markdown]
# ## 안정성(유동성) 비율
#
# * 기업의 유동성(단치채무상환능력)과 장기채무상환능력을 나타내는 재무비율
# *유동비율,당좌비율,부채비율,이자보상비율 등

# %% [markdown]
# ## 수익성 비율
#
# * 기업의 경영성과를 나타내는 재무비율
# * 매출액순이익률, 총자본이익률, 자기자본순이익률(ROE), 총자산이익률(ROA)

# %% [markdown]
# ## 활동성 비율
#
# * 기업이 보유자산을 얼마나 효율적으로 운영하였는지를 나타내는 재무비율
# * 총자산회전율, 매출채권회전율, 재고자산회전율

# %% [markdown]
# ## 성장성 비율
#
# * 기업규모의 증가,이익의 증가 등을 측정하는 비율
# * 총자산증가율, 자기자본증가율, 매출액증가율, 순이익증가율

# %% [markdown]
# ## 시장가치비율
#
# * 기업의 주식가격과 재무제표 항목을 대비시키는 비율
# * 주가이익비율, 주가순자산비율,주가매출액비율,주가현금흐름비율

# %% [markdown]
# ## 회사 실적주에 근거한 재무비율
# * 자기자본 순 이익률(ROE), 당기순이익률 등에 근거하여 시장대비
# overperform 중인 종목 선정.

# %% [markdown]
# # 대형주를 통한 주식포트폴리오 반영
#
# * 자산총계 , 유동자산, 자본총계, 자본금 상위RANK 선정 방식

# %% [markdown]
# # 테마별 포트폴리오 투자 중요중요 (왜냐하면 상현승우님이 하고 계신 경제적 군집 라벨에 유효한 관계를 미칠수 있다고 생각합니다.)
#
# * 어떻게 테마군을 나눌 것인지?!

# %% [markdown]
# # 벤자민 그레이엄의 가치투자기법
#
# * 그는 기본적으로 주식시장의 흐름이나 해당 산업의 동향 보다는 장기적인 안목으로 보았을 때 기업의 내재가치에 비해 충분히 할인(저평가)되어 있는 주식에서 수익을 얻을 수 있다고 확신하였으며 내재가치를 구하는 데 필요한 근거가 부족한 기술주에 대한 투자는 일종의 투기라고 생각하였습니다.
#
# * 안전마진의 개념을 상당히 강조하였는데 이는 결국 주가와 기업의 내재가치와의 차이를 의미하는 것으로서 내재가치보다 싼 주식을 매수하면 기업의 수익창출 능력이 저하되더라도 손해를 보지 않을 것이라고 판단하였습니다.
#
# * 벤자민 그레이엄의 투자원칙
# 1. 주식을 사기 전에 그 기업과 경영의 건전성을 철저히 분석해야 한다.
# 2. 심각한 손실에 대해 스스로를 신중하게 보호해야 한다.
# 3. 탁월하지 않은 적당한 성과를 희망해야 한다.
#
# * 구제적인 투자원칙 요약
# 1. 유동자산이 유동부채에 비해 2배 이상이 되어야 한다.(유동비율 200%이상)
# 2. 순유동자산(유동자산-유동부채)이 장기차입금보다 커야 한다.
# 3. 부채비율이 제조업은 100%이하(유틸리티, 통신 등은 230%이하)
# 4. 최근 10년간 EPS성장률이 30%이상(첫 3개년 평균과 마지막 3개년 평균 비교)
# 5. PER은 15배를 넘지 않아야 한다.(과거 3년 평균 EPS 기준)
# 6. PBR은 PER과 곱했을 때 22를 넘지 않아야 한다.
# 7. 과거 20년 이상 꾸준히 배당을 지급해 온 기업에만 투자한다.

# %% [markdown]
# # 피터린치의 투자방법및 포트폴리오
#
# *ref: https://littlefox-investment.tistory.com/1
#
# * 순 이익 관련 주식범주
#
# 1. 고성장주(Fast growers) - 순이익이 매년 20% 이상 늘어나는 기업
#
# 2. 우량주(The stalwarts) - 연 10%의 순이익 성장률을 보이는 종목
#
# 3. 저성장주(Slow growers) - 순이익 증가율이 한 자릿수인 기업
#
# 4. 경기민감주(Cyclicals) - 순이익이 경기 순환에 민감한 종목
#
# 5. 턴어라운드주(Turnarounds)
#
# 6. 자산주(Asset plays)
#
# * 부채
#
# 1. 부채 업음
#
# 2. 부채 약간있으나 쉽게 상환가능
#
# 3. 이자보상배율이 낮은 기업
#
# 4. 부채 상환 능력 없음
#
# * 기업 혹은 업종 고유의 특성...!!!! 이거승 흠....!!!

# %% [markdown]
# # 종합적으로 고려를 해봤을때 여러가지 조합을 실현시킬 수 있을것이다.
#
# ### 1. 재무비율 특성만으로 파악한 포트폴리오 특징
# * 안정성,수익성,활동성,성장성,시장가치,실적 6가지 등..
#
# ### 2. 회사 규모에 따른 회사 크기 분류
# * 대형주 , 중형주, 소형주 3가지
#
# ### 3. 테마주(제조업,통신업,서비스업,해운업 등등) 분류 N가지
# ### 3.1 순이익 관련 주식범주 (고성장주,우량주,저성장주,경기민감주,턴어라운드주,자산주) 6 가지
#
# ### 4. 위 방식을 토대로 최종주식포트폴리오 종목선정 갯수 N개
#
# ### 5. 투자 비중 N%,N%,N%
#
# ## * 총 경우의수
#
# * 1 * 2 * 3 * 종목 선정 갯수 * 투자 비중 = 최종 포트폴리오 경우의수
