# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')

# %%
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
rtn_df_train=rtn_df.loc[:'2019-10-31']
rtn_df_test=rtn_df.loc['2019-11-01':]

# %%
rtn_df_test
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2019-12-02  0.000133 -0.000918  0.001895  0.000000 -0.001307 -0.015266
# 2019-12-03  0.000064 -0.000485 -0.003760  0.009965  0.000654  0.006416
# 2019-12-04  0.000044  0.001297 -0.007311 -0.002127  0.015564  0.004111
# 2019-12-05  0.000041 -0.000500 -0.003947  0.001418  0.001929  0.000540
# 2019-12-06  0.000045 -0.000216  0.010192 -0.010688  0.006402  0.002048
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.000084 -0.000864 -0.001079  0.009819  0.030728  0.011425
# 2022-05-05  0.000000  0.000000  0.000000 -0.004196 -0.005292 -0.027030
# 2022-05-06  0.000109  0.001001 -0.012424  0.001961  0.001061 -0.011940
# 2022-05-09  0.000202  0.002147  0.000000 -0.014940 -0.046284 -0.045043
# 2022-05-10  0.000063  0.000674 -0.018298 -0.008557 -0.005939 -0.018388
#
#                nsd로그
# Date
# 2019-12-02 -0.003250
# 2019-12-03  0.000192
# 2019-12-04  0.006963
# 2019-12-05 -0.005146
# 2019-12-06  0.005336
# ...              ...
# 2022-05-04  0.014217
# 2022-05-05 -0.033019
# 2022-05-06 -0.016993
# 2022-05-09 -0.040948
# 2022-05-10 -0.002740
#
# [633 rows x 7 columns]

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[df['상승']==0]

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
up_2006=df.loc['2006-10-02':'2007-10-31']
up_2009=df.loc['2009-01-02':'2010-01-29']
up_2012=df.loc['2012-03-01':'2013-09-30']
up_2014=df.loc['2014-09-01':'2015-05-29']
up_2015=df.loc['2015-10-01':'2016-01-29']
up_2016=df.loc['2016-05-02':'2017-06-30']
up_2019=df.loc['2019-12-02':'2020-03-31']
#up_2020=df.loc['2020-07-01':'2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

for i in range(1, len(up_2006) - T + 1):
    d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2009) - T + 1):
    d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2012) - T + 1):
    d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2014) - T + 1):
    d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2015) - T + 1):
    d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2016) - T + 1):
    d = np.expand_dims(np.array(up_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2019) - T + 1):
    d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
#for i in range(0, len(up_2020) - T + 1):
    #d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
    #x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ##  데이터셋 나눠서 만들기(하강)

# %%
down_2006=df.loc['2006-03-01':'2006-09-29']
down_2007=df.loc['2007-11-01':'2008-12-31']
down_2010=df.loc['2010-02-01':'2012-02-29']
down_2013=df.loc['2013-10-01':'2014-08-29']
down_2015=df.loc['2015-06-01':'2015-09-30']
down_2016=df.loc['2016-02-01':'2016-04-29']
down_2017=df.loc['2017-07-03':'2019-11-29']
down_2020=df.loc['2020-04-01':'2020-06-30']
#down_2021=df.loc['2021-09-01':'2022-05-10']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(down_2006.iloc[0:T, :]), 0)

for i in range(1, len(down_2006) - T + 1):
    d = np.expand_dims(np.array(down_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2007) - T + 1):
    d = np.expand_dims(np.array(down_2007.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2010) - T + 1):
    d = np.expand_dims(np.array(down_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2013) - T + 1):
    d = np.expand_dims(np.array(down_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2015) - T + 1):
    d = np.expand_dims(np.array(down_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2016) - T + 1):
    d = np.expand_dims(np.array(down_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2017) - T + 1):
    d = np.expand_dims(np.array(down_2017.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2020) - T + 1):
    d = np.expand_dims(np.array(down_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(down_2021) - T + 1):
#     d = np.expand_dims(np.array(down_2021.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# # rtn_train 구성하기

# %%
# rtn_train 값에 기간별로 자른 값 집어넣기
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100

# %%
N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.001
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     #callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7)                 420
#
#  dense (Dense)               (None, 7)                 56
#
#  activation (Activation)     (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 56/56 [==============================] - 7s 14ms/step - loss: -0.9786 - val_loss: -2.6649
# Epoch 2/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9860 - val_loss: -2.6648
# Epoch 3/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9843 - val_loss: -2.6647
# Epoch 4/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9883 - val_loss: -2.6646
# Epoch 5/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9843 - val_loss: -2.6645
# Epoch 6/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9887 - val_loss: -2.6645
# Epoch 7/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9907 - val_loss: -2.6643
# Epoch 8/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9875 - val_loss: -2.6642
# Epoch 9/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9890 - val_loss: -2.6641
# Epoch 10/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9912 - val_loss: -2.6640
# Epoch 11/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9934 - val_loss: -2.6639
# Epoch 12/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9958 - val_loss: -2.6638
# Epoch 13/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -0.9995 - val_loss: -2.6637
# Epoch 14/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0007 - val_loss: -2.6636
# Epoch 15/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0005 - val_loss: -2.6635
# Epoch 16/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9969 - val_loss: -2.6635
# Epoch 17/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9958 - val_loss: -2.6633
# Epoch 18/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0020 - val_loss: -2.6632
# Epoch 19/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9965 - val_loss: -2.6632
# Epoch 20/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0020 - val_loss: -2.6631
# Epoch 21/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -0.9992 - val_loss: -2.6630
# Epoch 22/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0001 - val_loss: -2.6629
# Epoch 23/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0012 - val_loss: -2.6628
# Epoch 24/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0040 - val_loss: -2.6627
# Epoch 25/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0049 - val_loss: -2.6626
# Epoch 26/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0054 - val_loss: -2.6625
# Epoch 27/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0024 - val_loss: -2.6624
# Epoch 28/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0091 - val_loss: -2.6623
# Epoch 29/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0145 - val_loss: -2.6623
# Epoch 30/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0054 - val_loss: -2.6622
# Epoch 31/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0083 - val_loss: -2.6621
# Epoch 32/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0121 - val_loss: -2.6620
# Epoch 33/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0045 - val_loss: -2.6620
# Epoch 34/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0087 - val_loss: -2.6619
# Epoch 35/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0142 - val_loss: -2.6618
# Epoch 36/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0125 - val_loss: -2.6617
# Epoch 37/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0087 - val_loss: -2.6618
# Epoch 38/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0220 - val_loss: -2.6615
# Epoch 39/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0102 - val_loss: -2.6615
# Epoch 40/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0194 - val_loss: -2.6614
# Epoch 41/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0180 - val_loss: -2.6614
# Epoch 42/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0234 - val_loss: -2.6613
# Epoch 43/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0182 - val_loss: -2.6613
# Epoch 44/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0243 - val_loss: -2.6612
# Epoch 45/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0142 - val_loss: -2.6611
# Epoch 46/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0224 - val_loss: -2.6611
# Epoch 47/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0231 - val_loss: -2.6610
# Epoch 48/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0198 - val_loss: -2.6609
# Epoch 49/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0236 - val_loss: -2.6609
# Epoch 50/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0208 - val_loss: -2.6607
# Epoch 51/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0271 - val_loss: -2.6607
# Epoch 52/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0317 - val_loss: -2.6606
# Epoch 53/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0391 - val_loss: -2.6606
# Epoch 54/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0275 - val_loss: -2.6605
# Epoch 55/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0323 - val_loss: -2.6604
# Epoch 56/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0360 - val_loss: -2.6604
# Epoch 57/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0214 - val_loss: -2.6603
# Epoch 58/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0322 - val_loss: -2.6603
# Epoch 59/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0354 - val_loss: -2.6602
# Epoch 60/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0374 - val_loss: -2.6601
# Epoch 61/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0589 - val_loss: -2.6601
# Epoch 62/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0364 - val_loss: -2.6600
# Epoch 63/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0423 - val_loss: -2.6600
# Epoch 64/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0388 - val_loss: -2.6599
# Epoch 65/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0355 - val_loss: -2.6599
# Epoch 66/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0362 - val_loss: -2.6599
# Epoch 67/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0453 - val_loss: -2.6597
# Epoch 68/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0426 - val_loss: -2.6597
# Epoch 69/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0436 - val_loss: -2.6597
# Epoch 70/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0310 - val_loss: -2.6596
# Epoch 71/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0387 - val_loss: -2.6596
# Epoch 72/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.0369 - val_loss: -2.6596
# Epoch 73/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.0465 - val_loss: -2.6596
# Epoch 74/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0465 - val_loss: -2.6595
# Epoch 75/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.0432 - val_loss: -2.6594
# Epoch 76/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.0527 - val_loss: -2.6594
# Epoch 77/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0527 - val_loss: -2.6593
# Epoch 78/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -1.0515 - val_loss: -2.6593
# Epoch 79/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0442 - val_loss: -2.6592
# Epoch 80/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0437 - val_loss: -2.6592
# Epoch 81/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0519 - val_loss: -2.6592
# Epoch 82/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0522 - val_loss: -2.6591
# Epoch 83/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0506 - val_loss: -2.6591
# Epoch 84/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0606 - val_loss: -2.6591
# Epoch 85/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0512 - val_loss: -2.6590
# Epoch 86/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0525 - val_loss: -2.6590
# Epoch 87/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0543 - val_loss: -2.6590
# Epoch 88/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0543 - val_loss: -2.6589
# Epoch 89/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0627 - val_loss: -2.6589
# Epoch 90/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0536 - val_loss: -2.6589
# Epoch 91/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0670 - val_loss: -2.6588
# Epoch 92/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0666 - val_loss: -2.6588
# Epoch 93/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0574 - val_loss: -2.6587
# Epoch 94/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0577 - val_loss: -2.6588
# Epoch 95/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0641 - val_loss: -2.6587
# Epoch 96/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0775 - val_loss: -2.6587
# Epoch 97/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0577 - val_loss: -2.6586
# Epoch 98/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0621 - val_loss: -2.6586
# Epoch 99/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0619 - val_loss: -2.6586
# Epoch 100/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0665 - val_loss: -2.6586
# Epoch 101/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0713 - val_loss: -2.6585
# Epoch 102/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0677 - val_loss: -2.6585
# Epoch 103/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0754 - val_loss: -2.6585
# Epoch 104/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0735 - val_loss: -2.6585
# Epoch 105/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0835 - val_loss: -2.6585
# Epoch 106/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0705 - val_loss: -2.6584
# Epoch 107/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0741 - val_loss: -2.6585
# Epoch 108/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0738 - val_loss: -2.6584
# Epoch 109/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0745 - val_loss: -2.6585
# Epoch 110/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0813 - val_loss: -2.6585
# Epoch 111/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0857 - val_loss: -2.6585
# Epoch 112/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0744 - val_loss: -2.6584
# Epoch 113/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0755 - val_loss: -2.6584
# Epoch 114/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0801 - val_loss: -2.6584
# Epoch 115/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0785 - val_loss: -2.6584
# Epoch 116/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0915 - val_loss: -2.6584
# Epoch 117/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0875 - val_loss: -2.6584
# Epoch 118/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0872 - val_loss: -2.6584
# Epoch 119/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0910 - val_loss: -2.6585
# Epoch 120/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.0874 - val_loss: -2.6584
# Epoch 121/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0919 - val_loss: -2.6584
# Epoch 122/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0974 - val_loss: -2.6584
# Epoch 123/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0881 - val_loss: -2.6584
# Epoch 124/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0877 - val_loss: -2.6585
# Epoch 125/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0846 - val_loss: -2.6584
# Epoch 126/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0879 - val_loss: -2.6584
# Epoch 127/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0924 - val_loss: -2.6585
# Epoch 128/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1006 - val_loss: -2.6585
# Epoch 129/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0925 - val_loss: -2.6585
# Epoch 130/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0960 - val_loss: -2.6585
# Epoch 131/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0974 - val_loss: -2.6585
# Epoch 132/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.1028 - val_loss: -2.6585
# Epoch 133/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0909 - val_loss: -2.6586
# Epoch 134/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0963 - val_loss: -2.6586
# Epoch 135/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1011 - val_loss: -2.6586
# Epoch 136/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1025 - val_loss: -2.6587
# Epoch 137/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0967 - val_loss: -2.6587
# Epoch 138/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1020 - val_loss: -2.6587
# Epoch 139/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1022 - val_loss: -2.6588
# Epoch 140/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1071 - val_loss: -2.6587
# Epoch 141/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1053 - val_loss: -2.6588
# Epoch 142/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.0991 - val_loss: -2.6588
# Epoch 143/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.0974 - val_loss: -2.6589
# Epoch 144/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1126 - val_loss: -2.6589
# Epoch 145/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1036 - val_loss: -2.6590
# Epoch 146/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1173 - val_loss: -2.6590
# Epoch 147/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.1193 - val_loss: -2.6590
# Epoch 148/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1112 - val_loss: -2.6591
# Epoch 149/1000
# 56/56 [==============================] - 0s 5ms/step - loss: -1.1075 - val_loss: -2.6591
# Epoch 150/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1266 - val_loss: -2.6592
# Epoch 151/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1092 - val_loss: -2.6592
# Epoch 152/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1366 - val_loss: -2.6593
# Epoch 153/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1161 - val_loss: -2.6594
# Epoch 154/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1252 - val_loss: -2.6593
# Epoch 155/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1093 - val_loss: -2.6594
# Epoch 156/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1193 - val_loss: -2.6595
# Epoch 157/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1188 - val_loss: -2.6595
# Epoch 158/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1173 - val_loss: -2.6596
# Epoch 159/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1181 - val_loss: -2.6596
# Epoch 160/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1157 - val_loss: -2.6597
# Epoch 161/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1266 - val_loss: -2.6598
# Epoch 162/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1323 - val_loss: -2.6599
# Epoch 163/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1196 - val_loss: -2.6599
# Epoch 164/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1351 - val_loss: -2.6601
# Epoch 165/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1247 - val_loss: -2.6601
# Epoch 166/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1305 - val_loss: -2.6602
# Epoch 167/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1258 - val_loss: -2.6603
# Epoch 168/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1322 - val_loss: -2.6603
# Epoch 169/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1166 - val_loss: -2.6604
# Epoch 170/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1264 - val_loss: -2.6605
# Epoch 171/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1339 - val_loss: -2.6606
# Epoch 172/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1278 - val_loss: -2.6607
# Epoch 173/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1413 - val_loss: -2.6608
# Epoch 174/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1312 - val_loss: -2.6609
# Epoch 175/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1386 - val_loss: -2.6610
# Epoch 176/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1334 - val_loss: -2.6611
# Epoch 177/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1433 - val_loss: -2.6612
# Epoch 178/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1405 - val_loss: -2.6612
# Epoch 179/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1387 - val_loss: -2.6613
# Epoch 180/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1443 - val_loss: -2.6615
# Epoch 181/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1420 - val_loss: -2.6616
# Epoch 182/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1445 - val_loss: -2.6617
# Epoch 183/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1432 - val_loss: -2.6618
# Epoch 184/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1377 - val_loss: -2.6619
# Epoch 185/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1408 - val_loss: -2.6620
# Epoch 186/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1490 - val_loss: -2.6621
# Epoch 187/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1478 - val_loss: -2.6623
# Epoch 188/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1399 - val_loss: -2.6624
# Epoch 189/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1450 - val_loss: -2.6626
# Epoch 190/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1522 - val_loss: -2.6627
# Epoch 191/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1445 - val_loss: -2.6628
# Epoch 192/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1395 - val_loss: -2.6629
# Epoch 193/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1546 - val_loss: -2.6630
# Epoch 194/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1419 - val_loss: -2.6632
# Epoch 195/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1502 - val_loss: -2.6634
# Epoch 196/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1593 - val_loss: -2.6635
# Epoch 197/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1497 - val_loss: -2.6636
# Epoch 198/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1613 - val_loss: -2.6638
# Epoch 199/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1523 - val_loss: -2.6640
# Epoch 200/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1546 - val_loss: -2.6641
# Epoch 201/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1620 - val_loss: -2.6643
# Epoch 202/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1582 - val_loss: -2.6645
# Epoch 203/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.1646 - val_loss: -2.6646
# Epoch 204/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.1584 - val_loss: -2.6648
# Epoch 205/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1655 - val_loss: -2.6649
# Epoch 206/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.1612 - val_loss: -2.6651
# Epoch 207/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1691 - val_loss: -2.6653
# Epoch 208/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -1.1660 - val_loss: -2.6655
# Epoch 209/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1692 - val_loss: -2.6656
# Epoch 210/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1661 - val_loss: -2.6658
# Epoch 211/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -1.1769 - val_loss: -2.6660
# Epoch 212/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -1.1701 - val_loss: -2.6662
# Epoch 213/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1654 - val_loss: -2.6664
# Epoch 214/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1722 - val_loss: -2.6666
# Epoch 215/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1749 - val_loss: -2.6668
# Epoch 216/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1754 - val_loss: -2.6670
# Epoch 217/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1683 - val_loss: -2.6672
# Epoch 218/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1786 - val_loss: -2.6674
# Epoch 219/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1735 - val_loss: -2.6676
# Epoch 220/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1804 - val_loss: -2.6678
# Epoch 221/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1770 - val_loss: -2.6680
# Epoch 222/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1809 - val_loss: -2.6683
# Epoch 223/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1809 - val_loss: -2.6684
# Epoch 224/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1784 - val_loss: -2.6687
# Epoch 225/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1888 - val_loss: -2.6689
# Epoch 226/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1798 - val_loss: -2.6692
# Epoch 227/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1857 - val_loss: -2.6694
# Epoch 228/1000
# 56/56 [==============================] - 1s 16ms/step - loss: -1.1855 - val_loss: -2.6696
# Epoch 229/1000
# 56/56 [==============================] - 1s 16ms/step - loss: -1.1801 - val_loss: -2.6698
# Epoch 230/1000
# 56/56 [==============================] - 1s 16ms/step - loss: -1.1820 - val_loss: -2.6702
# Epoch 231/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1931 - val_loss: -2.6704
# Epoch 232/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1977 - val_loss: -2.6706
# Epoch 233/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.1885 - val_loss: -2.6708
# Epoch 234/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.1908 - val_loss: -2.6711
# Epoch 235/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.1871 - val_loss: -2.6714
# Epoch 236/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2051 - val_loss: -2.6716
# Epoch 237/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1947 - val_loss: -2.6719
# Epoch 238/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -1.1929 - val_loss: -2.6721
# Epoch 239/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1919 - val_loss: -2.6725
# Epoch 240/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.1928 - val_loss: -2.6727
# Epoch 241/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1958 - val_loss: -2.6730
# Epoch 242/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.1954 - val_loss: -2.6732
# Epoch 243/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1973 - val_loss: -2.6736
# Epoch 244/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.2058 - val_loss: -2.6738
# Epoch 245/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.1976 - val_loss: -2.6742
# Epoch 246/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2065 - val_loss: -2.6744
# Epoch 247/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.2057 - val_loss: -2.6747
# Epoch 248/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.2006 - val_loss: -2.6750
# Epoch 249/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2012 - val_loss: -2.6753
# Epoch 250/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2038 - val_loss: -2.6756
# Epoch 251/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2094 - val_loss: -2.6759
# Epoch 252/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2095 - val_loss: -2.6762
# Epoch 253/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2165 - val_loss: -2.6766
# Epoch 254/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2122 - val_loss: -2.6768
# Epoch 255/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2068 - val_loss: -2.6772
# Epoch 256/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2141 - val_loss: -2.6776
# Epoch 257/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2155 - val_loss: -2.6779
# Epoch 258/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2076 - val_loss: -2.6782
# Epoch 259/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2154 - val_loss: -2.6785
# Epoch 260/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2296 - val_loss: -2.6789
# Epoch 261/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2244 - val_loss: -2.6791
# Epoch 262/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2108 - val_loss: -2.6796
# Epoch 263/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2246 - val_loss: -2.6799
# Epoch 264/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2141 - val_loss: -2.6803
# Epoch 265/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2236 - val_loss: -2.6806
# Epoch 266/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2223 - val_loss: -2.6810
# Epoch 267/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2205 - val_loss: -2.6814
# Epoch 268/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2261 - val_loss: -2.6817
# Epoch 269/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2249 - val_loss: -2.6821
# Epoch 270/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2308 - val_loss: -2.6825
# Epoch 271/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2246 - val_loss: -2.6828
# Epoch 272/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2317 - val_loss: -2.6832
# Epoch 273/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2335 - val_loss: -2.6836
# Epoch 274/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2262 - val_loss: -2.6840
# Epoch 275/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2320 - val_loss: -2.6844
# Epoch 276/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2298 - val_loss: -2.6848
# Epoch 277/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2330 - val_loss: -2.6852
# Epoch 278/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2352 - val_loss: -2.6856
# Epoch 279/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2426 - val_loss: -2.6860
# Epoch 280/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2446 - val_loss: -2.6864
# Epoch 281/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2407 - val_loss: -2.6868
# Epoch 282/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2365 - val_loss: -2.6872
# Epoch 283/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2364 - val_loss: -2.6876
# Epoch 284/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2451 - val_loss: -2.6881
# Epoch 285/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2496 - val_loss: -2.6886
# Epoch 286/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2587 - val_loss: -2.6889
# Epoch 287/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2452 - val_loss: -2.6894
# Epoch 288/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2348 - val_loss: -2.6898
# Epoch 289/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2453 - val_loss: -2.6902
# Epoch 290/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2430 - val_loss: -2.6907
# Epoch 291/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2658 - val_loss: -2.6912
# Epoch 292/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2538 - val_loss: -2.6916
# Epoch 293/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2558 - val_loss: -2.6921
# Epoch 294/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2526 - val_loss: -2.6925
# Epoch 295/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2641 - val_loss: -2.6930
# Epoch 296/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2485 - val_loss: -2.6935
# Epoch 297/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2507 - val_loss: -2.6939
# Epoch 298/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2608 - val_loss: -2.6944
# Epoch 299/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2628 - val_loss: -2.6948
# Epoch 300/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2584 - val_loss: -2.6954
# Epoch 301/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2639 - val_loss: -2.6958
# Epoch 302/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.2522 - val_loss: -2.6963
# Epoch 303/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.2676 - val_loss: -2.6968
# Epoch 304/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.2615 - val_loss: -2.6973
# Epoch 305/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2637 - val_loss: -2.6977
# Epoch 306/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.2866 - val_loss: -2.6983
# Epoch 307/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2686 - val_loss: -2.6988
# Epoch 308/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2730 - val_loss: -2.6994
# Epoch 309/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.2744 - val_loss: -2.6997
# Epoch 310/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2728 - val_loss: -2.7003
# Epoch 311/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2766 - val_loss: -2.7008
# Epoch 312/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2807 - val_loss: -2.7014
# Epoch 313/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2784 - val_loss: -2.7019
# Epoch 314/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.2771 - val_loss: -2.7024
# Epoch 315/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.2822 - val_loss: -2.7030
# Epoch 316/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2754 - val_loss: -2.7035
# Epoch 317/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2812 - val_loss: -2.7041
# Epoch 318/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.2883 - val_loss: -2.7047
# Epoch 319/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.2903 - val_loss: -2.7051
# Epoch 320/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.2845 - val_loss: -2.7057
# Epoch 321/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.2831 - val_loss: -2.7063
# Epoch 322/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.2961 - val_loss: -2.7069
# Epoch 323/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.2855 - val_loss: -2.7074
# Epoch 324/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.2985 - val_loss: -2.7080
# Epoch 325/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.2967 - val_loss: -2.7086
# Epoch 326/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.2931 - val_loss: -2.7091
# Epoch 327/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2971 - val_loss: -2.7097
# Epoch 328/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.2926 - val_loss: -2.7103
# Epoch 329/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.2909 - val_loss: -2.7110
# Epoch 330/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3019 - val_loss: -2.7115
# Epoch 331/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3038 - val_loss: -2.7122
# Epoch 332/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3054 - val_loss: -2.7128
# Epoch 333/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3084 - val_loss: -2.7134
# Epoch 334/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3234 - val_loss: -2.7140
# Epoch 335/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3048 - val_loss: -2.7147
# Epoch 336/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3075 - val_loss: -2.7153
# Epoch 337/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3089 - val_loss: -2.7160
# Epoch 338/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3021 - val_loss: -2.7166
# Epoch 339/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3123 - val_loss: -2.7173
# Epoch 340/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3176 - val_loss: -2.7179
# Epoch 341/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3211 - val_loss: -2.7186
# Epoch 342/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3140 - val_loss: -2.7192
# Epoch 343/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3265 - val_loss: -2.7199
# Epoch 344/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3229 - val_loss: -2.7206
# Epoch 345/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.3253 - val_loss: -2.7212
# Epoch 346/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.3229 - val_loss: -2.7219
# Epoch 347/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3265 - val_loss: -2.7225
# Epoch 348/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.3245 - val_loss: -2.7233
# Epoch 349/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.3248 - val_loss: -2.7240
# Epoch 350/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.3301 - val_loss: -2.7246
# Epoch 351/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3317 - val_loss: -2.7254
# Epoch 352/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3316 - val_loss: -2.7260
# Epoch 353/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3305 - val_loss: -2.7267
# Epoch 354/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3284 - val_loss: -2.7275
# Epoch 355/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3343 - val_loss: -2.7282
# Epoch 356/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.3387 - val_loss: -2.7289
# Epoch 357/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -1.3342 - val_loss: -2.7297
# Epoch 358/1000
# 56/56 [==============================] - 1s 12ms/step - loss: -1.3351 - val_loss: -2.7303
# Epoch 359/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3393 - val_loss: -2.7311
# Epoch 360/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3404 - val_loss: -2.7318
# Epoch 361/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3388 - val_loss: -2.7325
# Epoch 362/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3466 - val_loss: -2.7333
# Epoch 363/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3404 - val_loss: -2.7340
# Epoch 364/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3428 - val_loss: -2.7348
# Epoch 365/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3512 - val_loss: -2.7355
# Epoch 366/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.3550 - val_loss: -2.7363
# Epoch 367/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.3565 - val_loss: -2.7372
# Epoch 368/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.3576 - val_loss: -2.7378
# Epoch 369/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3491 - val_loss: -2.7387
# Epoch 370/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3579 - val_loss: -2.7394
# Epoch 371/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.3556 - val_loss: -2.7402
# Epoch 372/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3581 - val_loss: -2.7410
# Epoch 373/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3782 - val_loss: -2.7417
# Epoch 374/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3560 - val_loss: -2.7425
# Epoch 375/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3593 - val_loss: -2.7433
# Epoch 376/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.3675 - val_loss: -2.7441
# Epoch 377/1000
# 56/56 [==============================] - 0s 9ms/step - loss: -1.3686 - val_loss: -2.7450
# Epoch 378/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3886 - val_loss: -2.7458
# Epoch 379/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.3701 - val_loss: -2.7466
# Epoch 380/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.3669 - val_loss: -2.7474
# Epoch 381/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3704 - val_loss: -2.7483
# Epoch 382/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3837 - val_loss: -2.7490
# Epoch 383/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3823 - val_loss: -2.7499
# Epoch 384/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3775 - val_loss: -2.7507
# Epoch 385/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3844 - val_loss: -2.7516
# Epoch 386/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3804 - val_loss: -2.7523
# Epoch 387/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3880 - val_loss: -2.7533
# Epoch 388/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3829 - val_loss: -2.7540
# Epoch 389/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3936 - val_loss: -2.7549
# Epoch 390/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3868 - val_loss: -2.7557
# Epoch 391/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3890 - val_loss: -2.7568
# Epoch 392/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3973 - val_loss: -2.7575
# Epoch 393/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3949 - val_loss: -2.7584
# Epoch 394/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3959 - val_loss: -2.7593
# Epoch 395/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.3847 - val_loss: -2.7600
# Epoch 396/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3943 - val_loss: -2.7611
# Epoch 397/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.3974 - val_loss: -2.7618
# Epoch 398/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4010 - val_loss: -2.7627
# Epoch 399/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4029 - val_loss: -2.7635
# Epoch 400/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4019 - val_loss: -2.7645
# Epoch 401/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4137 - val_loss: -2.7653
# Epoch 402/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4095 - val_loss: -2.7663
# Epoch 403/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4047 - val_loss: -2.7672
# Epoch 404/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.4195 - val_loss: -2.7680
# Epoch 405/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.4293 - val_loss: -2.7689
# Epoch 406/1000
# 56/56 [==============================] - 0s 9ms/step - loss: -1.4222 - val_loss: -2.7698
# Epoch 407/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.4317 - val_loss: -2.7708
# Epoch 408/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.4263 - val_loss: -2.7716
# Epoch 409/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4215 - val_loss: -2.7726
# Epoch 410/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.4358 - val_loss: -2.7735
# Epoch 411/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4285 - val_loss: -2.7744
# Epoch 412/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4232 - val_loss: -2.7753
# Epoch 413/1000
# 56/56 [==============================] - 1s 9ms/step - loss: -1.4318 - val_loss: -2.7762
# Epoch 414/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4311 - val_loss: -2.7770
# Epoch 415/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4353 - val_loss: -2.7781
# Epoch 416/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4341 - val_loss: -2.7790
# Epoch 417/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4355 - val_loss: -2.7798
# Epoch 418/1000
# 56/56 [==============================] - 0s 9ms/step - loss: -1.4306 - val_loss: -2.7809
# Epoch 419/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4437 - val_loss: -2.7818
# Epoch 420/1000
# 56/56 [==============================] - 0s 9ms/step - loss: -1.4396 - val_loss: -2.7826
# Epoch 421/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4454 - val_loss: -2.7835
# Epoch 422/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4550 - val_loss: -2.7845
# Epoch 423/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4458 - val_loss: -2.7854
# Epoch 424/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4545 - val_loss: -2.7863
# Epoch 425/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4583 - val_loss: -2.7873
# Epoch 426/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4378 - val_loss: -2.7882
# Epoch 427/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -1.4505 - val_loss: -2.7891
# Epoch 428/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4421 - val_loss: -2.7901
# Epoch 429/1000
# 56/56 [==============================] - 1s 11ms/step - loss: -1.4605 - val_loss: -2.7911
# Epoch 430/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4521 - val_loss: -2.7918
# Epoch 431/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4550 - val_loss: -2.7928
# Epoch 432/1000
# 56/56 [==============================] - 1s 10ms/step - loss: -1.4674 - val_loss: -2.7938
# Epoch 433/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4586 - val_loss: -2.7947
# Epoch 434/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4648 - val_loss: -2.7956
# Epoch 435/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4708 - val_loss: -2.7967
# Epoch 436/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4672 - val_loss: -2.7975
# Epoch 437/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4868 - val_loss: -2.7985
# Epoch 438/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4775 - val_loss: -2.7994
# Epoch 439/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4787 - val_loss: -2.8003
# Epoch 440/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4891 - val_loss: -2.8013
# Epoch 441/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4799 - val_loss: -2.8023
# Epoch 442/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4815 - val_loss: -2.8032
# Epoch 443/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4853 - val_loss: -2.8041
# Epoch 444/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4836 - val_loss: -2.8050
# Epoch 445/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4912 - val_loss: -2.8059
# Epoch 446/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4931 - val_loss: -2.8068
# Epoch 447/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4860 - val_loss: -2.8079
# Epoch 448/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4935 - val_loss: -2.8088
# Epoch 449/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4931 - val_loss: -2.8097
# Epoch 450/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.4992 - val_loss: -2.8106
# Epoch 451/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4982 - val_loss: -2.8116
# Epoch 452/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -1.4995 - val_loss: -2.8124
# Epoch 453/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -1.5095 - val_loss: -2.8133
# Epoch 454/1000
# ...
# Epoch 848/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.1763 - val_loss: -2.9764
# Epoch 849/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1704 - val_loss: -2.9767
# Epoch 850/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.1714 - val_loss: -2.9770
# Epoch 851/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1782 - val_loss: -2.9772
# Epoch 852/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1818 - val_loss: -2.9776
# Epoch 853/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1944 - val_loss: -2.9779
# Epoch 854/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.1851 - val_loss: -2.9780
# Epoch 855/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1790 - val_loss: -2.9784
# Epoch 856/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1884 - val_loss: -2.9786
# Epoch 857/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1806 - val_loss: -2.9790
# Epoch 858/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1950 - val_loss: -2.9793
# Epoch 859/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.1864 - val_loss: -2.9796
# Epoch 860/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1890 - val_loss: -2.9798
# Epoch 861/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2024 - val_loss: -2.9801
# Epoch 862/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2040 - val_loss: -2.9804
# Epoch 863/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1997 - val_loss: -2.9806
# Epoch 864/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2010 - val_loss: -2.9809
# Epoch 865/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2050 - val_loss: -2.9812
# Epoch 866/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2019 - val_loss: -2.9815
# Epoch 867/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.1994 - val_loss: -2.9818
# Epoch 868/1000
# 56/56 [==============================] - 1s 13ms/step - loss: -2.2086 - val_loss: -2.9820
# Epoch 869/1000
# 56/56 [==============================] - 1s 14ms/step - loss: -2.2183 - val_loss: -2.9823
# Epoch 870/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2119 - val_loss: -2.9825
# Epoch 871/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2090 - val_loss: -2.9828
# Epoch 872/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2159 - val_loss: -2.9831
# Epoch 873/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2211 - val_loss: -2.9833
# Epoch 874/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2120 - val_loss: -2.9836
# Epoch 875/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2093 - val_loss: -2.9839
# Epoch 876/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2305 - val_loss: -2.9842
# Epoch 877/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2216 - val_loss: -2.9845
# Epoch 878/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2239 - val_loss: -2.9847
# Epoch 879/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2297 - val_loss: -2.9850
# Epoch 880/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2271 - val_loss: -2.9853
# Epoch 881/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2261 - val_loss: -2.9856
# Epoch 882/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2223 - val_loss: -2.9858
# Epoch 883/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2316 - val_loss: -2.9861
# Epoch 884/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2261 - val_loss: -2.9864
# Epoch 885/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2294 - val_loss: -2.9867
# Epoch 886/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2418 - val_loss: -2.9869
# Epoch 887/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2272 - val_loss: -2.9872
# Epoch 888/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2486 - val_loss: -2.9875
# Epoch 889/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2421 - val_loss: -2.9877
# Epoch 890/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2464 - val_loss: -2.9881
# Epoch 891/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.2446 - val_loss: -2.9883
# Epoch 892/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2416 - val_loss: -2.9886
# Epoch 893/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2598 - val_loss: -2.9888
# Epoch 894/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2447 - val_loss: -2.9891
# Epoch 895/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2489 - val_loss: -2.9895
# Epoch 896/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2503 - val_loss: -2.9897
# Epoch 897/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2499 - val_loss: -2.9899
# Epoch 898/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2468 - val_loss: -2.9902
# Epoch 899/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2540 - val_loss: -2.9904
# Epoch 900/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2562 - val_loss: -2.9908
# Epoch 901/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2595 - val_loss: -2.9910
# Epoch 902/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.2704 - val_loss: -2.9913
# Epoch 903/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2576 - val_loss: -2.9916
# Epoch 904/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2584 - val_loss: -2.9918
# Epoch 905/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2553 - val_loss: -2.9921
# Epoch 906/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2645 - val_loss: -2.9924
# Epoch 907/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2737 - val_loss: -2.9928
# Epoch 908/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2749 - val_loss: -2.9929
# Epoch 909/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2655 - val_loss: -2.9932
# Epoch 910/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2728 - val_loss: -2.9935
# Epoch 911/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2756 - val_loss: -2.9938
# Epoch 912/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2674 - val_loss: -2.9941
# Epoch 913/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2785 - val_loss: -2.9943
# Epoch 914/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2799 - val_loss: -2.9946
# Epoch 915/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2885 - val_loss: -2.9949
# Epoch 916/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2752 - val_loss: -2.9951
# Epoch 917/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2824 - val_loss: -2.9955
# Epoch 918/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2789 - val_loss: -2.9957
# Epoch 919/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2784 - val_loss: -2.9959
# Epoch 920/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3004 - val_loss: -2.9963
# Epoch 921/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2927 - val_loss: -2.9965
# Epoch 922/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.2993 - val_loss: -2.9968
# Epoch 923/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2923 - val_loss: -2.9970
# Epoch 924/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2998 - val_loss: -2.9973
# Epoch 925/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.2916 - val_loss: -2.9976
# Epoch 926/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3025 - val_loss: -2.9979
# Epoch 927/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.2985 - val_loss: -2.9981
# Epoch 928/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3128 - val_loss: -2.9984
# Epoch 929/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.2862 - val_loss: -2.9986
# Epoch 930/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3067 - val_loss: -2.9990
# Epoch 931/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3091 - val_loss: -2.9992
# Epoch 932/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3132 - val_loss: -2.9995
# Epoch 933/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3090 - val_loss: -2.9998
# Epoch 934/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3037 - val_loss: -3.0001
# Epoch 935/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3101 - val_loss: -3.0003
# Epoch 936/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3130 - val_loss: -3.0006
# Epoch 937/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3090 - val_loss: -3.0009
# Epoch 938/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3293 - val_loss: -3.0011
# Epoch 939/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3173 - val_loss: -3.0015
# Epoch 940/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3192 - val_loss: -3.0017
# Epoch 941/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3270 - val_loss: -3.0020
# Epoch 942/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3225 - val_loss: -3.0023
# Epoch 943/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3194 - val_loss: -3.0025
# Epoch 944/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3240 - val_loss: -3.0028
# Epoch 945/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3367 - val_loss: -3.0031
# Epoch 946/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3242 - val_loss: -3.0033
# Epoch 947/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3373 - val_loss: -3.0036
# Epoch 948/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3328 - val_loss: -3.0039
# Epoch 949/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3387 - val_loss: -3.0041
# Epoch 950/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3382 - val_loss: -3.0044
# Epoch 951/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3277 - val_loss: -3.0047
# Epoch 952/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3443 - val_loss: -3.0050
# Epoch 953/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3334 - val_loss: -3.0052
# Epoch 954/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3371 - val_loss: -3.0055
# Epoch 955/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3624 - val_loss: -3.0057
# Epoch 956/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3543 - val_loss: -3.0060
# Epoch 957/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3463 - val_loss: -3.0063
# Epoch 958/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3518 - val_loss: -3.0066
# Epoch 959/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3522 - val_loss: -3.0068
# Epoch 960/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3620 - val_loss: -3.0070
# Epoch 961/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3521 - val_loss: -3.0073
# Epoch 962/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3521 - val_loss: -3.0076
# Epoch 963/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3503 - val_loss: -3.0080
# Epoch 964/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3670 - val_loss: -3.0082
# Epoch 965/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3774 - val_loss: -3.0084
# Epoch 966/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3638 - val_loss: -3.0087
# Epoch 967/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3652 - val_loss: -3.0089
# Epoch 968/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3785 - val_loss: -3.0092
# Epoch 969/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3680 - val_loss: -3.0095
# Epoch 970/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3728 - val_loss: -3.0097
# Epoch 971/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3586 - val_loss: -3.0100
# Epoch 972/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3756 - val_loss: -3.0103
# Epoch 973/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3722 - val_loss: -3.0105
# Epoch 974/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.3787 - val_loss: -3.0108
# Epoch 975/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3781 - val_loss: -3.0111
# Epoch 976/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3849 - val_loss: -3.0114
# Epoch 977/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3859 - val_loss: -3.0116
# Epoch 978/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3790 - val_loss: -3.0119
# Epoch 979/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3864 - val_loss: -3.0121
# Epoch 980/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3910 - val_loss: -3.0124
# Epoch 981/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.3864 - val_loss: -3.0127
# Epoch 982/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4046 - val_loss: -3.0129
# Epoch 983/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3842 - val_loss: -3.0132
# Epoch 984/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3858 - val_loss: -3.0135
# Epoch 985/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3909 - val_loss: -3.0137
# Epoch 986/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3983 - val_loss: -3.0140
# Epoch 987/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.4012 - val_loss: -3.0143
# Epoch 988/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4011 - val_loss: -3.0145
# Epoch 989/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3969 - val_loss: -3.0148
# Epoch 990/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4081 - val_loss: -3.0151
# Epoch 991/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3959 - val_loss: -3.0154
# Epoch 992/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4114 - val_loss: -3.0156
# Epoch 993/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.3897 - val_loss: -3.0159
# Epoch 994/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4103 - val_loss: -3.0161
# Epoch 995/1000
# 56/56 [==============================] - 0s 6ms/step - loss: -2.4144 - val_loss: -3.0164
# Epoch 996/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4186 - val_loss: -3.0166
# Epoch 997/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4112 - val_loss: -3.0170
# Epoch 998/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4154 - val_loss: -3.0172
# Epoch 999/1000
# 56/56 [==============================] - 0s 8ms/step - loss: -2.4167 - val_loss: -3.0174
# Epoch 1000/1000
# 56/56 [==============================] - 0s 7ms/step - loss: -2.4233 - val_loss: -3.0177

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
##그래프저장
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 31), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# 포트폴리오 수익률 (연간):
# crp_rtn      0.102273
# lstm_rtn     0.101755
# sp500_rtn    0.083039
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.042336
# lstm_rtn     0.054583
# sp500_rtn    0.062662
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      2.415771
# lstm_rtn     1.864236
# sp500_rtn    1.325181
# dtype: float64

# %% [markdown]
# ## 가중치 DF 저장 (일자별)

# %%
w_hist_lstm = []
for i in range(0, xc_test.shape[0]):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)

# %%
idx = np.arange(0, len(test_date))
date=test_date[idx]

# %%
W_df=pd.DataFrame(w_hist_lstm[:-1],columns=rtn_df.columns,index=list(date)[20:])
W_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 2020-01-29  0.070550  0.061675  0.064723  0.154777  0.057919  0.192750
# 2020-01-30  0.067082  0.062645  0.064830  0.151532  0.057903  0.199340
# 2020-01-31  0.062015  0.058732  0.062725  0.173860  0.055574  0.195758
# 2020-02-03  0.062633  0.059673  0.064361  0.164536  0.056166  0.200697
# 2020-02-04  0.063149  0.059445  0.063963  0.167379  0.055863  0.199063
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.099079  0.079493  0.072274  0.136883  0.066145  0.175853
# 2022-05-05  0.146439  0.106608  0.080498  0.129932  0.074587  0.161077
# 2022-05-06  0.185661  0.166382  0.079847  0.137060  0.079639  0.145912
# 2022-05-09  0.228560  0.172424  0.084550  0.119589  0.089976  0.143537
# 2022-05-10  0.220939  0.212105  0.086604  0.108880  0.096120  0.142988
#
#                nsd로그
# 2020-01-29  0.397606
# 2020-01-30  0.396668
# 2020-01-31  0.391336
# 2020-02-03  0.391935
# 2020-02-04  0.391138
# ...              ...
# 2022-05-04  0.370273
# 2022-05-05  0.300859
# 2022-05-06  0.205499
# 2022-05-09  0.161364
# 2022-05-10  0.132364
#
# [593 rows x 7 columns]

# %%
W_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.csv")

# %% [markdown]
# # 타 펀드 비교(KB)

# %%
kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
kb.일자=pd.to_datetime(kb.일자)
kb=kb.set_index('일자')
#일자설정
kb=kb.loc[perf_df.index[0]:perf_df.index[-1]]
kb['금액']=10000
kb['수익률(%)']=kb['수익률(%)']*0.01
for i in range(1,kb.shape[0]):
    kb.iloc[i,1]=kb.iloc[i,0]*kb.iloc[i-1,1]+kb.iloc[i-1,1]
p_df=perf_df.copy()
p_df=p_df.reset_index()
kb=kb.reset_index()
grp=pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')
grp=grp.set_index('Date')
grp=grp[['crp', 'lstm_markowitz', 'kospi', '금액']]
grp.columns=['crp', 'lstm_markowitz', 'kospi', 'KB펀드']
grp=grp.dropna()

# %%
p = grp.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.show()

# %% [markdown]
# # 타 펀드 비교 <미래에셋>

# %%
fa=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/미래에셋.csv")
fa=fa.T
fa=fa.iloc[1:]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
fa=fa.set_index('index')
fa.columns=['투자수익률','비교지수']
fa['미래에셋']=fa['투자수익률']*0.01*10000+10000
fa['미래에셋_pct']=fa['미래에셋'].pct_change(1)
#일자설정
fa=fa.loc[perf_df.index[0]:perf_df.index[-1]]
fa['미래에셋']=10000
for i in range(1,fa.shape[0]):
    fa.iloc[i,2]=fa.iloc[i,3]*fa.iloc[i-1,2]+fa.iloc[i-1,2]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])

# %%
grp=pd.merge(grp.reset_index(),fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
grp=grp[['Date','crp','lstm_markowitz','kospi','미래에셋','KB펀드']]
grp=grp.dropna()
grp=grp.set_index('Date')

# %%
p = grp[['lstm_markowitz', 'kospi', '미래에셋', 'KB펀드']].plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()

# %% [markdown]
# # 주식 전략 결합

# %%
log_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
log_df['Date']=pd.to_datetime(log_df['Date'])

# %%
r_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/레버리지로그수익률.csv")

# %%
r_df=r_df.fillna(0)

# %%
r_df['Unnamed: 0']=pd.to_datetime(r_df['Unnamed: 0'])
r_df.columns=['Date','레버리지기법']
r_df=r_df.set_index('Date')

# %%
r_df.loc[perf_df.index[0]:perf_df.index[-1]]
# Out:
#               레버리지기법
# Date
# 2020-01-02 -0.007227
# 2020-01-03 -0.000912
# 2020-01-06 -0.003326
# 2020-01-07  0.022675
# 2020-01-08  0.004034
# ...              ...
# 2022-04-18  0.011149
# 2022-04-19  0.007144
# 2022-04-20  0.008293
# 2022-04-21  0.008251
# 2022-04-22 -0.012174
#
# [571 rows x 1 columns]

# %%
log_df=pd.merge(log_df,r_df[['Date','레버리지기법']],on='Date',how='outer').dropna()

# %%
log_df
# Out:
#            Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 1    2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2    2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 3    2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 4    2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# 5    2006-03-08  0.000203  0.000818 -0.001992 -0.019625 -0.016154  0.005173
# ...         ...       ...       ...       ...       ...       ...       ...
# 4191 2022-05-03  0.000032 -0.000973 -0.002604  0.002823 -0.014052  0.012346
# 4192 2022-05-04  0.000084 -0.000864 -0.001079  0.009819  0.030728  0.011425
# 4194 2022-05-06  0.000109  0.001001 -0.012424  0.001961  0.001061 -0.011940
# 4195 2022-05-09  0.000202  0.002147  0.000000 -0.014940 -0.046284 -0.045043
# 4196 2022-05-10  0.000063  0.000674 -0.018298 -0.008557 -0.005939 -0.018388
#
#          nsd로그   상승          코스피    레버리지기법
# 1    -0.012176  0.0  1367.699951  0.008548
# 2     0.017103  0.0  1328.949951 -0.020464
# 3    -0.018103  0.0  1344.760010  0.001442
# 4    -0.043212  0.0  1316.670044 -0.031050
# 5     0.007549  0.0  1314.050049 -0.003508
# ...        ...  ...          ...       ...
# 4191  0.007312  0.0  2680.459961 -0.007335
# 4192  0.014217  0.0  2677.570068 -0.003867
# 4194 -0.016993  0.0  2644.510010 -0.021694
# 4195 -0.040948  0.0  2644.510010 -0.019313
# 4196 -0.002740  0.0  2596.560059  0.004609
#
# [4001 rows x 11 columns]

# %%
#비중 df
w_df=pd.DataFrame(w_hist_lstm,columns=symbol,index=list(perf_df.index[1:]))

# %%
w_df=w_df.reset_index()

# %%
w_df.columns=['Date', '단기채w', '중기채w', 'kspw', 'iauw', 'dbcw', 'vnqw',
       'nsdw']
w_df.Date=pd.to_datetime(w_df.Date)

# %%
log_df=pd.merge(log_df,w_df,on='Date',how='outer')

# %%
#기간별로 정렬
log_df=log_df.sort_values(by=['Date'], ascending=True)

# %%
log_df=log_df.fillna(method='ffill').dropna()

# %%
log_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','레버리지기법']]=log_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','레버리지기법']].cumsum()

# %%
log_df['금액']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['ksp로그'])

# %%
log_df.columns
# Out:
# Index(['Date', 'crp', 'lstm_markowitz', 'kospi', '미래에셋', 'KB펀드', '단기채로그',
#        '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그', '상승', '코스피',
#        '레버리지기법', '단기채w', '중기채w', 'kspw', 'iauw', 'dbcw', 'vnqw', 'nsdw'],
#       dtype='object')

# %%
log_df['금액']=10000

# %%
log_df
# Out:
#      index       Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그  \
# 0     3436 2020-01-29  0.000055  0.000712  0.003925  0.004659 -0.004709
# 1     3437 2020-01-30  0.000121  0.001354 -0.013282  0.005323 -0.013514
# 2     3438 2020-01-31  0.000174  0.001314 -0.026870  0.011937 -0.021710
# 3     3439 2020-02-03  0.000335  0.002022 -0.026932  0.004659 -0.040403
# 4     3440 2020-02-04  0.000394  0.000961 -0.008684 -0.008710 -0.039006
# ..     ...        ...       ...       ...       ...       ...       ...
# 562   3996 2022-05-03  0.024343 -0.009579  0.221533  0.136900  0.626770
# 563   3997 2022-05-04  0.024427 -0.010443  0.220454  0.146719  0.657498
# 564   3998 2022-05-06  0.024537 -0.009443  0.208031  0.148680  0.658558
# 565   3999 2022-05-09  0.024738 -0.007295  0.208031  0.133740  0.612274
# 566   4000 2022-05-10  0.024801 -0.006621  0.189732  0.125183  0.606335
#
#         vnq로그     nsd로그   상승          코스피    레버리지기법      단기채w      중기채w  \
# 0   -0.003677  0.037094  1.0  2185.280029  0.016772  0.070550  0.061675
# 1   -0.002940  0.042455  1.0  2148.000000 -0.005751  0.070550  0.061675
# 2   -0.015214  0.046757  1.0  2119.010010 -0.008286  0.070550  0.061675
# 3   -0.011919  0.058113  1.0  2118.879883 -0.010043  0.070550  0.061675
# 4   -0.001679  0.065556  1.0  2157.899902  0.003297  0.070550  0.061675
# ..        ...       ...  ...          ...       ...       ...       ...
# 562  0.160364  0.302106  0.0  2680.459961  0.163253  0.263879  0.204511
# 563  0.171790  0.316322  0.0  2677.570068  0.159386  0.263879  0.204511
# 564  0.159849  0.299329  0.0  2644.510010  0.137692  0.263879  0.204511
# 565  0.114806  0.258381  0.0  2644.510010  0.118379  0.263879  0.204511
# 566  0.096418  0.255641  0.0  2596.560059  0.122988  0.263879  0.204511
#
#          kspw      iauw      dbcw      vnqw      nsdw            금액
# 0    0.064723  0.154777  0.057919  0.192750  0.397606  10039.325493
# 1    0.064723  0.154777  0.057919  0.192750  0.397606   9868.058496
# 2    0.064723  0.154777  0.057919  0.192750  0.397606   9734.876504
# 3    0.064723  0.154777  0.057919  0.192750  0.397606   9734.278691
# 4    0.064723  0.154777  0.057919  0.192750  0.397606   9913.539322
# ..        ...       ...       ...       ...       ...           ...
# 562  0.091360  0.088651  0.146297  0.118937  0.086365  12479.885875
# 563  0.091360  0.088651  0.146297  0.118937  0.086365  12466.430897
# 564  0.091360  0.088651  0.146297  0.118937  0.086365  12312.507405
# 565  0.091360  0.088651  0.146297  0.118937  0.086365  12312.507405
# 566  0.091360  0.088651  0.146297  0.118937  0.086365  12089.258437
#
# [567 rows x 20 columns]

# %%
log_df['금액']=log_df['금액']*np.exp(log_df['ksp로그'])

# %%
log_df=log_df.reset_index()

# %%
grp=pd.merge(grp.reset_index(),log_df[['Date','금액']],on='Date',how='outer').dropna()

# %%
p = grp[['lstm_markowitz', 'kospi', '미래에셋', 'KB펀드','금액']].plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()

# %%
grp
# Out:
#                      crp  lstm_markowitz         kospi          미래에셋  \
# Date
# 2019-12-31  10000.000000    10000.000000  10000.000000  10000.000000
# 2020-01-29  10036.938181    10224.825144   9943.622596   9629.564297
# 2020-02-26  10005.999563    10295.900080   9449.872335   8954.842124
# 2020-03-25   8402.684397     8137.672903   7757.124911   6931.557594
# 2020-04-22   9057.310134     8708.347455   8628.001892   7832.951138
# 2020-05-20   9362.758662     9051.162397   9053.406951   8273.064032
# 2020-06-17   9824.690125     9496.075493   9742.364072   8539.424943
# 2020-07-15   9957.452690     9693.330050  10019.156475   8721.114835
# 2020-08-12  10371.504093    10128.862742  11067.859069   9440.818487
# 2020-09-09  10292.450094    10063.904103  10810.586408   9187.687423
# 2020-10-07  10275.134080     9984.177318  10861.230422   9319.103898
# 2020-11-04  10237.541204     9981.092303  10726.451888   9218.557065
# 2020-12-02  10597.367513    10321.319603  12176.077380  10275.180808
# 2020-12-31  10894.766691    10518.663007  13075.075297  11180.984301
# 2021-01-29  11152.962972    10823.820056  13542.570389  11487.916740
# 2021-02-26  11372.913887    10954.044864  13709.747406  11794.849180
# 2021-03-26  11325.681680    11101.501111  13837.428358  12222.614218
# 2021-04-23  11839.313048    11778.345831  14474.785528  12817.957312
# 2021-05-21  12021.770849    12011.649133  14362.575064  12713.000529
# 2021-06-18  12277.632671    12309.262421  14869.976147  12985.535368
# 2021-07-16  12426.582998    12415.465402  14910.837517  13082.554242
# 2021-08-13  12453.489541    12646.145731  14430.238170  12573.646146
# 2021-09-10  12541.492616    12927.108612  14223.064067  12628.329511
# 2021-10-08  12507.212782    12833.097990  13451.974837  11965.073205
# 2021-11-05  12761.542320    13370.005194  13510.991755  11899.805962
# 2021-12-03  12483.723393    12989.070543  13506.714764  12004.762745
# 2021-12-31  12894.858341    13492.275383  13549.122517  12262.303757
# 2022-01-28  12169.251869    12293.796849  12118.926784  11074.263539
# 2022-02-25  12386.036159    12415.628222  12179.991104  11158.934556
# 2022-03-25  12836.006161    12819.592352  12422.156545  11382.959958
# 2022-04-22  12913.432618    12896.716753  12307.171036  11360.028224
#
#                     KB펀드
# Date
# 2019-12-31  10000.000000
# 2020-01-29  10001.226413
# 2020-02-26  10003.711958
# 2020-03-25   9384.491606
# 2020-04-22   9915.377562
# 2020-05-20  10137.949590
# 2020-06-17  10302.839218
# 2020-07-15  10403.527375
# 2020-08-12  10647.166535
# 2020-09-09  10601.037559
# 2020-10-07  10595.732142
# 2020-11-04  10556.818433
# 2020-12-02  10927.285521
# 2020-12-31  11241.136501
# 2021-01-29  11444.498132
# 2021-02-26  11676.615631
# 2021-03-26  11856.883786
# 2021-04-23  12055.941048
# 2021-05-21  12026.296586
# 2021-06-18  12186.972527
# 2021-07-16  12302.854271
# 2021-08-13  12365.113572
# 2021-09-10  12259.260034
# 2021-10-08  12097.598061
# 2021-11-05  12153.756683
# 2021-12-03  12070.437716
# 2021-12-31  12189.993461
# 2022-01-28  11746.996099
# 2022-02-25  11705.772804
# 2022-03-25  11867.286281
# 2022-04-22  11849.037618
