# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')

# %%
rtn_df=rtn_df[rtn_df['상승']==0]
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]
rtn_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.000084 -0.000864 -0.001079  0.009819  0.030728  0.011425
# 2022-05-05  0.000000  0.000000  0.000000 -0.004196 -0.005292 -0.027030
# 2022-05-06  0.000109  0.001001 -0.012424  0.001961  0.001061 -0.011940
# 2022-05-09  0.000202  0.002147  0.000000 -0.014940 -0.046284 -0.045043
# 2022-05-10  0.000063  0.000674 -0.018298 -0.008557 -0.005939 -0.018388
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2022-05-04  0.014217
# 2022-05-05 -0.033019
# 2022-05-06 -0.016993
# 2022-05-09 -0.040948
# 2022-05-10 -0.002740
#
# [2258 rows x 7 columns]

# %%
rtn_df_train=rtn_df.loc[:'2021-08-31']
rtn_df_test=rtn_df.loc['2021-09-01':'2022-05-10']

# %%
rtn_df_train
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  0.000044  0.000002  0.014103 -0.002368 -0.025318 -0.028902
# 2020-06-25  0.000025  0.000145 -0.022996 -0.001186  0.009057  0.012691
# 2020-06-26  0.000017  0.000046  0.010492  0.004737 -0.012371 -0.019380
# 2020-06-29  0.000081 -0.000325 -0.019475  0.000000  0.016461  0.019123
# 2020-06-30  0.000043 -0.000137  0.007068  0.003538  0.004886  0.011784
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2020-06-24 -0.028392
# 2020-06-25  0.029151
# 2020-06-26 -0.024478
# 2020-06-29  0.014826
# 2020-06-30  0.016202
#
# [2078 rows x 7 columns]

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[df['상승']==0]

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
up_2006=df.loc['2006-10-02':'2007-10-31']
up_2009=df.loc['2009-01-02':'2010-01-29']
up_2012=df.loc['2012-03-01':'2013-09-30']
up_2014=df.loc['2014-09-01':'2015-05-29']
up_2015=df.loc['2015-10-01':'2016-01-29']
up_2016=df.loc['2016-05-02':'2017-06-30']
up_2019=df.loc['2019-12-02':'2020-03-31']
#up_2020=df.loc['2020-07-01':'2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

for i in range(1, len(up_2006) - T + 1):
    d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2009) - T + 1):
    d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2012) - T + 1):
    d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2014) - T + 1):
    d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2015) - T + 1):
    d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2016) - T + 1):
    d = np.expand_dims(np.array(up_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2019) - T + 1):
    d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
#for i in range(0, len(up_2020) - T + 1):
    #d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
    #x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# #  데이터셋 나눠서 만들기(하강)

# %%
down_2006=df.loc['2006-03-01':'2006-09-29']
down_2007=df.loc['2007-11-01':'2008-12-31']
down_2010=df.loc['2010-02-01':'2012-02-29']
down_2013=df.loc['2013-10-01':'2014-08-29']
down_2015=df.loc['2015-06-01':'2015-09-30']
down_2016=df.loc['2016-02-01':'2016-04-29']
down_2017=df.loc['2017-07-03':'2019-11-29']
down_2020=df.loc['2020-04-01':'2020-06-30']
#down_2021=df.loc['2021-09-01':'2022-05-10']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(down_2006.iloc[0:T, :]), 0)

for i in range(1, len(down_2006) - T + 1):
    d = np.expand_dims(np.array(down_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2007) - T + 1):
    d = np.expand_dims(np.array(down_2007.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2010) - T + 1):
    d = np.expand_dims(np.array(down_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2013) - T + 1):
    d = np.expand_dims(np.array(down_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2015) - T + 1):
    d = np.expand_dims(np.array(down_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2016) - T + 1):
    d = np.expand_dims(np.array(down_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2017) - T + 1):
    d = np.expand_dims(np.array(down_2017.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2020) - T + 1):
    d = np.expand_dims(np.array(down_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(down_2021) - T + 1):
#     d = np.expand_dims(np.array(down_2021.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# # rtn_train 구성하기

# %%
# rtn_train 값에 기간별로 자른 값 집어넣기
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100

N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.1
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 7)                 420
#
#  dense_6 (Dense)             (None, 7)                 56
#
#  activation_6 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 28/28 [==============================] - 3s 32ms/step - loss: 0.1207 - val_loss: -0.9947
# Epoch 2/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0913 - val_loss: -0.9953
# Epoch 3/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0964 - val_loss: -0.9958
# Epoch 4/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1140 - val_loss: -0.9963
# Epoch 5/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1189 - val_loss: -0.9969
# Epoch 6/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0905 - val_loss: -0.9975
# Epoch 7/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1162 - val_loss: -0.9980
# Epoch 8/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0972 - val_loss: -0.9986
# Epoch 9/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1143 - val_loss: -0.9990
# Epoch 10/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1152 - val_loss: -0.9997
# Epoch 11/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0957 - val_loss: -1.0001
# Epoch 12/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1007 - val_loss: -1.0008
# Epoch 13/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1025 - val_loss: -1.0013
# Epoch 14/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1458 - val_loss: -1.0019
# Epoch 15/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0886 - val_loss: -1.0025
# Epoch 16/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0781 - val_loss: -1.0030
# Epoch 17/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1163 - val_loss: -1.0036
# Epoch 18/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1048 - val_loss: -1.0041
# Epoch 19/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0732 - val_loss: -1.0046
# Epoch 20/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0777 - val_loss: -1.0052
# Epoch 21/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0925 - val_loss: -1.0058
# Epoch 22/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1141 - val_loss: -1.0062
# Epoch 23/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1261 - val_loss: -1.0067
# Epoch 24/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0990 - val_loss: -1.0074
# Epoch 25/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0742 - val_loss: -1.0080
# Epoch 26/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1038 - val_loss: -1.0085
# Epoch 27/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0726 - val_loss: -1.0091
# Epoch 28/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0831 - val_loss: -1.0097
# Epoch 29/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0946 - val_loss: -1.0103
# Epoch 30/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0753 - val_loss: -1.0108
# Epoch 31/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0810 - val_loss: -1.0114
# Epoch 32/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0988 - val_loss: -1.0118
# Epoch 33/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0731 - val_loss: -1.0124
# Epoch 34/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0912 - val_loss: -1.0129
# Epoch 35/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1013 - val_loss: -1.0135
# Epoch 36/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1047 - val_loss: -1.0141
# Epoch 37/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0876 - val_loss: -1.0145
# Epoch 38/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0773 - val_loss: -1.0151
# Epoch 39/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0993 - val_loss: -1.0157
# Epoch 40/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0898 - val_loss: -1.0163
# Epoch 41/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0774 - val_loss: -1.0167
# Epoch 42/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0789 - val_loss: -1.0175
# Epoch 43/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0833 - val_loss: -1.0179
# Epoch 44/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0711 - val_loss: -1.0184
# Epoch 45/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0885 - val_loss: -1.0191
# Epoch 46/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0583 - val_loss: -1.0195
# Epoch 47/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0389 - val_loss: -1.0201
# Epoch 48/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0521 - val_loss: -1.0206
# Epoch 49/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0656 - val_loss: -1.0211
# Epoch 50/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0862 - val_loss: -1.0218
# Epoch 51/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0694 - val_loss: -1.0222
# Epoch 52/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0659 - val_loss: -1.0228
# Epoch 53/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0622 - val_loss: -1.0234
# Epoch 54/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0852 - val_loss: -1.0240
# Epoch 55/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0700 - val_loss: -1.0245
# Epoch 56/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0620 - val_loss: -1.0251
# Epoch 57/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0458 - val_loss: -1.0255
# Epoch 58/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0543 - val_loss: -1.0261
# Epoch 59/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0514 - val_loss: -1.0267
# Epoch 60/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0522 - val_loss: -1.0272
# Epoch 61/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0773 - val_loss: -1.0279
# Epoch 62/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0619 - val_loss: -1.0283
# Epoch 63/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0598 - val_loss: -1.0289
# Epoch 64/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0760 - val_loss: -1.0295
# Epoch 65/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0412 - val_loss: -1.0300
# Epoch 66/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0713 - val_loss: -1.0307
# Epoch 67/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0476 - val_loss: -1.0311
# Epoch 68/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0666 - val_loss: -1.0317
# Epoch 69/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0424 - val_loss: -1.0322
# Epoch 70/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0557 - val_loss: -1.0328
# Epoch 71/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0709 - val_loss: -1.0334
# Epoch 72/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0332 - val_loss: -1.0339
# Epoch 73/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0374 - val_loss: -1.0344
# Epoch 74/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0254 - val_loss: -1.0350
# Epoch 75/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0728 - val_loss: -1.0355
# Epoch 76/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0606 - val_loss: -1.0360
# Epoch 77/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0638 - val_loss: -1.0367
# Epoch 78/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: -1.0371
# Epoch 79/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0390 - val_loss: -1.0376
# Epoch 80/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 8.4076e-04 - val_loss: -1.0384
# Epoch 81/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0184 - val_loss: -1.0388
# Epoch 82/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0268 - val_loss: -1.0394
# Epoch 83/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0109 - val_loss: -1.0399
# Epoch 84/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0607 - val_loss: -1.0404
# Epoch 85/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0340 - val_loss: -1.0410
# Epoch 86/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0389 - val_loss: -1.0415
# Epoch 87/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0315 - val_loss: -1.0420
# Epoch 88/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0409 - val_loss: -1.0427
# Epoch 89/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0360 - val_loss: -1.0431
# Epoch 90/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0279 - val_loss: -1.0438
# Epoch 91/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0169 - val_loss: -1.0442
# Epoch 92/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0382 - val_loss: -1.0449
# Epoch 93/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0293 - val_loss: -1.0453
# Epoch 94/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0235 - val_loss: -1.0458
# Epoch 95/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0298 - val_loss: -1.0464
# Epoch 96/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0283 - val_loss: -1.0470
# Epoch 97/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0496 - val_loss: -1.0475
# Epoch 98/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0132 - val_loss: -1.0481
# Epoch 99/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0233 - val_loss: -1.0486
# Epoch 100/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0252 - val_loss: -1.0492
# Epoch 101/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: -1.0497
# Epoch 102/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0388 - val_loss: -1.0503
# Epoch 103/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: -1.0507
# Epoch 104/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -9.4259e-04 - val_loss: -1.0513
# Epoch 105/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0230 - val_loss: -1.0520
# Epoch 106/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -7.5925e-04 - val_loss: -1.0525
# Epoch 107/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0030 - val_loss: -1.0530
# Epoch 108/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0176 - val_loss: -1.0536
# Epoch 109/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0104 - val_loss: -1.0541
# Epoch 110/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0312 - val_loss: -1.0547
# Epoch 111/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0114 - val_loss: -1.0553
# Epoch 112/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: -1.0558
# Epoch 113/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: -1.0563
# Epoch 114/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 9.9034e-04 - val_loss: -1.0569
# Epoch 115/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0063 - val_loss: -1.0574
# Epoch 116/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0118 - val_loss: -1.0580
# Epoch 117/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: -1.0585
# Epoch 118/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0284 - val_loss: -1.0592
# Epoch 119/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: -1.0597
# Epoch 120/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0062 - val_loss: -1.0601
# Epoch 121/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0242 - val_loss: -1.0607
# Epoch 122/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: -1.0613
# Epoch 123/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0031 - val_loss: -1.0619
# Epoch 124/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0131 - val_loss: -1.0623
# Epoch 125/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0017 - val_loss: -1.0629
# Epoch 126/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0051 - val_loss: -1.0634
# Epoch 127/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0151 - val_loss: -1.0640
# Epoch 128/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0163 - val_loss: -1.0646
# Epoch 129/1000
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: -1.0652
# Epoch 130/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0241 - val_loss: -1.0657
# Epoch 131/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0050 - val_loss: -1.0662
# Epoch 132/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0154 - val_loss: -1.0668
# Epoch 133/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0093 - val_loss: -1.0672
# Epoch 134/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: -1.0678
# Epoch 135/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0157 - val_loss: -1.0684
# Epoch 136/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0058 - val_loss: -1.0690
# Epoch 137/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0025 - val_loss: -1.0695
# Epoch 138/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0299 - val_loss: -1.0701
# Epoch 139/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0221 - val_loss: -1.0706
# Epoch 140/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0215 - val_loss: -1.0712
# Epoch 141/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0420 - val_loss: -1.0717
# Epoch 142/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0083 - val_loss: -1.0722
# Epoch 143/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0307 - val_loss: -1.0728
# Epoch 144/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0211 - val_loss: -1.0734
# Epoch 145/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0628 - val_loss: -1.0739
# Epoch 146/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0115 - val_loss: -1.0745
# Epoch 147/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0470 - val_loss: -1.0750
# Epoch 148/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0166 - val_loss: -1.0755
# Epoch 149/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0094 - val_loss: -1.0761
# Epoch 150/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0451 - val_loss: -1.0766
# Epoch 151/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0128 - val_loss: -1.0772
# Epoch 152/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0135 - val_loss: -1.0777
# Epoch 153/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0378 - val_loss: -1.0783
# Epoch 154/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0286 - val_loss: -1.0788
# Epoch 155/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0250 - val_loss: -1.0794
# Epoch 156/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0090 - val_loss: -1.0799
# Epoch 157/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0256 - val_loss: -1.0805
# Epoch 158/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0144 - val_loss: -1.0811
# Epoch 159/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0097 - val_loss: -1.0815
# Epoch 160/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.0162 - val_loss: -1.0822
# Epoch 161/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0414 - val_loss: -1.0827
# Epoch 162/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0232 - val_loss: -1.0833
# Epoch 163/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0403 - val_loss: -1.0838
# Epoch 164/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0456 - val_loss: -1.0843
# Epoch 165/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0263 - val_loss: -1.0850
# Epoch 166/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0435 - val_loss: -1.0854
# Epoch 167/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0336 - val_loss: -1.0859
# Epoch 168/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0274 - val_loss: -1.0866
# Epoch 169/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0272 - val_loss: -1.0871
# Epoch 170/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0385 - val_loss: -1.0876
# Epoch 171/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0628 - val_loss: -1.0883
# Epoch 172/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0351 - val_loss: -1.0888
# Epoch 173/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0222 - val_loss: -1.0893
# Epoch 174/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0028 - val_loss: -1.0899
# Epoch 175/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0413 - val_loss: -1.0904
# Epoch 176/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0461 - val_loss: -1.0909
# Epoch 177/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0634 - val_loss: -1.0915
# Epoch 178/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0293 - val_loss: -1.0920
# Epoch 179/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0655 - val_loss: -1.0928
# Epoch 180/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0362 - val_loss: -1.0933
# Epoch 181/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0539 - val_loss: -1.0937
# Epoch 182/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0445 - val_loss: -1.0943
# Epoch 183/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0576 - val_loss: -1.0949
# Epoch 184/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0676 - val_loss: -1.0954
# Epoch 185/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0572 - val_loss: -1.0959
# Epoch 186/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0506 - val_loss: -1.0965
# Epoch 187/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0479 - val_loss: -1.0971
# Epoch 188/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0714 - val_loss: -1.0977
# Epoch 189/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0623 - val_loss: -1.0982
# Epoch 190/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0653 - val_loss: -1.0988
# Epoch 191/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0425 - val_loss: -1.0994
# Epoch 192/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0555 - val_loss: -1.0999
# Epoch 193/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0501 - val_loss: -1.1004
# Epoch 194/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0868 - val_loss: -1.1010
# Epoch 195/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0702 - val_loss: -1.1016
# Epoch 196/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0692 - val_loss: -1.1022
# Epoch 197/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0678 - val_loss: -1.1027
# Epoch 198/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0549 - val_loss: -1.1032
# Epoch 199/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0558 - val_loss: -1.1037
# Epoch 200/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0786 - val_loss: -1.1043
# Epoch 201/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0555 - val_loss: -1.1049
# Epoch 202/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0861 - val_loss: -1.1054
# Epoch 203/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0802 - val_loss: -1.1059
# Epoch 204/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0600 - val_loss: -1.1065
# Epoch 205/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0820 - val_loss: -1.1071
# Epoch 206/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0720 - val_loss: -1.1076
# Epoch 207/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0728 - val_loss: -1.1081
# Epoch 208/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0991 - val_loss: -1.1088
# Epoch 209/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0687 - val_loss: -1.1093
# Epoch 210/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0921 - val_loss: -1.1100
# Epoch 211/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0592 - val_loss: -1.1105
# Epoch 212/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0735 - val_loss: -1.1110
# Epoch 213/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0756 - val_loss: -1.1115
# Epoch 214/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0900 - val_loss: -1.1121
# Epoch 215/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0781 - val_loss: -1.1127
# Epoch 216/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1349 - val_loss: -1.1133
# Epoch 217/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1047 - val_loss: -1.1138
# Epoch 218/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0645 - val_loss: -1.1143
# Epoch 219/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0868 - val_loss: -1.1150
# Epoch 220/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0866 - val_loss: -1.1156
# Epoch 221/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.0980 - val_loss: -1.1161
# Epoch 222/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0848 - val_loss: -1.1167
# Epoch 223/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0856 - val_loss: -1.1172
# Epoch 224/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0839 - val_loss: -1.1177
# Epoch 225/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0905 - val_loss: -1.1183
# Epoch 226/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.0824 - val_loss: -1.1189
# Epoch 227/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0910 - val_loss: -1.1195
# Epoch 228/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0993 - val_loss: -1.1200
# Epoch 229/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0816 - val_loss: -1.1205
# Epoch 230/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0954 - val_loss: -1.1211
# Epoch 231/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0971 - val_loss: -1.1217
# Epoch 232/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1047 - val_loss: -1.1222
# Epoch 233/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0893 - val_loss: -1.1228
# Epoch 234/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0829 - val_loss: -1.1234
# Epoch 235/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0771 - val_loss: -1.1238
# Epoch 236/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0973 - val_loss: -1.1245
# Epoch 237/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0981 - val_loss: -1.1250
# Epoch 238/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1124 - val_loss: -1.1255
# Epoch 239/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.0952 - val_loss: -1.1261
# Epoch 240/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1065 - val_loss: -1.1267
# Epoch 241/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1205 - val_loss: -1.1273
# Epoch 242/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1148 - val_loss: -1.1279
# Epoch 243/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1076 - val_loss: -1.1285
# Epoch 244/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1097 - val_loss: -1.1290
# Epoch 245/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1164 - val_loss: -1.1296
# Epoch 246/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1104 - val_loss: -1.1301
# Epoch 247/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1122 - val_loss: -1.1306
# Epoch 248/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1033 - val_loss: -1.1312
# Epoch 249/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.1517 - val_loss: -1.1318
# Epoch 250/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1118 - val_loss: -1.1323
# Epoch 251/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1158 - val_loss: -1.1329
# Epoch 252/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1528 - val_loss: -1.1334
# Epoch 253/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1356 - val_loss: -1.1340
# Epoch 254/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1305 - val_loss: -1.1346
# Epoch 255/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1081 - val_loss: -1.1351
# Epoch 256/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1441 - val_loss: -1.1358
# Epoch 257/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1238 - val_loss: -1.1363
# Epoch 258/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1133 - val_loss: -1.1369
# Epoch 259/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1275 - val_loss: -1.1374
# Epoch 260/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1312 - val_loss: -1.1380
# Epoch 261/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1197 - val_loss: -1.1385
# Epoch 262/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1288 - val_loss: -1.1391
# Epoch 263/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1328 - val_loss: -1.1397
# Epoch 264/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1129 - val_loss: -1.1402
# Epoch 265/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1239 - val_loss: -1.1409
# Epoch 266/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1440 - val_loss: -1.1414
# Epoch 267/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1202 - val_loss: -1.1420
# Epoch 268/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1192 - val_loss: -1.1424
# Epoch 269/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1297 - val_loss: -1.1431
# Epoch 270/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1287 - val_loss: -1.1437
# Epoch 271/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1391 - val_loss: -1.1441
# Epoch 272/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1196 - val_loss: -1.1447
# Epoch 273/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1321 - val_loss: -1.1453
# Epoch 274/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1241 - val_loss: -1.1459
# Epoch 275/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1230 - val_loss: -1.1464
# Epoch 276/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1342 - val_loss: -1.1471
# Epoch 277/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1535 - val_loss: -1.1476
# Epoch 278/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1613 - val_loss: -1.1482
# Epoch 279/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1359 - val_loss: -1.1487
# Epoch 280/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1537 - val_loss: -1.1493
# Epoch 281/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1517 - val_loss: -1.1499
# Epoch 282/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1295 - val_loss: -1.1504
# Epoch 283/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1574 - val_loss: -1.1510
# Epoch 284/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1360 - val_loss: -1.1516
# Epoch 285/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1382 - val_loss: -1.1521
# Epoch 286/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1584 - val_loss: -1.1527
# Epoch 287/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1646 - val_loss: -1.1532
# Epoch 288/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1485 - val_loss: -1.1538
# Epoch 289/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1368 - val_loss: -1.1544
# Epoch 290/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1384 - val_loss: -1.1550
# Epoch 291/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1466 - val_loss: -1.1556
# Epoch 292/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1588 - val_loss: -1.1561
# Epoch 293/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1503 - val_loss: -1.1566
# Epoch 294/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1904 - val_loss: -1.1572
# Epoch 295/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1450 - val_loss: -1.1579
# Epoch 296/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1473 - val_loss: -1.1583
# Epoch 297/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1798 - val_loss: -1.1590
# Epoch 298/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1402 - val_loss: -1.1594
# Epoch 299/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1561 - val_loss: -1.1600
# Epoch 300/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1561 - val_loss: -1.1606
# Epoch 301/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1542 - val_loss: -1.1612
# Epoch 302/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1614 - val_loss: -1.1618
# Epoch 303/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1588 - val_loss: -1.1623
# Epoch 304/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1572 - val_loss: -1.1628
# Epoch 305/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1496 - val_loss: -1.1634
# Epoch 306/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1576 - val_loss: -1.1641
# Epoch 307/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1705 - val_loss: -1.1646
# Epoch 308/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1555 - val_loss: -1.1651
# Epoch 309/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1600 - val_loss: -1.1657
# Epoch 310/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1686 - val_loss: -1.1663
# Epoch 311/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1604 - val_loss: -1.1668
# Epoch 312/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1573 - val_loss: -1.1674
# Epoch 313/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1691 - val_loss: -1.1680
# Epoch 314/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1787 - val_loss: -1.1686
# Epoch 315/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1692 - val_loss: -1.1692
# Epoch 316/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1798 - val_loss: -1.1697
# Epoch 317/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1710 - val_loss: -1.1705
# Epoch 318/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1711 - val_loss: -1.1709
# Epoch 319/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1643 - val_loss: -1.1714
# Epoch 320/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1753 - val_loss: -1.1721
# Epoch 321/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1881 - val_loss: -1.1727
# Epoch 322/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1775 - val_loss: -1.1732
# Epoch 323/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1893 - val_loss: -1.1739
# Epoch 324/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1861 - val_loss: -1.1745
# Epoch 325/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1652 - val_loss: -1.1749
# Epoch 326/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2090 - val_loss: -1.1755
# Epoch 327/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1780 - val_loss: -1.1761
# Epoch 328/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1915 - val_loss: -1.1767
# Epoch 329/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1871 - val_loss: -1.1771
# Epoch 330/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1925 - val_loss: -1.1778
# Epoch 331/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2076 - val_loss: -1.1784
# Epoch 332/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1738 - val_loss: -1.1790
# Epoch 333/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1907 - val_loss: -1.1795
# Epoch 334/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2149 - val_loss: -1.1802
# Epoch 335/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2072 - val_loss: -1.1807
# Epoch 336/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1954 - val_loss: -1.1813
# Epoch 337/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1677 - val_loss: -1.1819
# Epoch 338/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2033 - val_loss: -1.1824
# Epoch 339/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1827 - val_loss: -1.1829
# Epoch 340/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2060 - val_loss: -1.1835
# Epoch 341/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2032 - val_loss: -1.1841
# Epoch 342/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1996 - val_loss: -1.1847
# Epoch 343/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1843 - val_loss: -1.1853
# Epoch 344/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2109 - val_loss: -1.1859
# Epoch 345/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1772 - val_loss: -1.1865
# Epoch 346/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2278 - val_loss: -1.1871
# Epoch 347/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1940 - val_loss: -1.1876
# Epoch 348/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1850 - val_loss: -1.1882
# Epoch 349/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2188 - val_loss: -1.1888
# Epoch 350/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2045 - val_loss: -1.1893
# Epoch 351/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2248 - val_loss: -1.1899
# Epoch 352/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2210 - val_loss: -1.1906
# Epoch 353/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2333 - val_loss: -1.1911
# Epoch 354/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2104 - val_loss: -1.1917
# Epoch 355/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2113 - val_loss: -1.1924
# Epoch 356/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.1935 - val_loss: -1.1929
# Epoch 357/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2270 - val_loss: -1.1935
# Epoch 358/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2030 - val_loss: -1.1940
# Epoch 359/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2005 - val_loss: -1.1946
# Epoch 360/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2017 - val_loss: -1.1952
# Epoch 361/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2282 - val_loss: -1.1958
# Epoch 362/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2255 - val_loss: -1.1963
# Epoch 363/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2233 - val_loss: -1.1970
# Epoch 364/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2013 - val_loss: -1.1975
# Epoch 365/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2214 - val_loss: -1.1982
# Epoch 366/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2152 - val_loss: -1.1988
# Epoch 367/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.1984 - val_loss: -1.1992
# Epoch 368/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2035 - val_loss: -1.1999
# Epoch 369/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2170 - val_loss: -1.2005
# Epoch 370/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2141 - val_loss: -1.2010
# Epoch 371/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2209 - val_loss: -1.2016
# Epoch 372/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2252 - val_loss: -1.2023
# Epoch 373/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2299 - val_loss: -1.2028
# Epoch 374/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2124 - val_loss: -1.2034
# Epoch 375/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2186 - val_loss: -1.2039
# Epoch 376/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2623 - val_loss: -1.2045
# Epoch 377/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2160 - val_loss: -1.2051
# Epoch 378/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2355 - val_loss: -1.2058
# Epoch 379/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2187 - val_loss: -1.2062
# Epoch 380/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2397 - val_loss: -1.2069
# Epoch 381/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2531 - val_loss: -1.2074
# Epoch 382/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2287 - val_loss: -1.2080
# Epoch 383/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2366 - val_loss: -1.2087
# Epoch 384/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2494 - val_loss: -1.2093
# Epoch 385/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2316 - val_loss: -1.2099
# Epoch 386/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2252 - val_loss: -1.2104
# Epoch 387/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2641 - val_loss: -1.2110
# Epoch 388/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2468 - val_loss: -1.2116
# Epoch 389/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2429 - val_loss: -1.2122
# Epoch 390/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2313 - val_loss: -1.2128
# Epoch 391/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2507 - val_loss: -1.2134
# Epoch 392/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2525 - val_loss: -1.2140
# Epoch 393/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2551 - val_loss: -1.2145
# Epoch 394/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2476 - val_loss: -1.2151
# Epoch 395/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2460 - val_loss: -1.2157
# Epoch 396/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2590 - val_loss: -1.2163
# Epoch 397/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2734 - val_loss: -1.2170
# Epoch 398/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2611 - val_loss: -1.2176
# Epoch 399/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2482 - val_loss: -1.2182
# Epoch 400/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2468 - val_loss: -1.2187
# Epoch 401/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2760 - val_loss: -1.2193
# Epoch 402/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2900 - val_loss: -1.2199
# Epoch 403/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2456 - val_loss: -1.2206
# Epoch 404/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2485 - val_loss: -1.2212
# Epoch 405/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2536 - val_loss: -1.2218
# Epoch 406/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2648 - val_loss: -1.2223
# Epoch 407/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2728 - val_loss: -1.2229
# Epoch 408/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2509 - val_loss: -1.2235
# Epoch 409/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2706 - val_loss: -1.2241
# Epoch 410/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2853 - val_loss: -1.2248
# Epoch 411/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2907 - val_loss: -1.2253
# Epoch 412/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2511 - val_loss: -1.2260
# Epoch 413/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2605 - val_loss: -1.2266
# Epoch 414/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2602 - val_loss: -1.2272
# Epoch 415/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2597 - val_loss: -1.2277
# Epoch 416/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2808 - val_loss: -1.2284
# Epoch 417/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2805 - val_loss: -1.2291
# Epoch 418/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2910 - val_loss: -1.2297
# Epoch 419/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2820 - val_loss: -1.2301
# Epoch 420/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2650 - val_loss: -1.2308
# Epoch 421/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2745 - val_loss: -1.2314
# Epoch 422/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2666 - val_loss: -1.2320
# Epoch 423/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2818 - val_loss: -1.2326
# Epoch 424/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2867 - val_loss: -1.2333
# Epoch 425/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2610 - val_loss: -1.2339
# Epoch 426/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2946 - val_loss: -1.2346
# Epoch 427/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2910 - val_loss: -1.2352
# Epoch 428/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2852 - val_loss: -1.2358
# Epoch 429/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2807 - val_loss: -1.2363
# Epoch 430/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2861 - val_loss: -1.2370
# Epoch 431/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2775 - val_loss: -1.2376
# Epoch 432/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2862 - val_loss: -1.2382
# Epoch 433/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2861 - val_loss: -1.2388
# Epoch 434/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2774 - val_loss: -1.2394
# Epoch 435/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2734 - val_loss: -1.2401
# Epoch 436/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2796 - val_loss: -1.2407
# Epoch 437/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.3306 - val_loss: -1.2414
# Epoch 438/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2793 - val_loss: -1.2419
# Epoch 439/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2828 - val_loss: -1.2425
# Epoch 440/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.3330 - val_loss: -1.2433
# Epoch 441/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2984 - val_loss: -1.2438
# Epoch 442/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.3076 - val_loss: -1.2445
# Epoch 443/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.3074 - val_loss: -1.2450
# Epoch 444/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2902 - val_loss: -1.2456
# Epoch 445/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.3224 - val_loss: -1.2463
# Epoch 446/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.3131 - val_loss: -1.2468
# Epoch 447/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.3123 - val_loss: -1.2475
# Epoch 448/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.3034 - val_loss: -1.2482
# Epoch 449/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.3217 - val_loss: -1.2487
# Epoch 450/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.2975 - val_loss: -1.2493
# Epoch 451/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.2859 - val_loss: -1.2500
# Epoch 452/1000
# ...
# Epoch 849/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7296 - val_loss: -1.5267
# Epoch 850/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7190 - val_loss: -1.5274
# Epoch 851/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7482 - val_loss: -1.5282
# Epoch 852/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7267 - val_loss: -1.5290
# Epoch 853/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7434 - val_loss: -1.5298
# Epoch 854/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7431 - val_loss: -1.5305
# Epoch 855/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7272 - val_loss: -1.5311
# Epoch 856/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7307 - val_loss: -1.5319
# Epoch 857/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7518 - val_loss: -1.5326
# Epoch 858/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7211 - val_loss: -1.5335
# Epoch 859/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7186 - val_loss: -1.5340
# Epoch 860/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7283 - val_loss: -1.5349
# Epoch 861/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7521 - val_loss: -1.5355
# Epoch 862/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7483 - val_loss: -1.5364
# Epoch 863/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7514 - val_loss: -1.5370
# Epoch 864/1000
# 28/28 [==============================] - 0s 13ms/step - loss: -0.7358 - val_loss: -1.5377
# Epoch 865/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7488 - val_loss: -1.5385
# Epoch 866/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7521 - val_loss: -1.5392
# Epoch 867/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7552 - val_loss: -1.5399
# Epoch 868/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7581 - val_loss: -1.5406
# Epoch 869/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7376 - val_loss: -1.5415
# Epoch 870/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7636 - val_loss: -1.5422
# Epoch 871/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7381 - val_loss: -1.5429
# Epoch 872/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7465 - val_loss: -1.5437
# Epoch 873/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.7311 - val_loss: -1.5444
# Epoch 874/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7552 - val_loss: -1.5451
# Epoch 875/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7292 - val_loss: -1.5458
# Epoch 876/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7469 - val_loss: -1.5465
# Epoch 877/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7645 - val_loss: -1.5472
# Epoch 878/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7614 - val_loss: -1.5480
# Epoch 879/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7549 - val_loss: -1.5487
# Epoch 880/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7576 - val_loss: -1.5493
# Epoch 881/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7522 - val_loss: -1.5501
# Epoch 882/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.7513 - val_loss: -1.5509
# Epoch 883/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7733 - val_loss: -1.5516
# Epoch 884/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7675 - val_loss: -1.5523
# Epoch 885/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.7516 - val_loss: -1.5529
# Epoch 886/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7642 - val_loss: -1.5537
# Epoch 887/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7584 - val_loss: -1.5544
# Epoch 888/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7593 - val_loss: -1.5551
# Epoch 889/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7739 - val_loss: -1.5558
# Epoch 890/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7699 - val_loss: -1.5566
# Epoch 891/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7665 - val_loss: -1.5573
# Epoch 892/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7675 - val_loss: -1.5580
# Epoch 893/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7742 - val_loss: -1.5587
# Epoch 894/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7655 - val_loss: -1.5594
# Epoch 895/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7873 - val_loss: -1.5601
# Epoch 896/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7836 - val_loss: -1.5609
# Epoch 897/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7806 - val_loss: -1.5615
# Epoch 898/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7630 - val_loss: -1.5622
# Epoch 899/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7602 - val_loss: -1.5630
# Epoch 900/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7990 - val_loss: -1.5637
# Epoch 901/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7908 - val_loss: -1.5644
# Epoch 902/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7745 - val_loss: -1.5652
# Epoch 903/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7873 - val_loss: -1.5659
# Epoch 904/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7782 - val_loss: -1.5665
# Epoch 905/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7706 - val_loss: -1.5671
# Epoch 906/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8007 - val_loss: -1.5680
# Epoch 907/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7722 - val_loss: -1.5686
# Epoch 908/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7939 - val_loss: -1.5694
# Epoch 909/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7885 - val_loss: -1.5701
# Epoch 910/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7728 - val_loss: -1.5708
# Epoch 911/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7907 - val_loss: -1.5714
# Epoch 912/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7637 - val_loss: -1.5722
# Epoch 913/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8046 - val_loss: -1.5729
# Epoch 914/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7935 - val_loss: -1.5737
# Epoch 915/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7868 - val_loss: -1.5742
# Epoch 916/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8045 - val_loss: -1.5750
# Epoch 917/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7902 - val_loss: -1.5756
# Epoch 918/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8080 - val_loss: -1.5762
# Epoch 919/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8217 - val_loss: -1.5770
# Epoch 920/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7783 - val_loss: -1.5778
# Epoch 921/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7954 - val_loss: -1.5784
# Epoch 922/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7899 - val_loss: -1.5791
# Epoch 923/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7906 - val_loss: -1.5798
# Epoch 924/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7870 - val_loss: -1.5805
# Epoch 925/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7993 - val_loss: -1.5812
# Epoch 926/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8032 - val_loss: -1.5819
# Epoch 927/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8215 - val_loss: -1.5825
# Epoch 928/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.7993 - val_loss: -1.5833
# Epoch 929/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8347 - val_loss: -1.5839
# Epoch 930/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8146 - val_loss: -1.5847
# Epoch 931/1000
# 28/28 [==============================] - 0s 13ms/step - loss: -0.8088 - val_loss: -1.5853
# Epoch 932/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8362 - val_loss: -1.5860
# Epoch 933/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.7991 - val_loss: -1.5868
# Epoch 934/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8220 - val_loss: -1.5873
# Epoch 935/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8075 - val_loss: -1.5880
# Epoch 936/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8160 - val_loss: -1.5887
# Epoch 937/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8156 - val_loss: -1.5894
# Epoch 938/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8284 - val_loss: -1.5901
# Epoch 939/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8169 - val_loss: -1.5908
# Epoch 940/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8390 - val_loss: -1.5914
# Epoch 941/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8449 - val_loss: -1.5921
# Epoch 942/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8214 - val_loss: -1.5927
# Epoch 943/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8209 - val_loss: -1.5934
# Epoch 944/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8268 - val_loss: -1.5942
# Epoch 945/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8310 - val_loss: -1.5948
# Epoch 946/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8432 - val_loss: -1.5955
# Epoch 947/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8448 - val_loss: -1.5961
# Epoch 948/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8492 - val_loss: -1.5968
# Epoch 949/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8415 - val_loss: -1.5975
# Epoch 950/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8387 - val_loss: -1.5982
# Epoch 951/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8615 - val_loss: -1.5988
# Epoch 952/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8502 - val_loss: -1.5995
# Epoch 953/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8421 - val_loss: -1.6001
# Epoch 954/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8384 - val_loss: -1.6007
# Epoch 955/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8402 - val_loss: -1.6014
# Epoch 956/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8391 - val_loss: -1.6021
# Epoch 957/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8205 - val_loss: -1.6027
# Epoch 958/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8237 - val_loss: -1.6035
# Epoch 959/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8420 - val_loss: -1.6040
# Epoch 960/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8359 - val_loss: -1.6047
# Epoch 961/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8705 - val_loss: -1.6053
# Epoch 962/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8382 - val_loss: -1.6059
# Epoch 963/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8548 - val_loss: -1.6067
# Epoch 964/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8356 - val_loss: -1.6073
# Epoch 965/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8504 - val_loss: -1.6080
# Epoch 966/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8618 - val_loss: -1.6086
# Epoch 967/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8389 - val_loss: -1.6092
# Epoch 968/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8525 - val_loss: -1.6100
# Epoch 969/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8656 - val_loss: -1.6105
# Epoch 970/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8525 - val_loss: -1.6112
# Epoch 971/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8502 - val_loss: -1.6118
# Epoch 972/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8642 - val_loss: -1.6124
# Epoch 973/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8528 - val_loss: -1.6131
# Epoch 974/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8489 - val_loss: -1.6138
# Epoch 975/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8945 - val_loss: -1.6144
# Epoch 976/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8551 - val_loss: -1.6150
# Epoch 977/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8887 - val_loss: -1.6157
# Epoch 978/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8606 - val_loss: -1.6163
# Epoch 979/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8628 - val_loss: -1.6169
# Epoch 980/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8520 - val_loss: -1.6176
# Epoch 981/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8595 - val_loss: -1.6182
# Epoch 982/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8699 - val_loss: -1.6189
# Epoch 983/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8717 - val_loss: -1.6195
# Epoch 984/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8756 - val_loss: -1.6202
# Epoch 985/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8442 - val_loss: -1.6208
# Epoch 986/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8797 - val_loss: -1.6214
# Epoch 987/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8653 - val_loss: -1.6221
# Epoch 988/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8687 - val_loss: -1.6226
# Epoch 989/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8583 - val_loss: -1.6234
# Epoch 990/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.9084 - val_loss: -1.6239
# Epoch 991/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8977 - val_loss: -1.6246
# Epoch 992/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8789 - val_loss: -1.6253
# Epoch 993/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8974 - val_loss: -1.6258
# Epoch 994/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8813 - val_loss: -1.6264
# Epoch 995/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8911 - val_loss: -1.6271
# Epoch 996/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8859 - val_loss: -1.6277
# Epoch 997/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8886 - val_loss: -1.6283
# Epoch 998/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.8888 - val_loss: -1.6290
# Epoch 999/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -0.8839 - val_loss: -1.6296
# Epoch 1000/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -0.9164 - val_loss: -1.6302

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value[:8], 
                        'lstm_markowitz':lstm_value[:8]
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 20), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# 포트폴리오 수익률 (연간):
# crp_rtn      0.068131
# lstm_rtn     0.100836
# sp500_rtn   -0.204279
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.019841
# lstm_rtn     0.019060
# sp500_rtn    0.023718
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      3.433920
# lstm_rtn     5.290482
# sp500_rtn   -8.612955
# dtype: float64

# %%
perf_df
# Out:
#                      crp  lstm_markowitz         kospi
# Date
# 2021-09-29  10000.000000    10000.000000  10000.000000
# 2021-10-27  10310.533712    10358.994007   9886.349802
# 2021-11-24  10300.712422    10351.932298   9784.398174
# 2021-12-22  10218.589872    10332.594173   9752.341988
# 2022-01-19  10114.197593    10265.198221   9287.677268
# 2022-02-16   9962.443141    10138.411163   8919.735560
# 2022-03-16  10056.164835    10263.072676   8689.527275
# 2022-04-13  10405.433940    10605.851342   8876.634980
