# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
rtn_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.000084 -0.000864 -0.001079  0.009819  0.030728  0.011425
# 2022-05-05  0.000000  0.000000  0.000000 -0.004196 -0.005292 -0.027030
# 2022-05-06  0.000109  0.001001 -0.012424  0.001961  0.001061 -0.011940
# 2022-05-09  0.000202  0.002147  0.000000 -0.014940 -0.046284 -0.045043
# 2022-05-10  0.000063  0.000674 -0.018298 -0.008557 -0.005939 -0.018388
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2022-05-04  0.014217
# 2022-05-05 -0.033019
# 2022-05-06 -0.016993
# 2022-05-09 -0.040948
# 2022-05-10 -0.002740
#
# [4197 rows x 7 columns]

# %% [markdown]
# # 하락장 예측 train, test
#
# <pre>
#
# 하락장 : 2020-02-26 ~ 2020-04-06
# 상승장 : 2020-04-06 ~ 2020-06-26
# 1. MACD 하락 - 상승 : 2020-02-26 ~ 2020-06-26
# 2. 종가 하락 - 상승 : 2020-02-26 ~ 2020-06-05

# %%
rtn_df_train=rtn_df.loc[:'2019-10-31'] # Train set
rtn_df_test=rtn_df.loc['2021-06-05':]  # Test set

# %%
rtn_df_train
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2019-10-25  0.000004 -0.001182  0.001069  0.002085  0.005782 -0.008568
# 2019-10-28  0.000081 -0.002041  0.002731 -0.009069 -0.003851 -0.006074
# 2019-10-29  0.000023  0.001165 -0.000435 -0.003510 -0.001931  0.006074
# 2019-10-30  0.000061  0.000579 -0.005953  0.007008 -0.006464  0.003605
# 2019-10-31  0.000025  0.000157  0.001542  0.009729 -0.005854 -0.001801
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2019-10-25 -0.025676
# 2019-10-28  0.003043
# 2019-10-29 -0.000912
# 2019-10-30  0.014293
# 2019-10-31 -0.002902
#
# [3543 rows x 7 columns]

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960/
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100


N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.03
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     #callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 7)                 420
#
#  dense_7 (Dense)             (None, 7)                 56
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 55/55 [==============================] - 2s 14ms/step - loss: -0.0131 - val_loss: -0.8160
# Epoch 2/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0105 - val_loss: -0.8157
# Epoch 3/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0102 - val_loss: -0.8154
# Epoch 4/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0157 - val_loss: -0.8151
# Epoch 5/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0220 - val_loss: -0.8149
# Epoch 6/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0195 - val_loss: -0.8146
# Epoch 7/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0339 - val_loss: -0.8144
# Epoch 8/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0203 - val_loss: -0.8141
# Epoch 9/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0235 - val_loss: -0.8139
# Epoch 10/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0290 - val_loss: -0.8135
# Epoch 11/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0326 - val_loss: -0.8133
# Epoch 12/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0238 - val_loss: -0.8131
# Epoch 13/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0398 - val_loss: -0.8127
# Epoch 14/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0339 - val_loss: -0.8125
# Epoch 15/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0408 - val_loss: -0.8121
# Epoch 16/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0347 - val_loss: -0.8119
# Epoch 17/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0446 - val_loss: -0.8117
# Epoch 18/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0524 - val_loss: -0.8115
# Epoch 19/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0404 - val_loss: -0.8112
# Epoch 20/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0598 - val_loss: -0.8109
# Epoch 21/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0433 - val_loss: -0.8106
# Epoch 22/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0589 - val_loss: -0.8103
# Epoch 23/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0480 - val_loss: -0.8101
# Epoch 24/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0608 - val_loss: -0.8099
# Epoch 25/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0496 - val_loss: -0.8095
# Epoch 26/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0587 - val_loss: -0.8093
# Epoch 27/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0587 - val_loss: -0.8089
# Epoch 28/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0637 - val_loss: -0.8087
# Epoch 29/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0651 - val_loss: -0.8084
# Epoch 30/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0624 - val_loss: -0.8081
# Epoch 31/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0672 - val_loss: -0.8079
# Epoch 32/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0625 - val_loss: -0.8075
# Epoch 33/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0661 - val_loss: -0.8073
# Epoch 34/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0688 - val_loss: -0.8069
# Epoch 35/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0713 - val_loss: -0.8067
# Epoch 36/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0756 - val_loss: -0.8064
# Epoch 37/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0820 - val_loss: -0.8061
# Epoch 38/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0740 - val_loss: -0.8058
# Epoch 39/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0794 - val_loss: -0.8054
# Epoch 40/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0906 - val_loss: -0.8052
# Epoch 41/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0838 - val_loss: -0.8050
# Epoch 42/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.0951 - val_loss: -0.8047
# Epoch 43/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0832 - val_loss: -0.8044
# Epoch 44/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0987 - val_loss: -0.8040
# Epoch 45/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0917 - val_loss: -0.8038
# Epoch 46/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0876 - val_loss: -0.8034
# Epoch 47/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0990 - val_loss: -0.8032
# Epoch 48/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0977 - val_loss: -0.8029
# Epoch 49/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.0915 - val_loss: -0.8026
# Epoch 50/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1085 - val_loss: -0.8023
# Epoch 51/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1048 - val_loss: -0.8020
# Epoch 52/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1052 - val_loss: -0.8017
# Epoch 53/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1016 - val_loss: -0.8015
# Epoch 54/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1038 - val_loss: -0.8010
# Epoch 55/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1101 - val_loss: -0.8008
# Epoch 56/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1156 - val_loss: -0.8006
# Epoch 57/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1132 - val_loss: -0.8002
# Epoch 58/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1189 - val_loss: -0.7999
# Epoch 59/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1133 - val_loss: -0.7997
# Epoch 60/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1193 - val_loss: -0.7993
# Epoch 61/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1210 - val_loss: -0.7990
# Epoch 62/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1193 - val_loss: -0.7987
# Epoch 63/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1216 - val_loss: -0.7985
# Epoch 64/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1236 - val_loss: -0.7981
# Epoch 65/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1279 - val_loss: -0.7978
# Epoch 66/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1384 - val_loss: -0.7975
# Epoch 67/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1259 - val_loss: -0.7972
# Epoch 68/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1360 - val_loss: -0.7969
# Epoch 69/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1254 - val_loss: -0.7966
# Epoch 70/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1341 - val_loss: -0.7963
# Epoch 71/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1322 - val_loss: -0.7960
# Epoch 72/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1363 - val_loss: -0.7956
# Epoch 73/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1375 - val_loss: -0.7953
# Epoch 74/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1507 - val_loss: -0.7951
# Epoch 75/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1401 - val_loss: -0.7947
# Epoch 76/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1457 - val_loss: -0.7944
# Epoch 77/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1473 - val_loss: -0.7941
# Epoch 78/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1526 - val_loss: -0.7938
# Epoch 79/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1571 - val_loss: -0.7936
# Epoch 80/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1504 - val_loss: -0.7932
# Epoch 81/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1529 - val_loss: -0.7930
# Epoch 82/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1572 - val_loss: -0.7926
# Epoch 83/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1535 - val_loss: -0.7922
# Epoch 84/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1526 - val_loss: -0.7920
# Epoch 85/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1630 - val_loss: -0.7917
# Epoch 86/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1561 - val_loss: -0.7914
# Epoch 87/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1584 - val_loss: -0.7911
# Epoch 88/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1691 - val_loss: -0.7907
# Epoch 89/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1793 - val_loss: -0.7904
# Epoch 90/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1867 - val_loss: -0.7901
# Epoch 91/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1776 - val_loss: -0.7898
# Epoch 92/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1679 - val_loss: -0.7894
# Epoch 93/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1693 - val_loss: -0.7892
# Epoch 94/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1751 - val_loss: -0.7889
# Epoch 95/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1820 - val_loss: -0.7885
# Epoch 96/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1774 - val_loss: -0.7882
# Epoch 97/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1837 - val_loss: -0.7879
# Epoch 98/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1869 - val_loss: -0.7875
# Epoch 99/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1846 - val_loss: -0.7872
# Epoch 100/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1955 - val_loss: -0.7870
# Epoch 101/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1880 - val_loss: -0.7865
# Epoch 102/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1847 - val_loss: -0.7863
# Epoch 103/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1923 - val_loss: -0.7860
# Epoch 104/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1913 - val_loss: -0.7857
# Epoch 105/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.1901 - val_loss: -0.7853
# Epoch 106/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1966 - val_loss: -0.7851
# Epoch 107/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2080 - val_loss: -0.7847
# Epoch 108/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2092 - val_loss: -0.7844
# Epoch 109/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.1997 - val_loss: -0.7840
# Epoch 110/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2025 - val_loss: -0.7837
# Epoch 111/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2066 - val_loss: -0.7833
# Epoch 112/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2111 - val_loss: -0.7830
# Epoch 113/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2142 - val_loss: -0.7826
# Epoch 114/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2109 - val_loss: -0.7823
# Epoch 115/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2072 - val_loss: -0.7821
# Epoch 116/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2164 - val_loss: -0.7816
# Epoch 117/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2125 - val_loss: -0.7813
# Epoch 118/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2188 - val_loss: -0.7809
# Epoch 119/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2186 - val_loss: -0.7806
# Epoch 120/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2146 - val_loss: -0.7803
# Epoch 121/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2119 - val_loss: -0.7800
# Epoch 122/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2186 - val_loss: -0.7796
# Epoch 123/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2210 - val_loss: -0.7792
# Epoch 124/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2232 - val_loss: -0.7790
# Epoch 125/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2312 - val_loss: -0.7786
# Epoch 126/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2313 - val_loss: -0.7782
# Epoch 127/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2342 - val_loss: -0.7779
# Epoch 128/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2329 - val_loss: -0.7776
# Epoch 129/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2379 - val_loss: -0.7772
# Epoch 130/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2358 - val_loss: -0.7769
# Epoch 131/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2400 - val_loss: -0.7765
# Epoch 132/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2446 - val_loss: -0.7761
# Epoch 133/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2477 - val_loss: -0.7758
# Epoch 134/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2408 - val_loss: -0.7755
# Epoch 135/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2460 - val_loss: -0.7752
# Epoch 136/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2476 - val_loss: -0.7748
# Epoch 137/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2424 - val_loss: -0.7744
# Epoch 138/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2451 - val_loss: -0.7741
# Epoch 139/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2551 - val_loss: -0.7737
# Epoch 140/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2541 - val_loss: -0.7733
# Epoch 141/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2605 - val_loss: -0.7730
# Epoch 142/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2514 - val_loss: -0.7725
# Epoch 143/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2511 - val_loss: -0.7722
# Epoch 144/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2515 - val_loss: -0.7719
# Epoch 145/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2581 - val_loss: -0.7714
# Epoch 146/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2635 - val_loss: -0.7711
# Epoch 147/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2666 - val_loss: -0.7708
# Epoch 148/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2631 - val_loss: -0.7703
# Epoch 149/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2661 - val_loss: -0.7699
# Epoch 150/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2695 - val_loss: -0.7696
# Epoch 151/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2695 - val_loss: -0.7693
# Epoch 152/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2628 - val_loss: -0.7688
# Epoch 153/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2764 - val_loss: -0.7684
# Epoch 154/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2697 - val_loss: -0.7680
# Epoch 155/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2737 - val_loss: -0.7677
# Epoch 156/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2741 - val_loss: -0.7673
# Epoch 157/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2749 - val_loss: -0.7669
# Epoch 158/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2773 - val_loss: -0.7664
# Epoch 159/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2705 - val_loss: -0.7660
# Epoch 160/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2856 - val_loss: -0.7657
# Epoch 161/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2808 - val_loss: -0.7653
# Epoch 162/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2831 - val_loss: -0.7649
# Epoch 163/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2780 - val_loss: -0.7645
# Epoch 164/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2846 - val_loss: -0.7641
# Epoch 165/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2787 - val_loss: -0.7637
# Epoch 166/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2856 - val_loss: -0.7632
# Epoch 167/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2928 - val_loss: -0.7627
# Epoch 168/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2913 - val_loss: -0.7624
# Epoch 169/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3002 - val_loss: -0.7620
# Epoch 170/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2959 - val_loss: -0.7616
# Epoch 171/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2992 - val_loss: -0.7611
# Epoch 172/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.2992 - val_loss: -0.7607
# Epoch 173/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2926 - val_loss: -0.7602
# Epoch 174/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.2982 - val_loss: -0.7598
# Epoch 175/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3032 - val_loss: -0.7594
# Epoch 176/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3128 - val_loss: -0.7590
# Epoch 177/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3130 - val_loss: -0.7585
# Epoch 178/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3008 - val_loss: -0.7581
# Epoch 179/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3053 - val_loss: -0.7577
# Epoch 180/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3038 - val_loss: -0.7572
# Epoch 181/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3050 - val_loss: -0.7567
# Epoch 182/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3220 - val_loss: -0.7564
# Epoch 183/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3240 - val_loss: -0.7559
# Epoch 184/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3207 - val_loss: -0.7555
# Epoch 185/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3195 - val_loss: -0.7550
# Epoch 186/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3181 - val_loss: -0.7547
# Epoch 187/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3207 - val_loss: -0.7542
# Epoch 188/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3296 - val_loss: -0.7537
# Epoch 189/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3227 - val_loss: -0.7533
# Epoch 190/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3327 - val_loss: -0.7528
# Epoch 191/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3312 - val_loss: -0.7524
# Epoch 192/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3289 - val_loss: -0.7520
# Epoch 193/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3312 - val_loss: -0.7515
# Epoch 194/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3341 - val_loss: -0.7510
# Epoch 195/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3309 - val_loss: -0.7506
# Epoch 196/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3327 - val_loss: -0.7502
# Epoch 197/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3375 - val_loss: -0.7497
# Epoch 198/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3346 - val_loss: -0.7492
# Epoch 199/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3392 - val_loss: -0.7488
# Epoch 200/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3503 - val_loss: -0.7482
# Epoch 201/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3452 - val_loss: -0.7477
# Epoch 202/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3410 - val_loss: -0.7474
# Epoch 203/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3407 - val_loss: -0.7469
# Epoch 204/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3434 - val_loss: -0.7464
# Epoch 205/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3434 - val_loss: -0.7459
# Epoch 206/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3472 - val_loss: -0.7455
# Epoch 207/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3542 - val_loss: -0.7449
# Epoch 208/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3605 - val_loss: -0.7445
# Epoch 209/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3518 - val_loss: -0.7440
# Epoch 210/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3565 - val_loss: -0.7435
# Epoch 211/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3551 - val_loss: -0.7431
# Epoch 212/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3617 - val_loss: -0.7426
# Epoch 213/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3613 - val_loss: -0.7421
# Epoch 214/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3736 - val_loss: -0.7416
# Epoch 215/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3639 - val_loss: -0.7411
# Epoch 216/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3681 - val_loss: -0.7406
# Epoch 217/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3721 - val_loss: -0.7402
# Epoch 218/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3634 - val_loss: -0.7395
# Epoch 219/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3791 - val_loss: -0.7391
# Epoch 220/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3691 - val_loss: -0.7386
# Epoch 221/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3665 - val_loss: -0.7381
# Epoch 222/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3725 - val_loss: -0.7376
# Epoch 223/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3809 - val_loss: -0.7370
# Epoch 224/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3715 - val_loss: -0.7366
# Epoch 225/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3804 - val_loss: -0.7360
# Epoch 226/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3852 - val_loss: -0.7356
# Epoch 227/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3853 - val_loss: -0.7350
# Epoch 228/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3803 - val_loss: -0.7346
# Epoch 229/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3828 - val_loss: -0.7341
# Epoch 230/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3894 - val_loss: -0.7336
# Epoch 231/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3868 - val_loss: -0.7331
# Epoch 232/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3941 - val_loss: -0.7324
# Epoch 233/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3928 - val_loss: -0.7320
# Epoch 234/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3901 - val_loss: -0.7315
# Epoch 235/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3952 - val_loss: -0.7308
# Epoch 236/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3842 - val_loss: -0.7303
# Epoch 237/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3920 - val_loss: -0.7299
# Epoch 238/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3926 - val_loss: -0.7292
# Epoch 239/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.3963 - val_loss: -0.7288
# Epoch 240/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4044 - val_loss: -0.7283
# Epoch 241/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.3999 - val_loss: -0.7276
# Epoch 242/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4007 - val_loss: -0.7271
# Epoch 243/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4046 - val_loss: -0.7265
# Epoch 244/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4071 - val_loss: -0.7260
# Epoch 245/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4059 - val_loss: -0.7254
# Epoch 246/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4157 - val_loss: -0.7248
# Epoch 247/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4097 - val_loss: -0.7244
# Epoch 248/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4049 - val_loss: -0.7238
# Epoch 249/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4132 - val_loss: -0.7233
# Epoch 250/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4172 - val_loss: -0.7227
# Epoch 251/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4180 - val_loss: -0.7221
# Epoch 252/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4168 - val_loss: -0.7215
# Epoch 253/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4170 - val_loss: -0.7210
# Epoch 254/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4287 - val_loss: -0.7205
# Epoch 255/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4231 - val_loss: -0.7198
# Epoch 256/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4253 - val_loss: -0.7192
# Epoch 257/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4271 - val_loss: -0.7188
# Epoch 258/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4301 - val_loss: -0.7181
# Epoch 259/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4309 - val_loss: -0.7176
# Epoch 260/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4332 - val_loss: -0.7170
# Epoch 261/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4382 - val_loss: -0.7163
# Epoch 262/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4355 - val_loss: -0.7159
# Epoch 263/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4409 - val_loss: -0.7153
# Epoch 264/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4330 - val_loss: -0.7147
# Epoch 265/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4350 - val_loss: -0.7141
# Epoch 266/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4444 - val_loss: -0.7136
# Epoch 267/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4411 - val_loss: -0.7130
# Epoch 268/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4450 - val_loss: -0.7124
# Epoch 269/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4387 - val_loss: -0.7118
# Epoch 270/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4419 - val_loss: -0.7111
# Epoch 271/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4505 - val_loss: -0.7105
# Epoch 272/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4529 - val_loss: -0.7099
# Epoch 273/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4540 - val_loss: -0.7093
# Epoch 274/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4579 - val_loss: -0.7086
# Epoch 275/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4557 - val_loss: -0.7081
# Epoch 276/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4497 - val_loss: -0.7075
# Epoch 277/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4627 - val_loss: -0.7068
# Epoch 278/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4575 - val_loss: -0.7062
# Epoch 279/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4614 - val_loss: -0.7055
# Epoch 280/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4587 - val_loss: -0.7051
# Epoch 281/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4531 - val_loss: -0.7043
# Epoch 282/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4641 - val_loss: -0.7036
# Epoch 283/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4610 - val_loss: -0.7031
# Epoch 284/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4667 - val_loss: -0.7025
# Epoch 285/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4641 - val_loss: -0.7019
# Epoch 286/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4646 - val_loss: -0.7012
# Epoch 287/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4713 - val_loss: -0.7004
# Epoch 288/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4668 - val_loss: -0.6999
# Epoch 289/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4678 - val_loss: -0.6992
# Epoch 290/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4750 - val_loss: -0.6987
# Epoch 291/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4676 - val_loss: -0.6979
# Epoch 292/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4726 - val_loss: -0.6972
# Epoch 293/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4809 - val_loss: -0.6965
# Epoch 294/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4820 - val_loss: -0.6960
# Epoch 295/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4765 - val_loss: -0.6953
# Epoch 296/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4712 - val_loss: -0.6946
# Epoch 297/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4890 - val_loss: -0.6939
# Epoch 298/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4804 - val_loss: -0.6933
# Epoch 299/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4892 - val_loss: -0.6926
# Epoch 300/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4885 - val_loss: -0.6919
# Epoch 301/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4883 - val_loss: -0.6911
# Epoch 302/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4920 - val_loss: -0.6906
# Epoch 303/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4932 - val_loss: -0.6899
# Epoch 304/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4949 - val_loss: -0.6893
# Epoch 305/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.4905 - val_loss: -0.6885
# Epoch 306/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4944 - val_loss: -0.6879
# Epoch 307/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5104 - val_loss: -0.6872
# Epoch 308/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4913 - val_loss: -0.6866
# Epoch 309/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5050 - val_loss: -0.6858
# Epoch 310/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5090 - val_loss: -0.6850
# Epoch 311/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.4999 - val_loss: -0.6844
# Epoch 312/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5038 - val_loss: -0.6837
# Epoch 313/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5082 - val_loss: -0.6830
# Epoch 314/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5132 - val_loss: -0.6823
# Epoch 315/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5080 - val_loss: -0.6815
# Epoch 316/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5095 - val_loss: -0.6809
# Epoch 317/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5091 - val_loss: -0.6803
# Epoch 318/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5113 - val_loss: -0.6794
# Epoch 319/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5141 - val_loss: -0.6788
# Epoch 320/1000
# 55/55 [==============================] - 1s 13ms/step - loss: -0.5254 - val_loss: -0.6781
# Epoch 321/1000
# 55/55 [==============================] - 1s 10ms/step - loss: -0.5163 - val_loss: -0.6772
# Epoch 322/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5172 - val_loss: -0.6766
# Epoch 323/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5311 - val_loss: -0.6758
# Epoch 324/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5226 - val_loss: -0.6752
# Epoch 325/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5309 - val_loss: -0.6745
# Epoch 326/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5198 - val_loss: -0.6737
# Epoch 327/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5241 - val_loss: -0.6731
# Epoch 328/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5339 - val_loss: -0.6721
# Epoch 329/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5308 - val_loss: -0.6714
# Epoch 330/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5279 - val_loss: -0.6708
# Epoch 331/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5266 - val_loss: -0.6700
# Epoch 332/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5401 - val_loss: -0.6692
# Epoch 333/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5322 - val_loss: -0.6686
# Epoch 334/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5288 - val_loss: -0.6678
# Epoch 335/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5344 - val_loss: -0.6670
# Epoch 336/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5450 - val_loss: -0.6662
# Epoch 337/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5352 - val_loss: -0.6655
# Epoch 338/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5472 - val_loss: -0.6647
# Epoch 339/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5479 - val_loss: -0.6640
# Epoch 340/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5432 - val_loss: -0.6633
# Epoch 341/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5403 - val_loss: -0.6626
# Epoch 342/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5404 - val_loss: -0.6617
# Epoch 343/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5470 - val_loss: -0.6610
# Epoch 344/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5453 - val_loss: -0.6603
# Epoch 345/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5526 - val_loss: -0.6594
# Epoch 346/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5539 - val_loss: -0.6587
# Epoch 347/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5537 - val_loss: -0.6579
# Epoch 348/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5527 - val_loss: -0.6571
# Epoch 349/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5594 - val_loss: -0.6563
# Epoch 350/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5524 - val_loss: -0.6556
# Epoch 351/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5513 - val_loss: -0.6548
# Epoch 352/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.5532 - val_loss: -0.6539
# Epoch 353/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5573 - val_loss: -0.6532
# Epoch 354/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5581 - val_loss: -0.6524
# Epoch 355/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5602 - val_loss: -0.6516
# Epoch 356/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5679 - val_loss: -0.6508
# Epoch 357/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5627 - val_loss: -0.6501
# Epoch 358/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5694 - val_loss: -0.6492
# Epoch 359/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5677 - val_loss: -0.6483
# Epoch 360/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5672 - val_loss: -0.6476
# Epoch 361/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5744 - val_loss: -0.6468
# Epoch 362/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5662 - val_loss: -0.6460
# Epoch 363/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5741 - val_loss: -0.6453
# Epoch 364/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5700 - val_loss: -0.6444
# Epoch 365/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5720 - val_loss: -0.6436
# Epoch 366/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5769 - val_loss: -0.6427
# Epoch 367/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5866 - val_loss: -0.6420
# Epoch 368/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5766 - val_loss: -0.6411
# Epoch 369/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5801 - val_loss: -0.6404
# Epoch 370/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5858 - val_loss: -0.6394
# Epoch 371/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5838 - val_loss: -0.6386
# Epoch 372/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5911 - val_loss: -0.6379
# Epoch 373/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5893 - val_loss: -0.6370
# Epoch 374/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5810 - val_loss: -0.6362
# Epoch 375/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5874 - val_loss: -0.6355
# Epoch 376/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5880 - val_loss: -0.6345
# Epoch 377/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5940 - val_loss: -0.6337
# Epoch 378/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5938 - val_loss: -0.6329
# Epoch 379/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5937 - val_loss: -0.6321
# Epoch 380/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5941 - val_loss: -0.6312
# Epoch 381/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6000 - val_loss: -0.6302
# Epoch 382/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6019 - val_loss: -0.6296
# Epoch 383/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5999 - val_loss: -0.6287
# Epoch 384/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6008 - val_loss: -0.6279
# Epoch 385/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6029 - val_loss: -0.6271
# Epoch 386/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.5998 - val_loss: -0.6263
# Epoch 387/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6032 - val_loss: -0.6253
# Epoch 388/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6034 - val_loss: -0.6246
# Epoch 389/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6049 - val_loss: -0.6237
# Epoch 390/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6023 - val_loss: -0.6229
# Epoch 391/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6066 - val_loss: -0.6221
# Epoch 392/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6087 - val_loss: -0.6212
# Epoch 393/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6109 - val_loss: -0.6204
# Epoch 394/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6173 - val_loss: -0.6194
# Epoch 395/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6314 - val_loss: -0.6184
# Epoch 396/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6201 - val_loss: -0.6177
# Epoch 397/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6161 - val_loss: -0.6170
# Epoch 398/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6173 - val_loss: -0.6161
# Epoch 399/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6207 - val_loss: -0.6151
# Epoch 400/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6150 - val_loss: -0.6143
# Epoch 401/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6238 - val_loss: -0.6135
# Epoch 402/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6192 - val_loss: -0.6126
# Epoch 403/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6215 - val_loss: -0.6118
# Epoch 404/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6242 - val_loss: -0.6109
# Epoch 405/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6287 - val_loss: -0.6100
# Epoch 406/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6278 - val_loss: -0.6091
# Epoch 407/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6281 - val_loss: -0.6083
# Epoch 408/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6323 - val_loss: -0.6074
# Epoch 409/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6335 - val_loss: -0.6065
# Epoch 410/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6342 - val_loss: -0.6056
# Epoch 411/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6315 - val_loss: -0.6047
# Epoch 412/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6383 - val_loss: -0.6038
# Epoch 413/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6423 - val_loss: -0.6029
# Epoch 414/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6346 - val_loss: -0.6021
# Epoch 415/1000
# 55/55 [==============================] - 0s 5ms/step - loss: -0.6387 - val_loss: -0.6012
# Epoch 416/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6375 - val_loss: -0.6004
# Epoch 417/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6416 - val_loss: -0.5994
# Epoch 418/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6364 - val_loss: -0.5985
# Epoch 419/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6465 - val_loss: -0.5977
# Epoch 420/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6421 - val_loss: -0.5967
# Epoch 421/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6427 - val_loss: -0.5959
# Epoch 422/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6428 - val_loss: -0.5950
# Epoch 423/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6545 - val_loss: -0.5942
# Epoch 424/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6463 - val_loss: -0.5933
# Epoch 425/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6535 - val_loss: -0.5924
# Epoch 426/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6505 - val_loss: -0.5915
# Epoch 427/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6553 - val_loss: -0.5905
# Epoch 428/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6562 - val_loss: -0.5896
# Epoch 429/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6558 - val_loss: -0.5888
# Epoch 430/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6567 - val_loss: -0.5879
# Epoch 431/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6619 - val_loss: -0.5870
# Epoch 432/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6599 - val_loss: -0.5860
# Epoch 433/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6621 - val_loss: -0.5851
# Epoch 434/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6623 - val_loss: -0.5843
# Epoch 435/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6625 - val_loss: -0.5833
# Epoch 436/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6587 - val_loss: -0.5825
# Epoch 437/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6622 - val_loss: -0.5815
# Epoch 438/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6654 - val_loss: -0.5805
# Epoch 439/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6663 - val_loss: -0.5795
# Epoch 440/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6669 - val_loss: -0.5787
# Epoch 441/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6727 - val_loss: -0.5778
# Epoch 442/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6712 - val_loss: -0.5769
# Epoch 443/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6690 - val_loss: -0.5760
# Epoch 444/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6782 - val_loss: -0.5750
# Epoch 445/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6806 - val_loss: -0.5741
# Epoch 446/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6767 - val_loss: -0.5733
# Epoch 447/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6849 - val_loss: -0.5722
# Epoch 448/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6759 - val_loss: -0.5714
# Epoch 449/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6754 - val_loss: -0.5705
# Epoch 450/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6756 - val_loss: -0.5695
# Epoch 451/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6889 - val_loss: -0.5687
# Epoch 452/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6872 - val_loss: -0.5677
# Epoch 453/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6822 - val_loss: -0.5668
# Epoch 454/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -0.6831 - val_loss: -0.5659
# Epoch 455/1000
# ...
# Epoch 848/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0045 - val_loss: -0.2785
# Epoch 849/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0085 - val_loss: -0.2780
# Epoch 850/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0058 - val_loss: -0.2776
# Epoch 851/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0052 - val_loss: -0.2770
# Epoch 852/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0084 - val_loss: -0.2764
# Epoch 853/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0019 - val_loss: -0.2760
# Epoch 854/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0079 - val_loss: -0.2755
# Epoch 855/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0051 - val_loss: -0.2749
# Epoch 856/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0080 - val_loss: -0.2745
# Epoch 857/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0071 - val_loss: -0.2741
# Epoch 858/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0133 - val_loss: -0.2736
# Epoch 859/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0155 - val_loss: -0.2730
# Epoch 860/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0159 - val_loss: -0.2726
# Epoch 861/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0145 - val_loss: -0.2721
# Epoch 862/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0132 - val_loss: -0.2716
# Epoch 863/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0090 - val_loss: -0.2710
# Epoch 864/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0160 - val_loss: -0.2704
# Epoch 865/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0118 - val_loss: -0.2702
# Epoch 866/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0123 - val_loss: -0.2696
# Epoch 867/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0175 - val_loss: -0.2691
# Epoch 868/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0169 - val_loss: -0.2685
# Epoch 869/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0216 - val_loss: -0.2682
# Epoch 870/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0150 - val_loss: -0.2676
# Epoch 871/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0206 - val_loss: -0.2671
# Epoch 872/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0223 - val_loss: -0.2666
# Epoch 873/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0198 - val_loss: -0.2661
# Epoch 874/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0194 - val_loss: -0.2656
# Epoch 875/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0204 - val_loss: -0.2653
# Epoch 876/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0266 - val_loss: -0.2646
# Epoch 877/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0213 - val_loss: -0.2642
# Epoch 878/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0210 - val_loss: -0.2637
# Epoch 879/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0243 - val_loss: -0.2633
# Epoch 880/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0267 - val_loss: -0.2629
# Epoch 881/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0283 - val_loss: -0.2625
# Epoch 882/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0259 - val_loss: -0.2618
# Epoch 883/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0262 - val_loss: -0.2614
# Epoch 884/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0292 - val_loss: -0.2609
# Epoch 885/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0271 - val_loss: -0.2606
# Epoch 886/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0266 - val_loss: -0.2599
# Epoch 887/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0339 - val_loss: -0.2596
# Epoch 888/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0325 - val_loss: -0.2590
# Epoch 889/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0327 - val_loss: -0.2586
# Epoch 890/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0308 - val_loss: -0.2582
# Epoch 891/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0403 - val_loss: -0.2575
# Epoch 892/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0349 - val_loss: -0.2572
# Epoch 893/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0306 - val_loss: -0.2566
# Epoch 894/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0347 - val_loss: -0.2562
# Epoch 895/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0396 - val_loss: -0.2559
# Epoch 896/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0392 - val_loss: -0.2554
# Epoch 897/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0408 - val_loss: -0.2550
# Epoch 898/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0369 - val_loss: -0.2544
# Epoch 899/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0415 - val_loss: -0.2538
# Epoch 900/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0422 - val_loss: -0.2533
# Epoch 901/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0450 - val_loss: -0.2531
# Epoch 902/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0437 - val_loss: -0.2525
# Epoch 903/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0400 - val_loss: -0.2523
# Epoch 904/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0468 - val_loss: -0.2516
# Epoch 905/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0418 - val_loss: -0.2512
# Epoch 906/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0427 - val_loss: -0.2508
# Epoch 907/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0473 - val_loss: -0.2504
# Epoch 908/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0474 - val_loss: -0.2499
# Epoch 909/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0494 - val_loss: -0.2494
# Epoch 910/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0479 - val_loss: -0.2489
# Epoch 911/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0504 - val_loss: -0.2486
# Epoch 912/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0529 - val_loss: -0.2479
# Epoch 913/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0485 - val_loss: -0.2476
# Epoch 914/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0451 - val_loss: -0.2472
# Epoch 915/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0547 - val_loss: -0.2466
# Epoch 916/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0492 - val_loss: -0.2462
# Epoch 917/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0482 - val_loss: -0.2457
# Epoch 918/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0581 - val_loss: -0.2453
# Epoch 919/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0564 - val_loss: -0.2448
# Epoch 920/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0547 - val_loss: -0.2445
# Epoch 921/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0561 - val_loss: -0.2440
# Epoch 922/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0544 - val_loss: -0.2435
# Epoch 923/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0539 - val_loss: -0.2432
# Epoch 924/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0599 - val_loss: -0.2426
# Epoch 925/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0591 - val_loss: -0.2424
# Epoch 926/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0617 - val_loss: -0.2418
# Epoch 927/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0574 - val_loss: -0.2414
# Epoch 928/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0596 - val_loss: -0.2409
# Epoch 929/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0587 - val_loss: -0.2407
# Epoch 930/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0623 - val_loss: -0.2401
# Epoch 931/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0686 - val_loss: -0.2396
# Epoch 932/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0614 - val_loss: -0.2392
# Epoch 933/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0681 - val_loss: -0.2389
# Epoch 934/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0641 - val_loss: -0.2385
# Epoch 935/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0629 - val_loss: -0.2381
# Epoch 936/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0685 - val_loss: -0.2375
# Epoch 937/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0684 - val_loss: -0.2371
# Epoch 938/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0705 - val_loss: -0.2367
# Epoch 939/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0653 - val_loss: -0.2364
# Epoch 940/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0665 - val_loss: -0.2360
# Epoch 941/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0668 - val_loss: -0.2355
# Epoch 942/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0722 - val_loss: -0.2350
# Epoch 943/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0681 - val_loss: -0.2348
# Epoch 944/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0695 - val_loss: -0.2343
# Epoch 945/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0729 - val_loss: -0.2337
# Epoch 946/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0758 - val_loss: -0.2334
# Epoch 947/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0798 - val_loss: -0.2331
# Epoch 948/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0792 - val_loss: -0.2326
# Epoch 949/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0791 - val_loss: -0.2322
# Epoch 950/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0763 - val_loss: -0.2319
# Epoch 951/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0755 - val_loss: -0.2313
# Epoch 952/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0844 - val_loss: -0.2309
# Epoch 953/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0773 - val_loss: -0.2305
# Epoch 954/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0800 - val_loss: -0.2301
# Epoch 955/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0849 - val_loss: -0.2297
# Epoch 956/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0787 - val_loss: -0.2296
# Epoch 957/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0774 - val_loss: -0.2289
# Epoch 958/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0885 - val_loss: -0.2286
# Epoch 959/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0819 - val_loss: -0.2282
# Epoch 960/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0828 - val_loss: -0.2280
# Epoch 961/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0813 - val_loss: -0.2274
# Epoch 962/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0852 - val_loss: -0.2271
# Epoch 963/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0883 - val_loss: -0.2267
# Epoch 964/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0885 - val_loss: -0.2263
# Epoch 965/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0855 - val_loss: -0.2259
# Epoch 966/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0862 - val_loss: -0.2254
# Epoch 967/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0934 - val_loss: -0.2252
# Epoch 968/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0913 - val_loss: -0.2247
# Epoch 969/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0869 - val_loss: -0.2244
# Epoch 970/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0899 - val_loss: -0.2239
# Epoch 971/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0905 - val_loss: -0.2236
# Epoch 972/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0957 - val_loss: -0.2231
# Epoch 973/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0945 - val_loss: -0.2228
# Epoch 974/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0942 - val_loss: -0.2224
# Epoch 975/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0951 - val_loss: -0.2221
# Epoch 976/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0967 - val_loss: -0.2217
# Epoch 977/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0945 - val_loss: -0.2213
# Epoch 978/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0936 - val_loss: -0.2210
# Epoch 979/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0938 - val_loss: -0.2206
# Epoch 980/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0983 - val_loss: -0.2201
# Epoch 981/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0954 - val_loss: -0.2198
# Epoch 982/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.0979 - val_loss: -0.2195
# Epoch 983/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.0994 - val_loss: -0.2191
# Epoch 984/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1047 - val_loss: -0.2188
# Epoch 985/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1031 - val_loss: -0.2184
# Epoch 986/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1022 - val_loss: -0.2180
# Epoch 987/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1027 - val_loss: -0.2176
# Epoch 988/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1052 - val_loss: -0.2172
# Epoch 989/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1059 - val_loss: -0.2171
# Epoch 990/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1075 - val_loss: -0.2167
# Epoch 991/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1164 - val_loss: -0.2162
# Epoch 992/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1038 - val_loss: -0.2160
# Epoch 993/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1049 - val_loss: -0.2155
# Epoch 994/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1079 - val_loss: -0.2153
# Epoch 995/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1147 - val_loss: -0.2149
# Epoch 996/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1100 - val_loss: -0.2145
# Epoch 997/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1108 - val_loss: -0.2143
# Epoch 998/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1072 - val_loss: -0.2140
# Epoch 999/1000
# 55/55 [==============================] - 0s 7ms/step - loss: -1.1117 - val_loss: -0.2134
# Epoch 1000/1000
# 55/55 [==============================] - 0s 6ms/step - loss: -1.1105 - val_loss: -0.2132

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
##그래프저장
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 31), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 포트폴리오 수익률 (연간):
# crp_rtn      0.004927
# lstm_rtn    -0.001587
# sp500_rtn   -0.239320
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.018207
# lstm_rtn     0.012622
# sp500_rtn    0.021241
# dtype: float64
#
# Sharp Ratio :
# crp_rtn       0.270634
# lstm_rtn     -0.125764
# sp500_rtn   -11.267012
# dtype: float64

# %% [markdown]
# # 가중치 DF 저장 (일자별)

# %%
w_hist_lstm = []
for i in range(0, xc_test.shape[0]):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)

# %%
idx = np.arange(0, len(test_date))
date=test_date[idx]

# %%
W_df=pd.DataFrame(w_hist_lstm[:-1],columns=rtn_df.columns,index=list(date)[20:])
W_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 2021-08-02  0.086232  0.249424  0.080350  0.268618  0.057307  0.115192
# 2021-08-03  0.099804  0.249900  0.080354  0.264243  0.058430  0.110158
# 2021-08-04  0.091353  0.260038  0.082905  0.282459  0.055940  0.099721
# 2021-08-05  0.089763  0.271546  0.076260  0.291478  0.055062  0.096093
# 2021-08-06  0.106920  0.275985  0.078914  0.266981  0.060981  0.104067
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.140281  0.267101  0.073664  0.249858  0.058142  0.095118
# 2022-05-05  0.167653  0.273434  0.076131  0.210945  0.057537  0.095420
# 2022-05-06  0.266382  0.303207  0.066918  0.132260  0.058615  0.086674
# 2022-05-09  0.273865  0.288894  0.074588  0.123061  0.062262  0.090200
# 2022-05-10  0.283826  0.303801  0.074509  0.096021  0.064041  0.095103
#
#                nsd로그
# 2021-08-02  0.142877
# 2021-08-03  0.137109
# 2021-08-04  0.127583
# 2021-08-05  0.119797
# 2021-08-06  0.106151
# ...              ...
# 2022-05-04  0.115837
# 2022-05-05  0.118880
# 2022-05-06  0.085943
# 2022-05-09  0.087130
# 2022-05-10  0.082700
#
# [202 rows x 7 columns]

# %%
W_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/최근하락/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치(일자별).csv")

# %% [markdown]
# # 타 펀드 비교(KB)

# %%
kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
kb.일자=pd.to_datetime(kb.일자)
kb=kb.set_index('일자')
#일자설정
kb=kb.loc[perf_df.index[0]:perf_df.index[-1]]
kb['금액']=10000
kb['수익률(%)']=kb['수익률(%)']*0.01
for i in range(1,kb.shape[0]):
    kb.iloc[i,1]=kb.iloc[i,0]*kb.iloc[i-1,1]+kb.iloc[i-1,1]
p_df=perf_df.copy()
p_df=p_df.reset_index()
kb=kb.reset_index()
grp=pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')
grp=grp.set_index('Date')
grp=grp[['crp', 'lstm_markowitz', 'kospi', '금액']]
grp.columns=['crp', 'lstm_markowitz', 'kospi', 'KB펀드']
grp=grp.dropna()

# %% [markdown]
# # 타 펀드 비교 <미래에셋>

# %%
fa=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/미래에셋.csv")
fa=fa.T
fa=fa.iloc[1:]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
fa=fa.set_index('index')
fa.columns=['투자수익률','비교지수']
fa['미래에셋']=fa['투자수익률']*0.01*10000+10000
fa['미래에셋_pct']=fa['미래에셋'].pct_change(1)
#일자설정
fa=fa.loc[perf_df.index[0]:perf_df.index[-1]]
fa['미래에셋']=10000
for i in range(1,fa.shape[0]):
    fa.iloc[i,2]=fa.iloc[i,3]*fa.iloc[i-1,2]+fa.iloc[i-1,2]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
grp=pd.merge(grp.reset_index(),fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
grp=grp[['Date','lstm_markowitz','kospi','미래에셋','KB펀드']]
grp=grp.dropna()
grp=grp.set_index('Date')

# %% [markdown]
# # 차트 이미지 저장

# %%
p = grp.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12) 
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/최근하락/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49483 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
grp[grp['KB펀드']<grp['lstm_markowitz']]

# %%
grp[grp['KB펀드']>grp['lstm_markowitz']]
