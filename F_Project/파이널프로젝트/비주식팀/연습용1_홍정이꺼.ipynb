# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %% [markdown]
# # train, test 기간설정
#
# <pre>
# 뉴스심리지수 활용 구간 설정
# <상승기간> Train set
# '2006-07-31' : '2007-12-31'
# '2009-01-31' : '2010-02-29'
# '2010-07-31' : '2011-01-31'
# '2011-12-31' : '2012-05-01'
# '2012-10-31' : '2013-02-28'
# '2013-07-31' : '2014-01-31'
# '2014-04-30' : '2014-11-30'
# '2015-02-28' : '2015-06-30'
# '2017-01-31' : '2018-02-28'
# '2019-03-31' : '2019-06-30'
# '2019-10-31' : '2020-01-31'
# '2020-06-30' : '2021-08-31'
#
#
# <하락기간> Train set
# '2008-01-31' : '2008-12-31'
# '2010-03-31' : '2010-06-30'
# '2011-02-28' : '2011-11-30'
# '2012-06-30' : '2012-09-30'
# '2013-03-31' : '2013-06-30'
# '2014-02-28' : '2014-03-31'
# '2014-12-31' : '2015-01-31'
# '2015-07-31' : '2016-12-31'
# '2018-03-31' : '2019-02-28'
# '2019-07-31' : '2019-09-30'
# '2020-02-29' : '2020-04-30'
# '2021-09-30' : '2022-05-31'
#
#
# [Test Set]
# '2017-05-22' : '2022-05-22'

# %%
# 모델 # 상승모델이나 하강모델 넣기
rtn_df_train=rtn_df.loc[:'2017-05-21'] # Train set
rtn_df_test=rtn_df.loc['2017-05-22':]  # Test set

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960/
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
# up_2006=df.loc['2006-07-31' : '2007-12-31']
# up_2009=df.loc['2009-01-31' : '2010-02-26']
# up_2010=df.loc['2010-07-31' : '2011-01-31']
# up_2011=df.loc['2011-12-31' : '2012-05-01']
# up_2012=df.loc['2012-10-31' : '2013-02-28']
# up_2013=df.loc['2013-07-31' : '2014-01-31']
# up_2014=df.loc['2014-04-30' : '2014-11-30']
# up_2015=df.loc['2015-02-28' : '2015-06-30']
# up_2017=df.loc['2017-01-31' : '2018-02-28']
# up_2019=df.loc['2019-03-31' : '2019-06-30']
# up_2020=df.loc['2019-10-31' : '2020-01-31']
# up_2021=df.loc['2020-06-30' : '2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
# T = N_TIME + N_FUTURE
# x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

# for i in range(1, len(up_2006) - T + 1):
#     d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2009) - T + 1):
#     d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2010) - T + 1):
#     d = np.expand_dims(np.array(up_2010.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2011) - T + 1):
#     d = np.expand_dims(np.array(up_2011.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2012) - T + 1):
#     d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2013) - T + 1):
#     d = np.expand_dims(np.array(up_2013.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2014) - T + 1):
#     d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2015) - T + 1):
#     d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2017) - T + 1):
#     d = np.expand_dims(np.array(up_2017.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2019) - T + 1):
#     d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2020) - T + 1):
#     d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(up_2021) - T + 1):
#     d = np.expand_dims(np.array(up_2021.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ##  데이터셋 나눠서 만들기(하강)

# %%
down_2008=df.loc['2008-01-31':'2008-12-31']
down_2010=df.loc['2010-03-31':'2010-06-30']
down_2011=df.loc['2011-02-28':'2011-11-30']
down_2012=df.loc['2012-06-30':'2012-09-30']
down_2013=df.loc['2013-03-31':'2013-06-30']
down_2014=df.loc['2014-02-28':'2014-03-31']
down_2015=df.loc['2014-12-31':'2015-01-31']
down_2016=df.loc['2015-07-31':'2016-12-31']
down_2018=df.loc['2018-03-31':'2019-02-28']
down_2019=df.loc['2019-07-31':'2019-09-30']
down_2020=df.loc['2020-02-29':'2020-04-30']
down_2021=df.loc['2021-09-30':'2022-05-01']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(down_2008.iloc[0:T, :]), 0)

for i in range(1, len(down_2008) - T + 1):
    d = np.expand_dims(np.array(down_2008.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2010) - T + 1):
    d = np.expand_dims(np.array(down_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2011) - T + 1):
    d = np.expand_dims(np.array(down_2011.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2012) - T + 1):
    d = np.expand_dims(np.array(down_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2013) - T + 1):
    d = np.expand_dims(np.array(down_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2014) - T + 1):
    d = np.expand_dims(np.array(down_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2015) - T + 1):
    d = np.expand_dims(np.array(down_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2016) - T + 1):
    d = np.expand_dims(np.array(down_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2018) - T + 1):
    d = np.expand_dims(np.array(down_2018.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2019) - T + 1):
    d = np.expand_dims(np.array(down_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2020) - T + 1):
    d = np.expand_dims(np.array(down_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2021) - T + 1):
    d = np.expand_dims(np.array(down_2021.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ## rtn_train 구성하기

# %%
# rtn_train 값에 기간별로 자른 값 집어넣기
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100


N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.07
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     #callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 7)                 420
#
#  dense_7 (Dense)             (None, 7)                 56
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 18/18 [==============================] - 6s 105ms/step - loss: 4.7455 - val_loss: -0.6190
# Epoch 2/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.6662 - val_loss: -0.6194
# Epoch 3/1000
# 18/18 [==============================] - 0s 21ms/step - loss: 4.7123 - val_loss: -0.6198
# Epoch 4/1000
# 18/18 [==============================] - 0s 24ms/step - loss: 4.7350 - val_loss: -0.6202
# Epoch 5/1000
# 18/18 [==============================] - 0s 23ms/step - loss: 4.7279 - val_loss: -0.6207
# Epoch 6/1000
# 18/18 [==============================] - 0s 21ms/step - loss: 4.7225 - val_loss: -0.6211
# Epoch 7/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.7239 - val_loss: -0.6215
# Epoch 8/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.7348 - val_loss: -0.6219
# Epoch 9/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.6696 - val_loss: -0.6223
# Epoch 10/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.7210 - val_loss: -0.6227
# Epoch 11/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.7042 - val_loss: -0.6231
# Epoch 12/1000
# 18/18 [==============================] - 0s 23ms/step - loss: 4.7058 - val_loss: -0.6235
# Epoch 13/1000
# 18/18 [==============================] - 0s 24ms/step - loss: 4.7007 - val_loss: -0.6239
# Epoch 14/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.7019 - val_loss: -0.6243
# Epoch 15/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.7022 - val_loss: -0.6248
# Epoch 16/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6987 - val_loss: -0.6252
# Epoch 17/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6974 - val_loss: -0.6256
# Epoch 18/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6948 - val_loss: -0.6260
# Epoch 19/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6842 - val_loss: -0.6264
# Epoch 20/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.6945 - val_loss: -0.6268
# Epoch 21/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.6876 - val_loss: -0.6272
# Epoch 22/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6806 - val_loss: -0.6276
# Epoch 23/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6766 - val_loss: -0.6280
# Epoch 24/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6529 - val_loss: -0.6284
# Epoch 25/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6661 - val_loss: -0.6288
# Epoch 26/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.6740 - val_loss: -0.6293
# Epoch 27/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6613 - val_loss: -0.6297
# Epoch 28/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6620 - val_loss: -0.6301
# Epoch 29/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6604 - val_loss: -0.6305
# Epoch 30/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6619 - val_loss: -0.6309
# Epoch 31/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6468 - val_loss: -0.6313
# Epoch 32/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6397 - val_loss: -0.6317
# Epoch 33/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6438 - val_loss: -0.6321
# Epoch 34/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6431 - val_loss: -0.6325
# Epoch 35/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.6371 - val_loss: -0.6329
# Epoch 36/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.6280 - val_loss: -0.6333
# Epoch 37/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.6014 - val_loss: -0.6337
# Epoch 38/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6202 - val_loss: -0.6341
# Epoch 39/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.5610 - val_loss: -0.6345
# Epoch 40/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.6197 - val_loss: -0.6350
# Epoch 41/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.6134 - val_loss: -0.6354
# Epoch 42/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.6010 - val_loss: -0.6358
# Epoch 43/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.6134 - val_loss: -0.6362
# Epoch 44/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.6088 - val_loss: -0.6366
# Epoch 45/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.6155 - val_loss: -0.6370
# Epoch 46/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.6017 - val_loss: -0.6374
# Epoch 47/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5857 - val_loss: -0.6378
# Epoch 48/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.5922 - val_loss: -0.6382
# Epoch 49/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.5905 - val_loss: -0.6386
# Epoch 50/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.5311 - val_loss: -0.6390
# Epoch 51/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.5860 - val_loss: -0.6394
# Epoch 52/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5836 - val_loss: -0.6398
# Epoch 53/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5855 - val_loss: -0.6402
# Epoch 54/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.5805 - val_loss: -0.6406
# Epoch 55/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.5698 - val_loss: -0.6411
# Epoch 56/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5784 - val_loss: -0.6415
# Epoch 57/1000
# 18/18 [==============================] - 1s 36ms/step - loss: 4.5631 - val_loss: -0.6419
# Epoch 58/1000
# 18/18 [==============================] - 0s 23ms/step - loss: 4.5710 - val_loss: -0.6423
# Epoch 59/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5633 - val_loss: -0.6427
# Epoch 60/1000
# 18/18 [==============================] - 0s 22ms/step - loss: 4.5670 - val_loss: -0.6431
# Epoch 61/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 4.5511 - val_loss: -0.6435
# Epoch 62/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.5499 - val_loss: -0.6439
# Epoch 63/1000
# 18/18 [==============================] - 1s 30ms/step - loss: 4.5512 - val_loss: -0.6443
# Epoch 64/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5465 - val_loss: -0.6447
# Epoch 65/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5382 - val_loss: -0.6451
# Epoch 66/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5546 - val_loss: -0.6455
# Epoch 67/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5415 - val_loss: -0.6459
# Epoch 68/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.5428 - val_loss: -0.6463
# Epoch 69/1000
# 18/18 [==============================] - 0s 21ms/step - loss: 4.5484 - val_loss: -0.6467
# Epoch 70/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.5357 - val_loss: -0.6472
# Epoch 71/1000
# 18/18 [==============================] - 0s 23ms/step - loss: 4.5245 - val_loss: -0.6476
# Epoch 72/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.5377 - val_loss: -0.6480
# Epoch 73/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5239 - val_loss: -0.6484
# Epoch 74/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.5193 - val_loss: -0.6488
# Epoch 75/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5143 - val_loss: -0.6492
# Epoch 76/1000
# 18/18 [==============================] - 0s 20ms/step - loss: 4.5174 - val_loss: -0.6496
# Epoch 77/1000
# 18/18 [==============================] - 0s 22ms/step - loss: 4.5121 - val_loss: -0.6500
# Epoch 78/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.5133 - val_loss: -0.6504
# Epoch 79/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 4.4947 - val_loss: -0.6508
# Epoch 80/1000
# 18/18 [==============================] - 0s 19ms/step - loss: 4.5150 - val_loss: -0.6512
# Epoch 81/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.5011 - val_loss: -0.6516
# Epoch 82/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.4908 - val_loss: -0.6520
# Epoch 83/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4810 - val_loss: -0.6525
# Epoch 84/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4928 - val_loss: -0.6529
# Epoch 85/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 4.4778 - val_loss: -0.6533
# Epoch 86/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4770 - val_loss: -0.6537
# Epoch 87/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4826 - val_loss: -0.6541
# Epoch 88/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4784 - val_loss: -0.6545
# Epoch 89/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4778 - val_loss: -0.6549
# Epoch 90/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.4560 - val_loss: -0.6553
# Epoch 91/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4718 - val_loss: -0.6557
# Epoch 92/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4530 - val_loss: -0.6561
# Epoch 93/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4604 - val_loss: -0.6565
# Epoch 94/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4561 - val_loss: -0.6569
# Epoch 95/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4467 - val_loss: -0.6573
# Epoch 96/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4670 - val_loss: -0.6577
# Epoch 97/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4555 - val_loss: -0.6582
# Epoch 98/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4398 - val_loss: -0.6586
# Epoch 99/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4393 - val_loss: -0.6590
# Epoch 100/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4350 - val_loss: -0.6594
# Epoch 101/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4488 - val_loss: -0.6598
# Epoch 102/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4357 - val_loss: -0.6602
# Epoch 103/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4100 - val_loss: -0.6606
# Epoch 104/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4240 - val_loss: -0.6610
# Epoch 105/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4259 - val_loss: -0.6614
# Epoch 106/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4156 - val_loss: -0.6618
# Epoch 107/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4175 - val_loss: -0.6622
# Epoch 108/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3953 - val_loss: -0.6626
# Epoch 109/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.4103 - val_loss: -0.6630
# Epoch 110/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4169 - val_loss: -0.6634
# Epoch 111/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4047 - val_loss: -0.6638
# Epoch 112/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.4041 - val_loss: -0.6643
# Epoch 113/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3991 - val_loss: -0.6647
# Epoch 114/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3954 - val_loss: -0.6651
# Epoch 115/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3882 - val_loss: -0.6655
# Epoch 116/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.4099 - val_loss: -0.6659
# Epoch 117/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3896 - val_loss: -0.6663
# Epoch 118/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.3826 - val_loss: -0.6667
# Epoch 119/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3801 - val_loss: -0.6671
# Epoch 120/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3536 - val_loss: -0.6675
# Epoch 121/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3754 - val_loss: -0.6679
# Epoch 122/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3612 - val_loss: -0.6683
# Epoch 123/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3730 - val_loss: -0.6687
# Epoch 124/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3624 - val_loss: -0.6691
# Epoch 125/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3697 - val_loss: -0.6696
# Epoch 126/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3145 - val_loss: -0.6700
# Epoch 127/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3563 - val_loss: -0.6704
# Epoch 128/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3443 - val_loss: -0.6708
# Epoch 129/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3550 - val_loss: -0.6712
# Epoch 130/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.3534 - val_loss: -0.6716
# Epoch 131/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.3485 - val_loss: -0.6720
# Epoch 132/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.3218 - val_loss: -0.6724
# Epoch 133/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.3375 - val_loss: -0.6728
# Epoch 134/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3367 - val_loss: -0.6732
# Epoch 135/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3297 - val_loss: -0.6736
# Epoch 136/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.3126 - val_loss: -0.6740
# Epoch 137/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3234 - val_loss: -0.6744
# Epoch 138/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3201 - val_loss: -0.6748
# Epoch 139/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3135 - val_loss: -0.6752
# Epoch 140/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3150 - val_loss: -0.6757
# Epoch 141/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3020 - val_loss: -0.6761
# Epoch 142/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3214 - val_loss: -0.6765
# Epoch 143/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.3021 - val_loss: -0.6769
# Epoch 144/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3003 - val_loss: -0.6773
# Epoch 145/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3050 - val_loss: -0.6777
# Epoch 146/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.2981 - val_loss: -0.6781
# Epoch 147/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2912 - val_loss: -0.6785
# Epoch 148/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.3041 - val_loss: -0.6789
# Epoch 149/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2330 - val_loss: -0.6793
# Epoch 150/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.3002 - val_loss: -0.6797
# Epoch 151/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.2801 - val_loss: -0.6801
# Epoch 152/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.2845 - val_loss: -0.6805
# Epoch 153/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.2818 - val_loss: -0.6810
# Epoch 154/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2767 - val_loss: -0.6814
# Epoch 155/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.2666 - val_loss: -0.6818
# Epoch 156/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2852 - val_loss: -0.6822
# Epoch 157/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2697 - val_loss: -0.6826
# Epoch 158/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2539 - val_loss: -0.6830
# Epoch 159/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2642 - val_loss: -0.6834
# Epoch 160/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.2519 - val_loss: -0.6838
# Epoch 161/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2612 - val_loss: -0.6842
# Epoch 162/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2550 - val_loss: -0.6846
# Epoch 163/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.2070 - val_loss: -0.6850
# Epoch 164/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2501 - val_loss: -0.6854
# Epoch 165/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2330 - val_loss: -0.6858
# Epoch 166/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2495 - val_loss: -0.6863
# Epoch 167/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2361 - val_loss: -0.6867
# Epoch 168/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.2363 - val_loss: -0.6871
# Epoch 169/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.2262 - val_loss: -0.6875
# Epoch 170/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2092 - val_loss: -0.6879
# Epoch 171/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.2214 - val_loss: -0.6883
# Epoch 172/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.2216 - val_loss: -0.6887
# Epoch 173/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2087 - val_loss: -0.6891
# Epoch 174/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2066 - val_loss: -0.6895
# Epoch 175/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2146 - val_loss: -0.6899
# Epoch 176/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2163 - val_loss: -0.6903
# Epoch 177/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1964 - val_loss: -0.6907
# Epoch 178/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.2052 - val_loss: -0.6911
# Epoch 179/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1976 - val_loss: -0.6915
# Epoch 180/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1791 - val_loss: -0.6919
# Epoch 181/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.1896 - val_loss: -0.6923
# Epoch 182/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1827 - val_loss: -0.6928
# Epoch 183/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1959 - val_loss: -0.6932
# Epoch 184/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1890 - val_loss: -0.6936
# Epoch 185/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1887 - val_loss: -0.6940
# Epoch 186/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.1639 - val_loss: -0.6944
# Epoch 187/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1670 - val_loss: -0.6948
# Epoch 188/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1697 - val_loss: -0.6952
# Epoch 189/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1589 - val_loss: -0.6956
# Epoch 190/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1753 - val_loss: -0.6960
# Epoch 191/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1750 - val_loss: -0.6964
# Epoch 192/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1740 - val_loss: -0.6968
# Epoch 193/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1596 - val_loss: -0.6973
# Epoch 194/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1507 - val_loss: -0.6977
# Epoch 195/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1604 - val_loss: -0.6981
# Epoch 196/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1627 - val_loss: -0.6985
# Epoch 197/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.1410 - val_loss: -0.6989
# Epoch 198/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1386 - val_loss: -0.6993
# Epoch 199/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1491 - val_loss: -0.6997
# Epoch 200/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.1498 - val_loss: -0.7001
# Epoch 201/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.1363 - val_loss: -0.7005
# Epoch 202/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1310 - val_loss: -0.7009
# Epoch 203/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0569 - val_loss: -0.7013
# Epoch 204/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1222 - val_loss: -0.7017
# Epoch 205/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 4.0622 - val_loss: -0.7021
# Epoch 206/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1200 - val_loss: -0.7026
# Epoch 207/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 4.1131 - val_loss: -0.7030
# Epoch 208/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.1055 - val_loss: -0.7034
# Epoch 209/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.1148 - val_loss: -0.7038
# Epoch 210/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1041 - val_loss: -0.7042
# Epoch 211/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.1132 - val_loss: -0.7046
# Epoch 212/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1138 - val_loss: -0.7050
# Epoch 213/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0996 - val_loss: -0.7054
# Epoch 214/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0999 - val_loss: -0.7058
# Epoch 215/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0936 - val_loss: -0.7062
# Epoch 216/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0844 - val_loss: -0.7066
# Epoch 217/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0886 - val_loss: -0.7071
# Epoch 218/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0811 - val_loss: -0.7074
# Epoch 219/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0876 - val_loss: -0.7079
# Epoch 220/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.0824 - val_loss: -0.7083
# Epoch 221/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0122 - val_loss: -0.7087
# Epoch 222/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0809 - val_loss: -0.7091
# Epoch 223/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0697 - val_loss: -0.7095
# Epoch 224/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0583 - val_loss: -0.7099
# Epoch 225/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0538 - val_loss: -0.7103
# Epoch 226/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0644 - val_loss: -0.7107
# Epoch 227/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0573 - val_loss: -0.7111
# Epoch 228/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0440 - val_loss: -0.7115
# Epoch 229/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.0356 - val_loss: -0.7119
# Epoch 230/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0377 - val_loss: -0.7124
# Epoch 231/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0420 - val_loss: -0.7128
# Epoch 232/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0310 - val_loss: -0.7132
# Epoch 233/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 4.0423 - val_loss: -0.7136
# Epoch 234/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0324 - val_loss: -0.7140
# Epoch 235/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0284 - val_loss: -0.7144
# Epoch 236/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0428 - val_loss: -0.7148
# Epoch 237/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0229 - val_loss: -0.7152
# Epoch 238/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 4.0327 - val_loss: -0.7156
# Epoch 239/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 4.0207 - val_loss: -0.7160
# Epoch 240/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.0194 - val_loss: -0.7165
# Epoch 241/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0124 - val_loss: -0.7169
# Epoch 242/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 4.0171 - val_loss: -0.7173
# Epoch 243/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9923 - val_loss: -0.7177
# Epoch 244/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.9931 - val_loss: -0.7181
# Epoch 245/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 4.0052 - val_loss: -0.7185
# Epoch 246/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 4.0020 - val_loss: -0.7189
# Epoch 247/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9965 - val_loss: -0.7193
# Epoch 248/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9933 - val_loss: -0.7197
# Epoch 249/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 3.9894 - val_loss: -0.7201
# Epoch 250/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9932 - val_loss: -0.7205
# Epoch 251/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9839 - val_loss: -0.7209
# Epoch 252/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9743 - val_loss: -0.7213
# Epoch 253/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9840 - val_loss: -0.7217
# Epoch 254/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9722 - val_loss: -0.7221
# Epoch 255/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9726 - val_loss: -0.7226
# Epoch 256/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9780 - val_loss: -0.7230
# Epoch 257/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9512 - val_loss: -0.7234
# Epoch 258/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.9783 - val_loss: -0.7238
# Epoch 259/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9565 - val_loss: -0.7242
# Epoch 260/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.9472 - val_loss: -0.7246
# Epoch 261/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9522 - val_loss: -0.7250
# Epoch 262/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9637 - val_loss: -0.7254
# Epoch 263/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9522 - val_loss: -0.7258
# Epoch 264/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9408 - val_loss: -0.7262
# Epoch 265/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9249 - val_loss: -0.7267
# Epoch 266/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9322 - val_loss: -0.7271
# Epoch 267/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9390 - val_loss: -0.7275
# Epoch 268/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9363 - val_loss: -0.7279
# Epoch 269/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9405 - val_loss: -0.7283
# Epoch 270/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.9287 - val_loss: -0.7287
# Epoch 271/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9312 - val_loss: -0.7291
# Epoch 272/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9116 - val_loss: -0.7295
# Epoch 273/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.9248 - val_loss: -0.7299
# Epoch 274/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9169 - val_loss: -0.7303
# Epoch 275/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9043 - val_loss: -0.7308
# Epoch 276/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8945 - val_loss: -0.7312
# Epoch 277/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9173 - val_loss: -0.7316
# Epoch 278/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.9038 - val_loss: -0.7320
# Epoch 279/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9119 - val_loss: -0.7324
# Epoch 280/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.9059 - val_loss: -0.7328
# Epoch 281/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8892 - val_loss: -0.7332
# Epoch 282/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.8909 - val_loss: -0.7336
# Epoch 283/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8936 - val_loss: -0.7340
# Epoch 284/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8928 - val_loss: -0.7345
# Epoch 285/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8364 - val_loss: -0.7349
# Epoch 286/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8794 - val_loss: -0.7353
# Epoch 287/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8816 - val_loss: -0.7357
# Epoch 288/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8563 - val_loss: -0.7361
# Epoch 289/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.8644 - val_loss: -0.7365
# Epoch 290/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8674 - val_loss: -0.7369
# Epoch 291/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8693 - val_loss: -0.7373
# Epoch 292/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8609 - val_loss: -0.7377
# Epoch 293/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8656 - val_loss: -0.7381
# Epoch 294/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.8575 - val_loss: -0.7386
# Epoch 295/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8594 - val_loss: -0.7390
# Epoch 296/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8386 - val_loss: -0.7394
# Epoch 297/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8551 - val_loss: -0.7398
# Epoch 298/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8522 - val_loss: -0.7402
# Epoch 299/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8408 - val_loss: -0.7406
# Epoch 300/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8014 - val_loss: -0.7410
# Epoch 301/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8277 - val_loss: -0.7414
# Epoch 302/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8366 - val_loss: -0.7418
# Epoch 303/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8261 - val_loss: -0.7423
# Epoch 304/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8247 - val_loss: -0.7427
# Epoch 305/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8236 - val_loss: -0.7431
# Epoch 306/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8238 - val_loss: -0.7435
# Epoch 307/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 3.8228 - val_loss: -0.7439
# Epoch 308/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8197 - val_loss: -0.7443
# Epoch 309/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8155 - val_loss: -0.7447
# Epoch 310/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7491 - val_loss: -0.7451
# Epoch 311/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.8115 - val_loss: -0.7456
# Epoch 312/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7874 - val_loss: -0.7460
# Epoch 313/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8011 - val_loss: -0.7464
# Epoch 314/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.8072 - val_loss: -0.7468
# Epoch 315/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7811 - val_loss: -0.7472
# Epoch 316/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7932 - val_loss: -0.7477
# Epoch 317/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7370 - val_loss: -0.7481
# Epoch 318/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.7837 - val_loss: -0.7485
# Epoch 319/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7819 - val_loss: -0.7489
# Epoch 320/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.7856 - val_loss: -0.7493
# Epoch 321/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7766 - val_loss: -0.7497
# Epoch 322/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7729 - val_loss: -0.7501
# Epoch 323/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7610 - val_loss: -0.7506
# Epoch 324/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7649 - val_loss: -0.7510
# Epoch 325/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7650 - val_loss: -0.7514
# Epoch 326/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7681 - val_loss: -0.7518
# Epoch 327/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7422 - val_loss: -0.7522
# Epoch 328/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7684 - val_loss: -0.7526
# Epoch 329/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7363 - val_loss: -0.7531
# Epoch 330/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7531 - val_loss: -0.7535
# Epoch 331/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.7487 - val_loss: -0.7539
# Epoch 332/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.7523 - val_loss: -0.7543
# Epoch 333/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7484 - val_loss: -0.7547
# Epoch 334/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7370 - val_loss: -0.7552
# Epoch 335/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.7359 - val_loss: -0.7556
# Epoch 336/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7407 - val_loss: -0.7560
# Epoch 337/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7372 - val_loss: -0.7564
# Epoch 338/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.7341 - val_loss: -0.7568
# Epoch 339/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.7188 - val_loss: -0.7573
# Epoch 340/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7216 - val_loss: -0.7577
# Epoch 341/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7175 - val_loss: -0.7581
# Epoch 342/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 3.7118 - val_loss: -0.7585
# Epoch 343/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7140 - val_loss: -0.7589
# Epoch 344/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7121 - val_loss: -0.7593
# Epoch 345/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7049 - val_loss: -0.7597
# Epoch 346/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.7050 - val_loss: -0.7602
# Epoch 347/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.7045 - val_loss: -0.7606
# Epoch 348/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.7051 - val_loss: -0.7610
# Epoch 349/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6897 - val_loss: -0.7614
# Epoch 350/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.6911 - val_loss: -0.7618
# Epoch 351/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6897 - val_loss: -0.7623
# Epoch 352/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6924 - val_loss: -0.7627
# Epoch 353/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6771 - val_loss: -0.7631
# Epoch 354/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6912 - val_loss: -0.7635
# Epoch 355/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6829 - val_loss: -0.7640
# Epoch 356/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6592 - val_loss: -0.7644
# Epoch 357/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 3.6675 - val_loss: -0.7648
# Epoch 358/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6728 - val_loss: -0.7652
# Epoch 359/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6529 - val_loss: -0.7656
# Epoch 360/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6602 - val_loss: -0.7661
# Epoch 361/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 3.6483 - val_loss: -0.7665
# Epoch 362/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.5982 - val_loss: -0.7669
# Epoch 363/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6568 - val_loss: -0.7673
# Epoch 364/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6521 - val_loss: -0.7678
# Epoch 365/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.6522 - val_loss: -0.7682
# Epoch 366/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6495 - val_loss: -0.7686
# Epoch 367/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6568 - val_loss: -0.7690
# Epoch 368/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6450 - val_loss: -0.7694
# Epoch 369/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5846 - val_loss: -0.7699
# Epoch 370/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.6337 - val_loss: -0.7703
# Epoch 371/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6302 - val_loss: -0.7707
# Epoch 372/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6241 - val_loss: -0.7711
# Epoch 373/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6276 - val_loss: -0.7716
# Epoch 374/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6298 - val_loss: -0.7720
# Epoch 375/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6162 - val_loss: -0.7724
# Epoch 376/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.6177 - val_loss: -0.7728
# Epoch 377/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6116 - val_loss: -0.7733
# Epoch 378/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5731 - val_loss: -0.7737
# Epoch 379/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5955 - val_loss: -0.7741
# Epoch 380/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.6069 - val_loss: -0.7745
# Epoch 381/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6089 - val_loss: -0.7750
# Epoch 382/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5977 - val_loss: -0.7754
# Epoch 383/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.6011 - val_loss: -0.7758
# Epoch 384/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5993 - val_loss: -0.7762
# Epoch 385/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5990 - val_loss: -0.7767
# Epoch 386/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5860 - val_loss: -0.7771
# Epoch 387/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.5888 - val_loss: -0.7775
# Epoch 388/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.5724 - val_loss: -0.7779
# Epoch 389/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5914 - val_loss: -0.7784
# Epoch 390/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5827 - val_loss: -0.7788
# Epoch 391/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5777 - val_loss: -0.7792
# Epoch 392/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5691 - val_loss: -0.7796
# Epoch 393/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5703 - val_loss: -0.7801
# Epoch 394/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5693 - val_loss: -0.7805
# Epoch 395/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5591 - val_loss: -0.7809
# Epoch 396/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5551 - val_loss: -0.7814
# Epoch 397/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5561 - val_loss: -0.7818
# Epoch 398/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.5355 - val_loss: -0.7822
# Epoch 399/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5520 - val_loss: -0.7826
# Epoch 400/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5460 - val_loss: -0.7831
# Epoch 401/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5269 - val_loss: -0.7835
# Epoch 402/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5449 - val_loss: -0.7839
# Epoch 403/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5386 - val_loss: -0.7843
# Epoch 404/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5395 - val_loss: -0.7848
# Epoch 405/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.5294 - val_loss: -0.7852
# Epoch 406/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5285 - val_loss: -0.7856
# Epoch 407/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5138 - val_loss: -0.7861
# Epoch 408/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5165 - val_loss: -0.7865
# Epoch 409/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5230 - val_loss: -0.7869
# Epoch 410/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.5257 - val_loss: -0.7873
# Epoch 411/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 3.4975 - val_loss: -0.7878
# Epoch 412/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5105 - val_loss: -0.7882
# Epoch 413/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5182 - val_loss: -0.7886
# Epoch 414/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5092 - val_loss: -0.7891
# Epoch 415/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5061 - val_loss: -0.7895
# Epoch 416/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 3.4974 - val_loss: -0.7899
# Epoch 417/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.5025 - val_loss: -0.7903
# Epoch 418/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.4791 - val_loss: -0.7908
# Epoch 419/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.5000 - val_loss: -0.7912
# Epoch 420/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4835 - val_loss: -0.7916
# Epoch 421/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4817 - val_loss: -0.7921
# Epoch 422/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4847 - val_loss: -0.7925
# Epoch 423/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4707 - val_loss: -0.7929
# Epoch 424/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.4822 - val_loss: -0.7933
# Epoch 425/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4685 - val_loss: -0.7938
# Epoch 426/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4682 - val_loss: -0.7942
# Epoch 427/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4656 - val_loss: -0.7946
# Epoch 428/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4665 - val_loss: -0.7951
# Epoch 429/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4631 - val_loss: -0.7955
# Epoch 430/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4485 - val_loss: -0.7959
# Epoch 431/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4564 - val_loss: -0.7964
# Epoch 432/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4493 - val_loss: -0.7968
# Epoch 433/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.3846 - val_loss: -0.7972
# Epoch 434/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4496 - val_loss: -0.7976
# Epoch 435/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4326 - val_loss: -0.7981
# Epoch 436/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4320 - val_loss: -0.7985
# Epoch 437/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4339 - val_loss: -0.7989
# Epoch 438/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.4354 - val_loss: -0.7993
# Epoch 439/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4159 - val_loss: -0.7998
# Epoch 440/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.4110 - val_loss: -0.8002
# Epoch 441/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4245 - val_loss: -0.8006
# Epoch 442/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4223 - val_loss: -0.8011
# Epoch 443/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.4228 - val_loss: -0.8015
# Epoch 444/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.4163 - val_loss: -0.8019
# Epoch 445/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.4067 - val_loss: -0.8024
# Epoch 446/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4098 - val_loss: -0.8028
# Epoch 447/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 3.4066 - val_loss: -0.8032
# Epoch 448/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.4002 - val_loss: -0.8036
# Epoch 449/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.3995 - val_loss: -0.8041
# Epoch 450/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 3.3913 - val_loss: -0.8045
# Epoch 451/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.3939 - val_loss: -0.8049
# Epoch 452/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.3937 - val_loss: -0.8053
# Epoch 453/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 3.3931 - val_loss: -0.8058
# Epoch 454/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 3.3807 - val_loss: -0.8062
# Epoch 455/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 3.3814 - val_loss: -0.8066
# Epoch 456/1000
# ...
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1765 - val_loss: -0.9393
# Epoch 848/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1716 - val_loss: -0.9396
# Epoch 849/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1664 - val_loss: -0.9398
# Epoch 850/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 2.1620 - val_loss: -0.9400
# Epoch 851/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 2.1617 - val_loss: -0.9402
# Epoch 852/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1528 - val_loss: -0.9404
# Epoch 853/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1605 - val_loss: -0.9406
# Epoch 854/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1638 - val_loss: -0.9408
# Epoch 855/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1413 - val_loss: -0.9410
# Epoch 856/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1518 - val_loss: -0.9412
# Epoch 857/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 2.1452 - val_loss: -0.9414
# Epoch 858/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 2.1525 - val_loss: -0.9416
# Epoch 859/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1444 - val_loss: -0.9418
# Epoch 860/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1406 - val_loss: -0.9420
# Epoch 861/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1385 - val_loss: -0.9422
# Epoch 862/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1393 - val_loss: -0.9424
# Epoch 863/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1296 - val_loss: -0.9426
# Epoch 864/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0960 - val_loss: -0.9428
# Epoch 865/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1170 - val_loss: -0.9430
# Epoch 866/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1201 - val_loss: -0.9432
# Epoch 867/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1273 - val_loss: -0.9434
# Epoch 868/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.1134 - val_loss: -0.9436
# Epoch 869/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1102 - val_loss: -0.9438
# Epoch 870/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.1130 - val_loss: -0.9440
# Epoch 871/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.1074 - val_loss: -0.9442
# Epoch 872/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0781 - val_loss: -0.9443
# Epoch 873/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 2.1119 - val_loss: -0.9445
# Epoch 874/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0886 - val_loss: -0.9447
# Epoch 875/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0926 - val_loss: -0.9449
# Epoch 876/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 2.0866 - val_loss: -0.9451
# Epoch 877/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 2.0907 - val_loss: -0.9453
# Epoch 878/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0907 - val_loss: -0.9455
# Epoch 879/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0824 - val_loss: -0.9457
# Epoch 880/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0866 - val_loss: -0.9458
# Epoch 881/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0800 - val_loss: -0.9460
# Epoch 882/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0728 - val_loss: -0.9462
# Epoch 883/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0416 - val_loss: -0.9464
# Epoch 884/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0703 - val_loss: -0.9466
# Epoch 885/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0708 - val_loss: -0.9468
# Epoch 886/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0596 - val_loss: -0.9469
# Epoch 887/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0616 - val_loss: -0.9471
# Epoch 888/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0664 - val_loss: -0.9473
# Epoch 889/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0586 - val_loss: -0.9475
# Epoch 890/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0442 - val_loss: -0.9476
# Epoch 891/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0508 - val_loss: -0.9478
# Epoch 892/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0413 - val_loss: -0.9480
# Epoch 893/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 2.0421 - val_loss: -0.9482
# Epoch 894/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0408 - val_loss: -0.9483
# Epoch 895/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0343 - val_loss: -0.9485
# Epoch 896/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 1.9894 - val_loss: -0.9487
# Epoch 897/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 2.0493 - val_loss: -0.9488
# Epoch 898/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0252 - val_loss: -0.9490
# Epoch 899/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0260 - val_loss: -0.9492
# Epoch 900/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0226 - val_loss: -0.9494
# Epoch 901/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0180 - val_loss: -0.9495
# Epoch 902/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0152 - val_loss: -0.9497
# Epoch 903/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0166 - val_loss: -0.9499
# Epoch 904/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0043 - val_loss: -0.9500
# Epoch 905/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0074 - val_loss: -0.9502
# Epoch 906/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0069 - val_loss: -0.9503
# Epoch 907/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0118 - val_loss: -0.9505
# Epoch 908/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9976 - val_loss: -0.9507
# Epoch 909/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 2.0034 - val_loss: -0.9508
# Epoch 910/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9899 - val_loss: -0.9510
# Epoch 911/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9897 - val_loss: -0.9511
# Epoch 912/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9875 - val_loss: -0.9513
# Epoch 913/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9907 - val_loss: -0.9514
# Epoch 914/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9832 - val_loss: -0.9516
# Epoch 915/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9774 - val_loss: -0.9518
# Epoch 916/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9650 - val_loss: -0.9519
# Epoch 917/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9753 - val_loss: -0.9521
# Epoch 918/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9699 - val_loss: -0.9522
# Epoch 919/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9730 - val_loss: -0.9524
# Epoch 920/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.9487 - val_loss: -0.9525
# Epoch 921/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9597 - val_loss: -0.9527
# Epoch 922/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9648 - val_loss: -0.9528
# Epoch 923/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9504 - val_loss: -0.9530
# Epoch 924/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9576 - val_loss: -0.9531
# Epoch 925/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9528 - val_loss: -0.9533
# Epoch 926/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9167 - val_loss: -0.9534
# Epoch 927/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9537 - val_loss: -0.9535
# Epoch 928/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9396 - val_loss: -0.9537
# Epoch 929/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9417 - val_loss: -0.9538
# Epoch 930/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9454 - val_loss: -0.9540
# Epoch 931/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9380 - val_loss: -0.9541
# Epoch 932/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9364 - val_loss: -0.9543
# Epoch 933/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.9391 - val_loss: -0.9544
# Epoch 934/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 1.9374 - val_loss: -0.9545
# Epoch 935/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9383 - val_loss: -0.9547
# Epoch 936/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8850 - val_loss: -0.9548
# Epoch 937/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9157 - val_loss: -0.9549
# Epoch 938/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9158 - val_loss: -0.9551
# Epoch 939/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9201 - val_loss: -0.9552
# Epoch 940/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9048 - val_loss: -0.9553
# Epoch 941/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9121 - val_loss: -0.9555
# Epoch 942/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.9067 - val_loss: -0.9556
# Epoch 943/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9023 - val_loss: -0.9557
# Epoch 944/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8925 - val_loss: -0.9559
# Epoch 945/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9026 - val_loss: -0.9560
# Epoch 946/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8994 - val_loss: -0.9561
# Epoch 947/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8928 - val_loss: -0.9562
# Epoch 948/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8950 - val_loss: -0.9564
# Epoch 949/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8800 - val_loss: -0.9565
# Epoch 950/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8855 - val_loss: -0.9566
# Epoch 951/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8942 - val_loss: -0.9567
# Epoch 952/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8820 - val_loss: -0.9568
# Epoch 953/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8820 - val_loss: -0.9570
# Epoch 954/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8766 - val_loss: -0.9571
# Epoch 955/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8761 - val_loss: -0.9572
# Epoch 956/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8690 - val_loss: -0.9573
# Epoch 957/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8691 - val_loss: -0.9574
# Epoch 958/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8644 - val_loss: -0.9576
# Epoch 959/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8653 - val_loss: -0.9577
# Epoch 960/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8547 - val_loss: -0.9578
# Epoch 961/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8538 - val_loss: -0.9579
# Epoch 962/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8497 - val_loss: -0.9580
# Epoch 963/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8571 - val_loss: -0.9581
# Epoch 964/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8435 - val_loss: -0.9582
# Epoch 965/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8473 - val_loss: -0.9583
# Epoch 966/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8413 - val_loss: -0.9584
# Epoch 967/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8284 - val_loss: -0.9586
# Epoch 968/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8375 - val_loss: -0.9587
# Epoch 969/1000
# 18/18 [==============================] - 0s 24ms/step - loss: 1.8202 - val_loss: -0.9588
# Epoch 970/1000
# 18/18 [==============================] - 0s 28ms/step - loss: 1.8298 - val_loss: -0.9589
# Epoch 971/1000
# 18/18 [==============================] - 0s 23ms/step - loss: 1.8289 - val_loss: -0.9590
# Epoch 972/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8195 - val_loss: -0.9591
# Epoch 973/1000
# 18/18 [==============================] - 0s 18ms/step - loss: 1.8257 - val_loss: -0.9592
# Epoch 974/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8165 - val_loss: -0.9593
# Epoch 975/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8211 - val_loss: -0.9594
# Epoch 976/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8161 - val_loss: -0.9595
# Epoch 977/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8236 - val_loss: -0.9596
# Epoch 978/1000
# 18/18 [==============================] - 0s 15ms/step - loss: 1.8020 - val_loss: -0.9597
# Epoch 979/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8130 - val_loss: -0.9598
# Epoch 980/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8086 - val_loss: -0.9599
# Epoch 981/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8113 - val_loss: -0.9600
# Epoch 982/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8067 - val_loss: -0.9600
# Epoch 983/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.7886 - val_loss: -0.9601
# Epoch 984/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.7913 - val_loss: -0.9602
# Epoch 985/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7887 - val_loss: -0.9603
# Epoch 986/1000
# 18/18 [==============================] - 0s 16ms/step - loss: 1.7867 - val_loss: -0.9604
# Epoch 987/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 1.7813 - val_loss: -0.9605
# Epoch 988/1000
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7855 - val_loss: -0.9606
# Epoch 989/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7871 - val_loss: -0.9607
# Epoch 990/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.7771 - val_loss: -0.9607
# Epoch 991/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.7861 - val_loss: -0.9608
# Epoch 992/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7693 - val_loss: -0.9609
# Epoch 993/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.7626 - val_loss: -0.9610
# Epoch 994/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 1.7686 - val_loss: -0.9611
# Epoch 995/1000
# 18/18 [==============================] - 0s 17ms/step - loss: 1.7587 - val_loss: -0.9612
# Epoch 996/1000
# 18/18 [==============================] - 0s 13ms/step - loss: 1.7375 - val_loss: -0.9612
# Epoch 997/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7724 - val_loss: -0.9613
# Epoch 998/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7557 - val_loss: -0.9614
# Epoch 999/1000
# 18/18 [==============================] - 0s 12ms/step - loss: 1.7618 - val_loss: -0.9615
# Epoch 1000/1000
# 18/18 [==============================] - 0s 11ms/step - loss: 1.7502 - val_loss: -0.9615

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
##그래프저장
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 31), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 포트폴리오 수익률 (연간):
# crp_rtn      0.072127
# lstm_rtn     0.052862
# sp500_rtn    0.022451
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.022594
# lstm_rtn     0.014581
# sp500_rtn    0.047066
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      3.192322
# lstm_rtn     3.625314
# sp500_rtn    0.477018
# dtype: float64

# %% [markdown]
# ## 가중치 DF 저장 (일자별)

# %%
w_hist_lstm = []
for i in range(0, xc_test.shape[0]):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)

# %%
idx = np.arange(0, len(test_date))
date=test_date[idx]

# %%
len(w_hist_lstm)
# Out:
# 1250

# %%
W_df=pd.DataFrame(w_hist_lstm[:-1],columns=rtn_df.columns,index=list(date)[20:])
W_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 2017-07-17  0.248153  0.210410  0.073695  0.219609  0.075302  0.082481
# 2017-07-18  0.227940  0.203271  0.076189  0.241344  0.073712  0.080968
# 2017-07-19  0.222446  0.209552  0.075894  0.239655  0.077632  0.081715
# 2017-07-20  0.226576  0.212583  0.075920  0.236395  0.080172  0.080961
# 2017-07-21  0.235348  0.212348  0.078799  0.218176  0.088236  0.082936
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.277195  0.201183  0.075675  0.195841  0.078060  0.082164
# 2022-05-05  0.289069  0.192017  0.075364  0.202906  0.076144  0.078666
# 2022-05-06  0.295693  0.214035  0.068802  0.177236  0.075996  0.083390
# 2022-05-09  0.312471  0.198922  0.077140  0.151515  0.088095  0.087959
# 2022-05-10  0.300961  0.205390  0.076549  0.152720  0.088623  0.090017
#
#                nsd로그
# 2017-07-17  0.090351
# 2017-07-18  0.096576
# 2017-07-19  0.093106
# 2017-07-20  0.087392
# 2017-07-21  0.084156
# ...              ...
# 2022-05-04  0.089883
# 2022-05-05  0.085834
# 2022-05-06  0.084849
# 2022-05-09  0.083898
# 2022-05-10  0.085739
#
# [1249 rows x 7 columns]

# %%
W_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/하락/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치(일자별).csv")

# %% [markdown]
# # 타 펀드 비교(KB)

# %%
kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
kb.일자=pd.to_datetime(kb.일자)
kb=kb.set_index('일자')
#일자설정
kb=kb.loc[perf_df.index[0]:perf_df.index[-1]]
kb['금액']=10000
kb['수익률(%)']=kb['수익률(%)']*0.01
for i in range(1,kb.shape[0]):
    kb.iloc[i,1]=kb.iloc[i,0]*kb.iloc[i-1,1]+kb.iloc[i-1,1]
p_df=perf_df.copy()
p_df=p_df.reset_index()
kb=kb.reset_index()
grp=pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')
grp=grp.set_index('Date')
grp=grp[['crp', 'lstm_markowitz', 'kospi', '금액']]
grp.columns=['crp', 'lstm_markowitz', 'kospi', 'KB펀드']
grp=grp.dropna()

# %% [markdown]
# # 타 펀드 비교 <미래에셋>

# %%
fa=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/미래에셋.csv")
fa=fa.T
fa=fa.iloc[1:]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
fa=fa.set_index('index')
fa.columns=['투자수익률','비교지수']
fa['미래에셋']=fa['투자수익률']*0.01*10000+10000
fa['미래에셋_pct']=fa['미래에셋'].pct_change(1)
#일자설정
fa=fa.loc[perf_df.index[0]:perf_df.index[-1]]
fa['미래에셋']=10000
for i in range(1,fa.shape[0]):
    fa.iloc[i,2]=fa.iloc[i,3]*fa.iloc[i-1,2]+fa.iloc[i-1,2]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
grp=pd.merge(grp.reset_index(),fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
grp=grp[['Date','lstm_markowitz','kospi','미래에셋','KB펀드']]
grp=grp.dropna()
grp=grp.set_index('Date')

# %% [markdown]
# # 차트 이미지 저장

# %%
p = grp.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/하락/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49483 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 주식 전략 결합

# %%
log_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
log_df = log_df.set_index('Date')
log_df = log_df.loc[:'2019-10-31']

# %%
log_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2019-10-25  0.000004 -0.001182  0.001069  0.002085  0.005782 -0.008568
# 2019-10-28  0.000081 -0.002041  0.002731 -0.009069 -0.003851 -0.006074
# 2019-10-29  0.000023  0.001165 -0.000435 -0.003510 -0.001931  0.006074
# 2019-10-30  0.000061  0.000579 -0.005953  0.007008 -0.006464  0.003605
# 2019-10-31  0.000025  0.000157  0.001542  0.009729 -0.005854 -0.001801
#
#                nsd로그  상승          코스피
# Date
# 2006-03-01 -0.000493   0  1371.589966
# 2006-03-02 -0.012176   0  1367.699951
# 2006-03-03  0.017103   0  1328.949951
# 2006-03-06 -0.018103   0  1344.760010
# 2006-03-07 -0.043212   0  1316.670044
# ...              ...  ..          ...
# 2019-10-25 -0.025676   0  2087.889893
# 2019-10-28  0.003043   0  2093.600098
# 2019-10-29 -0.000912   0  2092.689941
# 2019-10-30  0.014293   0  2080.270020
# 2019-10-31 -0.002902   0  2083.479980
#
# [3543 rows x 9 columns]

# %%
log_df = log_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그',
       'vnq로그', 'nsd로그']]

# %%
log_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/log데이터셋.csv")

# %%
log_df = pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/log데이터셋.csv")

# %%
log_df['Date']=pd.to_datetime(log_df['Date'])

# %%
log_df.columns
# Out:
# Index(['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그'], dtype='object')

# %%
r_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/주식전략/로그수익률전체_10종목.csv")

# %%
r_df=r_df.fillna(0)

# %%
r_df.columns
# Out:
# Index(['Unnamed: 0', '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
#        '성장성기법', '수익성기법', '시장가치기법', '활동성기법'],
#       dtype='object')

# %%
r_df['Unnamed: 0']=pd.to_datetime(r_df['Unnamed: 0'])
r_df.columns=['Date', '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']

# %% [markdown]
# ## 극안전형

# %%
극안전형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/극안전형.csv")
안전추구형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/안전추구형.csv")
위험중립형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/위험중립형.csv")
적극투자형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/적극투자형.csv")
공격투자형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/공격투자형.csv")

# %%
극안전형 = 극안전형.drop('Unnamed: 0', axis=1)
극안전형.columns = ['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']

# %%
극안전형
# Out:
#            Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 0    2019-11-01  0.357846  0.350863  0.062167  0.075185  0.050869  0.051566
# 1    2019-11-04  0.355070  0.349667  0.060141  0.084932  0.049446  0.050332
# 2    2019-11-05  0.354140  0.348552  0.058575  0.088817  0.049258  0.050139
# 3    2019-11-06  0.357363  0.350958  0.059128  0.081139  0.049868  0.050622
# 4    2019-11-07  0.357707  0.352224  0.059453  0.079134  0.049905  0.050711
# ..          ...       ...       ...       ...       ...       ...       ...
# 649  2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 650  2022-05-05  0.321733  0.328054  0.062213  0.138679  0.047262  0.050574
# 651  2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 652  2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 653  2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#         nsd로그
# 0    0.051505
# 1    0.050412
# 2    0.050519
# 3    0.050922
# 4    0.050866
# ..        ...
# 649  0.051183
# 650  0.051485
# 651  0.051133
# 652  0.051428
# 653  0.051980
#
# [654 rows x 8 columns]

# %%
극안전형.Date=pd.to_datetime(극안전형.Date)

# %%
극안전형_df=pd.concat([log_df,극안전형], axis=0)
극안전형_df
# Out:
#           Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 0   2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 1   2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2   2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 3   2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 4   2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ..         ...       ...       ...       ...       ...       ...       ...
# 649 2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 650 2022-05-05  0.321733  0.328054  0.062213  0.138679  0.047262  0.050574
# 651 2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 652 2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 653 2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#         nsd로그
# 0   -0.000493
# 1   -0.012176
# 2    0.017103
# 3   -0.018103
# 4   -0.043212
# ..        ...
# 649  0.051183
# 650  0.051485
# 651  0.051133
# 652  0.051428
# 653  0.051980
#
# [4197 rows x 8 columns]

# %%
#기간별로 정렬
극안전형_df=극안전형_df.sort_values(by=['Date'], ascending=True)

# %%
극안전형_df=극안전형_df.fillna(method='ffill').dropna()

# %%
극안전형_df=pd.merge(극안전형_df,r_df, on='Date', how='outer').dropna()

# %%
극안전형_df = 극안전형_df.set_index('Date')

# %%
극안전형_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# 2006-03-08  0.000203  0.000818 -0.001992 -0.019625 -0.016154  0.005173
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-03  0.330887  0.330873  0.062915  0.125514  0.047841  0.050911
# 2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#                nsd로그     유동성기법    레버리지기법    그레이엄기법      린치기법      버핏기법  \
# Date
# 2006-03-02 -0.012176 -0.004163  0.003148 -0.004245 -0.009235 -0.004180
# 2006-03-03  0.017103 -0.016589 -0.022778 -0.017546 -0.022754 -0.024339
# 2006-03-06 -0.018103  0.011637  0.011190  0.004478  0.003144  0.012759
# 2006-03-07 -0.043212 -0.016843 -0.028491 -0.011694 -0.002772 -0.025226
# 2006-03-08  0.007549 -0.007919 -0.004598  0.010290  0.001887 -0.014189
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-03  0.051060  0.002114 -0.006505 -0.008353 -0.003740  0.001091
# 2022-05-04  0.051183 -0.009320 -0.003745 -0.006407  0.001788 -0.004029
# 2022-05-06  0.051133  0.001078 -0.013734 -0.006216 -0.013486 -0.012977
# 2022-05-09  0.051428 -0.016910 -0.011615 -0.028295 -0.018643 -0.011348
# 2022-05-10  0.051980 -0.015892 -0.004799 -0.002160 -0.009955 -0.010384
#
#               삼대투자기법     성장성기법     수익성기법    시장가치기법     활동성기법
# Date
# 2006-03-02 -0.002885 -0.011703  0.003138  0.001468  0.007272
# 2006-03-03 -0.019855 -0.019931 -0.023816 -0.042204 -0.022764
# 2006-03-06  0.010315  0.011755  0.010877  0.021549  0.014470
# 2006-03-07 -0.013850 -0.019911 -0.026519 -0.021908 -0.025480
# 2006-03-08 -0.006048 -0.010333 -0.003670  0.000692 -0.003637
# ...              ...       ...       ...       ...       ...
# 2022-05-03 -0.004454 -0.004513 -0.006798 -0.001810 -0.008891
# 2022-05-04 -0.000976  0.000924 -0.002858  0.006830  0.002055
# 2022-05-06 -0.015054 -0.014405 -0.012405 -0.008364 -0.006202
# 2022-05-09 -0.021987 -0.013603 -0.014154 -0.013436 -0.006623
# 2022-05-10 -0.003993 -0.004541 -0.006504 -0.001658 -0.015276
#
# [4001 rows x 17 columns]

# %%
극안전형_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','유동성기법', '레버리지기법','그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']]=극안전형_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','유동성기법','레버리지기법','그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']].cumsum()

# %%
극안전형_df['금액']=10000

# %%
극안전형_df
# Out:
#           Date       단기채로그       중기채로그      ksp로그       iau로그      dbc로그  \
# 0   2019-11-01    0.357846    0.350863   0.062167    0.075185   0.050869
# 1   2019-11-04    0.712916    0.700531   0.122307    0.160117   0.100315
# 2   2019-11-05    1.067056    1.049082   0.180882    0.248934   0.149573
# 3   2019-11-06    1.424418    1.400040   0.240010    0.330073   0.199441
# 4   2019-11-07    1.782125    1.752264   0.299463    0.409208   0.249346
# ..         ...         ...         ...        ...         ...        ...
# 618 2022-05-03  146.648074  156.564560  45.243843  108.555898  33.600930
# 619 2022-05-04  146.969286  156.889159  45.303126  108.702273  33.648079
# 620 2022-05-06  147.310963  157.228137  45.361161  108.812906  33.696533
# 621 2022-05-09  147.657208  157.568805  45.425395  108.909344  33.745712
# 622 2022-05-10  148.008962  157.914959  45.487003  108.995747  33.795428
#
#          vnq로그      nsd로그     유동성기법    레버리지기법  ...    시장가치기법     활동성기법  \
# 0     0.051566   0.051505  0.000157  0.014511  ...  0.008100  0.014093
# 1     0.101897   0.101917  0.014559  0.017529  ...  0.016869  0.033270
# 2     0.152037   0.152436  0.029178  0.017005  ...  0.027458  0.038091
# 3     0.202659   0.203359  0.028046  0.012199  ...  0.029495  0.034984
# 4     0.253370   0.254225  0.029493  0.013177  ...  0.034695  0.042584
# ..         ...        ...       ...       ...  ...       ...       ...
# 618  50.255897  81.130798 -0.164537 -0.030700  ...  0.434623  0.034518
# 619  50.306097  81.181981 -0.173857 -0.034445  ...  0.441454  0.036573
# 620  50.357186  81.233114 -0.172779 -0.048179  ...  0.433090  0.030371
# 621  50.408994  81.284542 -0.189689 -0.059794  ...  0.419654  0.023748
# 622  50.461378  81.336522 -0.205581 -0.064594  ...  0.417996  0.008471
#
#          단기채w      중기채w      kspw      iauw      dbcw      vnqw      nsdw  \
# 0    0.357846  0.350863  0.062167  0.075185  0.050869  0.051566  0.051505
# 1    0.355070  0.349667  0.060141  0.084932  0.049446  0.050332  0.050412
# 2    0.354140  0.348552  0.058575  0.088817  0.049258  0.050139  0.050519
# 3    0.357363  0.350958  0.059128  0.081139  0.049868  0.050622  0.050922
# 4    0.357707  0.352224  0.059453  0.079134  0.049905  0.050711  0.050866
# ..        ...       ...       ...       ...       ...       ...       ...
# 618  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 619  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 620  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 621  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 622  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
#
#         금액
# 0    10000
# 1    10000
# 2    10000
# 3    10000
# 4    10000
# ..     ...
# 618  10000
# 619  10000
# 620  10000
# 621  10000
# 622  10000
#
# [626 rows x 26 columns]

# %%
log_df['유동성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['유동성기법'])
log_df['레버리지']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['레버리지기법'])
log_df['그레이엄']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['그레이엄기법'])
log_df['린치']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['린치기법'])
log_df['버핏']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['버핏기법'])
log_df['삼대투자']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['삼대투자기법'])
log_df['성장성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['성장성기법'])
log_df['수익성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['수익성기법'])
log_df['시장가치']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['시장가치기법'])
log_df['활동성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['활동성기법'])

# %%
log_df.columns
# Out:
# Index(['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그',
#        '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법', '성장성기법', '수익성기법',
#        '시장가치기법', '활동성기법', '단기채w', '중기채w', 'kspw', 'iauw', 'dbcw', 'vnqw',
#        'nsdw', '금액', '유동성', '레버리지', '그레이엄', '린치', '버핏', '삼대투자', '성장성', '수익성',
#        '시장가치', '활동성'],
#       dtype='object')

# %%
grp = grp.drop(['level_0', 'index'], axis=1)

# %%
grp=pd.merge(grp,log_df[['Date','유동성', '레버리지', '그레이엄', '린치', '버핏', '삼대투자',
       '성장성', '수익성', '시장가치', '활동성']],on='Date',how='outer').dropna()

# %%
grp
# Out:
#         Date  lstm_markowitz         kospi          미래에셋          KB펀드  \
# 0 2019-11-01    10187.362432  10393.479515  10227.294524  10080.015967
# 1 2019-11-29    10334.183163  10332.906193  10208.113551  10171.523403
# 2 2019-12-30    10554.629758  10875.839370  10873.693296  10341.156641
# 3 2020-01-28    10723.319220  10772.162152  10450.752853  10398.571566
# 4 2020-02-25    10996.476872  10410.355712   9849.429366  10309.944928
# 5 2020-03-24     7480.303458   7967.427054   7047.089287   9519.046916
#
#         금액         유동성_x        레버리지_x        그레이엄_x          린치_x  ...  \
# 0  10000.0  10005.633421  10014.622593  10011.265371  10008.849871  ...
# 1  10000.0  10007.633854   9997.061891  10006.098425  10008.513379  ...
# 2  10000.0  10107.852540  10109.586143  10135.190078  10119.390367  ...
# 3  10000.0  10144.402212  10153.875840  10132.090062  10102.381538  ...
# 4  10000.0  10157.752961  10181.030486  10125.822446  10109.267991  ...
# 5  10000.0   9618.630957   9643.519709   9553.747163   9547.239428  ...
#
#             유동성          레버리지          그레이엄            린치            버핏  \
# 0  1.315413e+04  1.316312e+04  1.315976e+04  1.315734e+04  1.316140e+04
# 1  1.208665e+07  1.208664e+07  1.208665e+07  1.208665e+07  1.208665e+07
# 2  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10
# 3  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13
# 4  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16
# 5  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19
#
#            삼대투자           성장성           수익성          시장가치           활동성
# 0  1.315880e+04  1.315901e+04  1.316230e+04  1.315909e+04  1.316285e+04
# 1  1.208663e+07  1.208666e+07  1.208665e+07  1.208667e+07  1.208666e+07
# 2  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10
# 3  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13
# 4  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16
# 5  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19
#
# [6 rows x 36 columns]

# %%
p = grp[['lstm_markowitz', '미래에셋', 'KB펀드', '유동성',
       '레버리지', '그레이엄', '린치', '버핏', '삼대투자', '성장성', '수익성', '시장가치', '활동성']].plot(figsize=(18, 10), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()

# %%
grp
# Out:
#                      crp  lstm_markowitz         kospi          미래에셋  \
# Date
# 2019-12-31  10000.000000    10000.000000  10000.000000  10000.000000
# 2020-01-29  10036.938181    10224.825144   9943.622596   9629.564297
# 2020-02-26  10005.999563    10295.900080   9449.872335   8954.842124
# 2020-03-25   8402.684397     8137.672903   7757.124911   6931.557594
# 2020-04-22   9057.310134     8708.347455   8628.001892   7832.951138
# 2020-05-20   9362.758662     9051.162397   9053.406951   8273.064032
# 2020-06-17   9824.690125     9496.075493   9742.364072   8539.424943
# 2020-07-15   9957.452690     9693.330050  10019.156475   8721.114835
# 2020-08-12  10371.504093    10128.862742  11067.859069   9440.818487
# 2020-09-09  10292.450094    10063.904103  10810.586408   9187.687423
# 2020-10-07  10275.134080     9984.177318  10861.230422   9319.103898
# 2020-11-04  10237.541204     9981.092303  10726.451888   9218.557065
# 2020-12-02  10597.367513    10321.319603  12176.077380  10275.180808
# 2020-12-31  10894.766691    10518.663007  13075.075297  11180.984301
# 2021-01-29  11152.962972    10823.820056  13542.570389  11487.916740
# 2021-02-26  11372.913887    10954.044864  13709.747406  11794.849180
# 2021-03-26  11325.681680    11101.501111  13837.428358  12222.614218
# 2021-04-23  11839.313048    11778.345831  14474.785528  12817.957312
# 2021-05-21  12021.770849    12011.649133  14362.575064  12713.000529
# 2021-06-18  12277.632671    12309.262421  14869.976147  12985.535368
# 2021-07-16  12426.582998    12415.465402  14910.837517  13082.554242
# 2021-08-13  12453.489541    12646.145731  14430.238170  12573.646146
# 2021-09-10  12541.492616    12927.108612  14223.064067  12628.329511
# 2021-10-08  12507.212782    12833.097990  13451.974837  11965.073205
# 2021-11-05  12761.542320    13370.005194  13510.991755  11899.805962
# 2021-12-03  12483.723393    12989.070543  13506.714764  12004.762745
# 2021-12-31  12894.858341    13492.275383  13549.122517  12262.303757
# 2022-01-28  12169.251869    12293.796849  12118.926784  11074.263539
# 2022-02-25  12386.036159    12415.628222  12179.991104  11158.934556
# 2022-03-25  12836.006161    12819.592352  12422.156545  11382.959958
# 2022-04-22  12913.432618    12896.716753  12307.171036  11360.028224
#
#                     KB펀드
# Date
# 2019-12-31  10000.000000
# 2020-01-29  10001.226413
# 2020-02-26  10003.711958
# 2020-03-25   9384.491606
# 2020-04-22   9915.377562
# 2020-05-20  10137.949590
# 2020-06-17  10302.839218
# 2020-07-15  10403.527375
# 2020-08-12  10647.166535
# 2020-09-09  10601.037559
# 2020-10-07  10595.732142
# 2020-11-04  10556.818433
# 2020-12-02  10927.285521
# 2020-12-31  11241.136501
# 2021-01-29  11444.498132
# 2021-02-26  11676.615631
# 2021-03-26  11856.883786
# 2021-04-23  12055.941048
# 2021-05-21  12026.296586
# 2021-06-18  12186.972527
# 2021-07-16  12302.854271
# 2021-08-13  12365.113572
# 2021-09-10  12259.260034
# 2021-10-08  12097.598061
# 2021-11-05  12153.756683
# 2021-12-03  12070.437716
# 2021-12-31  12189.993461
# 2022-01-28  11746.996099
# 2022-02-25  11705.772804
# 2022-03-25  11867.286281
# 2022-04-22  11849.037618
