# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %% [markdown]
# # train, test 기간설정
#
# <pre>
# 뉴스심리지수 활용 구간 설정
# <상승기간> Train set
# '2006-07-31' : '2007-12-31'
# '2009-01-31' : '2010-02-29'
# '2010-07-31' : '2011-01-31'
# '2011-12-31' : '2012-05-01'
# '2012-10-31' : '2013-02-28'
# '2013-07-31' : '2014-01-31'
# '2014-04-30' : '2014-11-30'
# '2015-02-28' : '2015-06-30'
# '2017-01-31' : '2018-02-28'
# '2019-03-31' : '2019-06-30'
# '2019-10-31' : '2020-01-31'
# '2020-06-30' : '2021-08-31'
#
#
# <하락기간> Train set
# '2008-01-31' : '2008-12-31'
# '2010-03-31' : '2010-06-30'
# '2011-02-28' : '2011-11-30'
# '2012-06-30' : '2012-09-30'
# '2013-03-31' : '2013-06-30'
# '2014-02-28' : '2014-03-31'
# '2014-12-31' : '2015-01-31'
# '2015-07-31' : '2016-12-31'
# '2018-03-31' : '2019-02-28'
# '2019-07-31' : '2019-09-30'
# '2020-02-29' : '2020-04-30'
# '2021-09-30' : '2022-05-31'
#
#
# [Test Set]
# '2017-05-22' : '2022-05-22'

# %%
# 모델 # 상승모델이나 하강모델 넣기
rtn_df_train=rtn_df.loc[:'2017-05-21'] # Train set
rtn_df_test=rtn_df.loc['2017-05-22':]  # Test set

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960/
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
up_2006=df.loc['2006-07-31' : '2007-12-31']
up_2009=df.loc['2009-01-31' : '2010-02-26']
up_2010=df.loc['2010-07-31' : '2011-01-31']
up_2011=df.loc['2011-12-31' : '2012-05-01']
up_2012=df.loc['2012-10-31' : '2013-02-28']
up_2013=df.loc['2013-07-31' : '2014-01-31']
up_2014=df.loc['2014-04-30' : '2014-11-30']
up_2015=df.loc['2015-02-28' : '2015-06-30']


up_2017=df.loc['2017-01-31' : '2018-02-28']
up_2019=df.loc['2019-03-31' : '2019-06-30']
up_2020=df.loc['2019-10-31' : '2020-01-31']
up_2021=df.loc['2020-06-30' : '2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

for i in range(1, len(up_2006) - T + 1):
    d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2009) - T + 1):
    d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2010) - T + 1):
    d = np.expand_dims(np.array(up_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2011) - T + 1):
    d = np.expand_dims(np.array(up_2011.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2012) - T + 1):
    d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2013) - T + 1):
    d = np.expand_dims(np.array(up_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2014) - T + 1):
    d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2015) - T + 1):
    d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2017) - T + 1):
    d = np.expand_dims(np.array(up_2017.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2019) - T + 1):
    d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2020) - T + 1):
    d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2021) - T + 1):
    d = np.expand_dims(np.array(up_2021.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ##  데이터셋 나눠서 만들기(하강)

# %%
down_2008=df.loc['2008-01-31':'2008-12-31']
down_2010=df.loc['2010-03-31':'2010-06-30']
down_2011=df.loc['2011-02-28':'2011-11-30']
down_2012=df.loc['2012-06-30':'2012-09-30']
down_2013=df.loc['2013-03-31':'2013-06-30']
down_2014=df.loc['2014-02-28':'2014-03-31']
down_2015=df.loc['2014-12-31':'2015-01-31']
down_2016=df.loc['2015-07-31':'2016-12-31']


down_2018=df.loc['2018-03-31':'2019-02-28']
down_2019=df.loc['2019-07-31':'2019-09-30']
down_2020=df.loc['2020-02-29':'2020-04-30']
down_2021=df.loc['2021-09-30':'2022-05-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(down_2008.iloc[0:T, :]), 0)

for i in range(1, len(down_2008) - T + 1):
    d = np.expand_dims(np.array(down_2008.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2010) - T + 1):
    d = np.expand_dims(np.array(down_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2011) - T + 1):
    d = np.expand_dims(np.array(down_2011.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2012) - T + 1):
    d = np.expand_dims(np.array(down_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2013) - T + 1):
    d = np.expand_dims(np.array(down_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2014) - T + 1):
    d = np.expand_dims(np.array(down_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2015) - T + 1):
    d = np.expand_dims(np.array(down_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2016) - T + 1):
    d = np.expand_dims(np.array(down_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2018) - T + 1):
    d = np.expand_dims(np.array(down_2018.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2019) - T + 1):
    d = np.expand_dims(np.array(down_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2020) - T + 1):
    d = np.expand_dims(np.array(down_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2021) - T + 1):
    d = np.expand_dims(np.array(down_2021.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ## rtn_train 구성하기

# %%
# rtn_train 값에 기간별로 자른 값 집어넣기
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100


N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.40
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 7)                 420
#
#  dense_5 (Dense)             (None, 7)                 56
#
#  activation_5 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 25/25 [==============================] - 4s 41ms/step - loss: 5.5665 - val_loss: 5.8673
# Epoch 2/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5842 - val_loss: 5.8629
# Epoch 3/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.5810 - val_loss: 5.8584
# Epoch 4/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.5046 - val_loss: 5.8541
# Epoch 5/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5943 - val_loss: 5.8495
# Epoch 6/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.5508 - val_loss: 5.8452
# Epoch 7/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5069 - val_loss: 5.8408
# Epoch 8/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.5464 - val_loss: 5.8364
# Epoch 9/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5056 - val_loss: 5.8323
# Epoch 10/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.4924 - val_loss: 5.8276
# Epoch 11/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5069 - val_loss: 5.8233
# Epoch 12/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.4878 - val_loss: 5.8190
# Epoch 13/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.4742 - val_loss: 5.8145
# Epoch 14/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.4615 - val_loss: 5.8103
# Epoch 15/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.4765 - val_loss: 5.8060
# Epoch 16/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.4682 - val_loss: 5.8016
# Epoch 17/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.4051 - val_loss: 5.7972
# Epoch 18/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3978 - val_loss: 5.7930
# Epoch 19/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3888 - val_loss: 5.7886
# Epoch 20/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3559 - val_loss: 5.7844
# Epoch 21/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.4223 - val_loss: 5.7801
# Epoch 22/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3783 - val_loss: 5.7758
# Epoch 23/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.3647 - val_loss: 5.7715
# Epoch 24/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.3193 - val_loss: 5.7673
# Epoch 25/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3386 - val_loss: 5.7629
# Epoch 26/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3758 - val_loss: 5.7586
# Epoch 27/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3323 - val_loss: 5.7542
# Epoch 28/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3783 - val_loss: 5.7501
# Epoch 29/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3745 - val_loss: 5.7459
# Epoch 30/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.2993 - val_loss: 5.7417
# Epoch 31/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3347 - val_loss: 5.7374
# Epoch 32/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2992 - val_loss: 5.7332
# Epoch 33/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3542 - val_loss: 5.7290
# Epoch 34/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 5.3181 - val_loss: 5.7248
# Epoch 35/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3215 - val_loss: 5.7205
# Epoch 36/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.3175 - val_loss: 5.7164
# Epoch 37/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.3211 - val_loss: 5.7120
# Epoch 38/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 5.2385 - val_loss: 5.7082
# Epoch 39/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2948 - val_loss: 5.7038
# Epoch 40/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.2562 - val_loss: 5.6997
# Epoch 41/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 5.2429 - val_loss: 5.6955
# Epoch 42/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2786 - val_loss: 5.6914
# Epoch 43/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2394 - val_loss: 5.6872
# Epoch 44/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2946 - val_loss: 5.6831
# Epoch 45/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2791 - val_loss: 5.6788
# Epoch 46/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1701 - val_loss: 5.6749
# Epoch 47/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.2208 - val_loss: 5.6707
# Epoch 48/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.2573 - val_loss: 5.6664
# Epoch 49/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2592 - val_loss: 5.6623
# Epoch 50/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2041 - val_loss: 5.6583
# Epoch 51/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.1723 - val_loss: 5.6542
# Epoch 52/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.1830 - val_loss: 5.6502
# Epoch 53/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1865 - val_loss: 5.6460
# Epoch 54/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.1855 - val_loss: 5.6420
# Epoch 55/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.1819 - val_loss: 5.6377
# Epoch 56/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.2040 - val_loss: 5.6338
# Epoch 57/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.1823 - val_loss: 5.6296
# Epoch 58/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1492 - val_loss: 5.6257
# Epoch 59/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1384 - val_loss: 5.6215
# Epoch 60/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.1329 - val_loss: 5.6175
# Epoch 61/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1311 - val_loss: 5.6134
# Epoch 62/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.0939 - val_loss: 5.6093
# Epoch 63/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 5.1069 - val_loss: 5.6053
# Epoch 64/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1426 - val_loss: 5.6012
# Epoch 65/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 5.1299 - val_loss: 5.5971
# Epoch 66/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 5.0835 - val_loss: 5.5931
# Epoch 67/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 5.0992 - val_loss: 5.5890
# Epoch 68/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.1330 - val_loss: 5.5849
# Epoch 69/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.0588 - val_loss: 5.5809
# Epoch 70/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.9313 - val_loss: 5.5770
# Epoch 71/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.1037 - val_loss: 5.5729
# Epoch 72/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.0624 - val_loss: 5.5689
# Epoch 73/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 5.0185 - val_loss: 5.5647
# Epoch 74/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 5.0447 - val_loss: 5.5607
# Epoch 75/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 5.0119 - val_loss: 5.5567
# Epoch 76/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.9790 - val_loss: 5.5526
# Epoch 77/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 5.0780 - val_loss: 5.5486
# Epoch 78/1000
# 25/25 [==============================] - 1s 20ms/step - loss: 5.0115 - val_loss: 5.5446
# Epoch 79/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.0354 - val_loss: 5.5405
# Epoch 80/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.0312 - val_loss: 5.5366
# Epoch 81/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 5.0122 - val_loss: 5.5326
# Epoch 82/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.9881 - val_loss: 5.5284
# Epoch 83/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.9767 - val_loss: 5.5245
# Epoch 84/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.9460 - val_loss: 5.5204
# Epoch 85/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9762 - val_loss: 5.5164
# Epoch 86/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9778 - val_loss: 5.5123
# Epoch 87/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8938 - val_loss: 5.5085
# Epoch 88/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9181 - val_loss: 5.5043
# Epoch 89/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.9426 - val_loss: 5.5003
# Epoch 90/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9302 - val_loss: 5.4964
# Epoch 91/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8856 - val_loss: 5.4924
# Epoch 92/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9129 - val_loss: 5.4883
# Epoch 93/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9344 - val_loss: 5.4843
# Epoch 94/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.9043 - val_loss: 5.4803
# Epoch 95/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8410 - val_loss: 5.4763
# Epoch 96/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8743 - val_loss: 5.4723
# Epoch 97/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 4.9171 - val_loss: 5.4682
# Epoch 98/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.9017 - val_loss: 5.4642
# Epoch 99/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8580 - val_loss: 5.4603
# Epoch 100/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8668 - val_loss: 5.4562
# Epoch 101/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8640 - val_loss: 5.4524
# Epoch 102/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8667 - val_loss: 5.4482
# Epoch 103/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8822 - val_loss: 5.4442
# Epoch 104/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8006 - val_loss: 5.4403
# Epoch 105/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8085 - val_loss: 5.4361
# Epoch 106/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8660 - val_loss: 5.4321
# Epoch 107/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.8309 - val_loss: 5.4282
# Epoch 108/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8195 - val_loss: 5.4241
# Epoch 109/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8033 - val_loss: 5.4201
# Epoch 110/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8146 - val_loss: 5.4161
# Epoch 111/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7524 - val_loss: 5.4121
# Epoch 112/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7212 - val_loss: 5.4080
# Epoch 113/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8045 - val_loss: 5.4040
# Epoch 114/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.8109 - val_loss: 5.3999
# Epoch 115/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.7741 - val_loss: 5.3960
# Epoch 116/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7357 - val_loss: 5.3919
# Epoch 117/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 4.7141 - val_loss: 5.3879
# Epoch 118/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.7386 - val_loss: 5.3838
# Epoch 119/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.7441 - val_loss: 5.3799
# Epoch 120/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.7268 - val_loss: 5.3758
# Epoch 121/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.7654 - val_loss: 5.3718
# Epoch 122/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.7070 - val_loss: 5.3678
# Epoch 123/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.7242 - val_loss: 5.3637
# Epoch 124/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.7195 - val_loss: 5.3598
# Epoch 125/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7216 - val_loss: 5.3555
# Epoch 126/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.7021 - val_loss: 5.3515
# Epoch 127/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.6955 - val_loss: 5.3475
# Epoch 128/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7083 - val_loss: 5.3435
# Epoch 129/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.7041 - val_loss: 5.3395
# Epoch 130/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6972 - val_loss: 5.3354
# Epoch 131/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 4.6154 - val_loss: 5.3314
# Epoch 132/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6570 - val_loss: 5.3272
# Epoch 133/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6605 - val_loss: 5.3230
# Epoch 134/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6290 - val_loss: 5.3192
# Epoch 135/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6678 - val_loss: 5.3151
# Epoch 136/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6122 - val_loss: 5.3109
# Epoch 137/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.6595 - val_loss: 5.3068
# Epoch 138/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6501 - val_loss: 5.3027
# Epoch 139/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6305 - val_loss: 5.2986
# Epoch 140/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.6347 - val_loss: 5.2945
# Epoch 141/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5563 - val_loss: 5.2905
# Epoch 142/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5676 - val_loss: 5.2863
# Epoch 143/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.5902 - val_loss: 5.2822
# Epoch 144/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5936 - val_loss: 5.2781
# Epoch 145/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6307 - val_loss: 5.2740
# Epoch 146/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.6032 - val_loss: 5.2699
# Epoch 147/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.5299 - val_loss: 5.2658
# Epoch 148/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5065 - val_loss: 5.2617
# Epoch 149/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5641 - val_loss: 5.2575
# Epoch 150/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.5601 - val_loss: 5.2534
# Epoch 151/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.5426 - val_loss: 5.2492
# Epoch 152/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4711 - val_loss: 5.2451
# Epoch 153/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.5476 - val_loss: 5.2409
# Epoch 154/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4627 - val_loss: 5.2369
# Epoch 155/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.4912 - val_loss: 5.2326
# Epoch 156/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.5505 - val_loss: 5.2285
# Epoch 157/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4564 - val_loss: 5.2243
# Epoch 158/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4975 - val_loss: 5.2202
# Epoch 159/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.5217 - val_loss: 5.2159
# Epoch 160/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.4878 - val_loss: 5.2116
# Epoch 161/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4810 - val_loss: 5.2075
# Epoch 162/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4961 - val_loss: 5.2032
# Epoch 163/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.4729 - val_loss: 5.1992
# Epoch 164/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.4489 - val_loss: 5.1950
# Epoch 165/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4682 - val_loss: 5.1907
# Epoch 166/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4309 - val_loss: 5.1865
# Epoch 167/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4456 - val_loss: 5.1823
# Epoch 168/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.3643 - val_loss: 5.1781
# Epoch 169/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.4051 - val_loss: 5.1738
# Epoch 170/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.4165 - val_loss: 5.1696
# Epoch 171/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3978 - val_loss: 5.1653
# Epoch 172/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.4182 - val_loss: 5.1610
# Epoch 173/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3936 - val_loss: 5.1569
# Epoch 174/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 4.3960 - val_loss: 5.1526
# Epoch 175/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 4.3923 - val_loss: 5.1483
# Epoch 176/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.4013 - val_loss: 5.1440
# Epoch 177/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3929 - val_loss: 5.1397
# Epoch 178/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.4072 - val_loss: 5.1353
# Epoch 179/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.3848 - val_loss: 5.1311
# Epoch 180/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.3648 - val_loss: 5.1267
# Epoch 181/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.3247 - val_loss: 5.1226
# Epoch 182/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 4.3235 - val_loss: 5.1182
# Epoch 183/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3037 - val_loss: 5.1140
# Epoch 184/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3481 - val_loss: 5.1095
# Epoch 185/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.3053 - val_loss: 5.1052
# Epoch 186/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3128 - val_loss: 5.1009
# Epoch 187/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.3074 - val_loss: 5.0965
# Epoch 188/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3128 - val_loss: 5.0921
# Epoch 189/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.3194 - val_loss: 5.0878
# Epoch 190/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 4.2826 - val_loss: 5.0833
# Epoch 191/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.3090 - val_loss: 5.0790
# Epoch 192/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2812 - val_loss: 5.0746
# Epoch 193/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.2706 - val_loss: 5.0702
# Epoch 194/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.2476 - val_loss: 5.0658
# Epoch 195/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2285 - val_loss: 5.0614
# Epoch 196/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2687 - val_loss: 5.0570
# Epoch 197/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2683 - val_loss: 5.0525
# Epoch 198/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.2452 - val_loss: 5.0481
# Epoch 199/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.2106 - val_loss: 5.0438
# Epoch 200/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.2532 - val_loss: 5.0392
# Epoch 201/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2366 - val_loss: 5.0347
# Epoch 202/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2087 - val_loss: 5.0302
# Epoch 203/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2089 - val_loss: 5.0258
# Epoch 204/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.2365 - val_loss: 5.0212
# Epoch 205/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1861 - val_loss: 5.0168
# Epoch 206/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.2035 - val_loss: 5.0123
# Epoch 207/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 4.2037 - val_loss: 5.0076
# Epoch 208/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 4.1625 - val_loss: 5.0033
# Epoch 209/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1655 - val_loss: 4.9988
# Epoch 210/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1451 - val_loss: 4.9941
# Epoch 211/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1947 - val_loss: 4.9896
# Epoch 212/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 4.1573 - val_loss: 4.9850
# Epoch 213/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.1004 - val_loss: 4.9805
# Epoch 214/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.1494 - val_loss: 4.9758
# Epoch 215/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.1405 - val_loss: 4.9712
# Epoch 216/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1354 - val_loss: 4.9667
# Epoch 217/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0957 - val_loss: 4.9620
# Epoch 218/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0816 - val_loss: 4.9574
# Epoch 219/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.1254 - val_loss: 4.9528
# Epoch 220/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0616 - val_loss: 4.9482
# Epoch 221/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.1044 - val_loss: 4.9435
# Epoch 222/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 4.0820 - val_loss: 4.9388
# Epoch 223/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0790 - val_loss: 4.9342
# Epoch 224/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0264 - val_loss: 4.9295
# Epoch 225/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0714 - val_loss: 4.9247
# Epoch 226/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0241 - val_loss: 4.9200
# Epoch 227/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0827 - val_loss: 4.9153
# Epoch 228/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0507 - val_loss: 4.9106
# Epoch 229/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0437 - val_loss: 4.9059
# Epoch 230/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 4.0029 - val_loss: 4.9013
# Epoch 231/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9896 - val_loss: 4.8964
# Epoch 232/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9839 - val_loss: 4.8916
# Epoch 233/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 4.0366 - val_loss: 4.8869
# Epoch 234/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0155 - val_loss: 4.8821
# Epoch 235/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.9727 - val_loss: 4.8774
# Epoch 236/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.0036 - val_loss: 4.8725
# Epoch 237/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9369 - val_loss: 4.8677
# Epoch 238/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.9580 - val_loss: 4.8628
# Epoch 239/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.9397 - val_loss: 4.8580
# Epoch 240/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.9231 - val_loss: 4.8533
# Epoch 241/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9459 - val_loss: 4.8484
# Epoch 242/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9308 - val_loss: 4.8434
# Epoch 243/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9276 - val_loss: 4.8384
# Epoch 244/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9411 - val_loss: 4.8336
# Epoch 245/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.9434 - val_loss: 4.8288
# Epoch 246/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.8729 - val_loss: 4.8239
# Epoch 247/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9090 - val_loss: 4.8189
# Epoch 248/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.9232 - val_loss: 4.8139
# Epoch 249/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.8990 - val_loss: 4.8089
# Epoch 250/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.8934 - val_loss: 4.8039
# Epoch 251/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.8467 - val_loss: 4.7990
# Epoch 252/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.8963 - val_loss: 4.7939
# Epoch 253/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7838 - val_loss: 4.7890
# Epoch 254/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.8819 - val_loss: 4.7840
# Epoch 255/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.8086 - val_loss: 4.7789
# Epoch 256/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.8522 - val_loss: 4.7738
# Epoch 257/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.8291 - val_loss: 4.7687
# Epoch 258/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.8243 - val_loss: 4.7637
# Epoch 259/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.8451 - val_loss: 4.7586
# Epoch 260/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.8370 - val_loss: 4.7536
# Epoch 261/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.8016 - val_loss: 4.7486
# Epoch 262/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7559 - val_loss: 4.7434
# Epoch 263/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.7903 - val_loss: 4.7382
# Epoch 264/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7833 - val_loss: 4.7332
# Epoch 265/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.7778 - val_loss: 4.7279
# Epoch 266/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7722 - val_loss: 4.7227
# Epoch 267/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7076 - val_loss: 4.7176
# Epoch 268/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7729 - val_loss: 4.7123
# Epoch 269/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7847 - val_loss: 4.7071
# Epoch 270/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7566 - val_loss: 4.7020
# Epoch 271/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7187 - val_loss: 4.6966
# Epoch 272/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.7396 - val_loss: 4.6913
# Epoch 273/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7450 - val_loss: 4.6861
# Epoch 274/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.6705 - val_loss: 4.6807
# Epoch 275/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.7389 - val_loss: 4.6755
# Epoch 276/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.6654 - val_loss: 4.6703
# Epoch 277/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.6910 - val_loss: 4.6649
# Epoch 278/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.7147 - val_loss: 4.6595
# Epoch 279/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.6127 - val_loss: 4.6541
# Epoch 280/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.6808 - val_loss: 4.6488
# Epoch 281/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.6833 - val_loss: 4.6434
# Epoch 282/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.6892 - val_loss: 4.6380
# Epoch 283/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.6374 - val_loss: 4.6326
# Epoch 284/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.6389 - val_loss: 4.6272
# Epoch 285/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.6775 - val_loss: 4.6217
# Epoch 286/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.6261 - val_loss: 4.6164
# Epoch 287/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.6426 - val_loss: 4.6109
# Epoch 288/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.6246 - val_loss: 4.6054
# Epoch 289/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.5949 - val_loss: 4.5997
# Epoch 290/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.6111 - val_loss: 4.5942
# Epoch 291/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.5861 - val_loss: 4.5889
# Epoch 292/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.5778 - val_loss: 4.5832
# Epoch 293/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.5718 - val_loss: 4.5777
# Epoch 294/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.5808 - val_loss: 4.5720
# Epoch 295/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.5378 - val_loss: 4.5667
# Epoch 296/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.5712 - val_loss: 4.5609
# Epoch 297/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.5702 - val_loss: 4.5552
# Epoch 298/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.5549 - val_loss: 4.5495
# Epoch 299/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.5552 - val_loss: 4.5439
# Epoch 300/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.5118 - val_loss: 4.5383
# Epoch 301/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 3.5229 - val_loss: 4.5327
# Epoch 302/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.5156 - val_loss: 4.5267
# Epoch 303/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4687 - val_loss: 4.5212
# Epoch 304/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4545 - val_loss: 4.5156
# Epoch 305/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.5093 - val_loss: 4.5097
# Epoch 306/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.4266 - val_loss: 4.5041
# Epoch 307/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4354 - val_loss: 4.4983
# Epoch 308/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4786 - val_loss: 4.4925
# Epoch 309/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.4276 - val_loss: 4.4867
# Epoch 310/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.4393 - val_loss: 4.4808
# Epoch 311/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.4215 - val_loss: 4.4750
# Epoch 312/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4353 - val_loss: 4.4692
# Epoch 313/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4490 - val_loss: 4.4632
# Epoch 314/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.3665 - val_loss: 4.4573
# Epoch 315/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.3713 - val_loss: 4.4516
# Epoch 316/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.3699 - val_loss: 4.4457
# Epoch 317/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.3802 - val_loss: 4.4396
# Epoch 318/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.4223 - val_loss: 4.4335
# Epoch 319/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.3432 - val_loss: 4.4276
# Epoch 320/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.3449 - val_loss: 4.4218
# Epoch 321/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.3460 - val_loss: 4.4157
# Epoch 322/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.3427 - val_loss: 4.4097
# Epoch 323/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.3279 - val_loss: 4.4037
# Epoch 324/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.3279 - val_loss: 4.3976
# Epoch 325/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.3280 - val_loss: 4.3916
# Epoch 326/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.3403 - val_loss: 4.3854
# Epoch 327/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.3297 - val_loss: 4.3793
# Epoch 328/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2762 - val_loss: 4.3733
# Epoch 329/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2776 - val_loss: 4.3670
# Epoch 330/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2660 - val_loss: 4.3609
# Epoch 331/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2715 - val_loss: 4.3548
# Epoch 332/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2470 - val_loss: 4.3487
# Epoch 333/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2712 - val_loss: 4.3424
# Epoch 334/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2633 - val_loss: 4.3362
# Epoch 335/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2178 - val_loss: 4.3300
# Epoch 336/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2775 - val_loss: 4.3237
# Epoch 337/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 3.2071 - val_loss: 4.3176
# Epoch 338/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2564 - val_loss: 4.3113
# Epoch 339/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1936 - val_loss: 4.3051
# Epoch 340/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.1981 - val_loss: 4.2987
# Epoch 341/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.2077 - val_loss: 4.2924
# Epoch 342/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 3.1825 - val_loss: 4.2860
# Epoch 343/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1770 - val_loss: 4.2796
# Epoch 344/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.2205 - val_loss: 4.2733
# Epoch 345/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.1387 - val_loss: 4.2669
# Epoch 346/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1633 - val_loss: 4.2604
# Epoch 347/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1321 - val_loss: 4.2542
# Epoch 348/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1535 - val_loss: 4.2477
# Epoch 349/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.1582 - val_loss: 4.2414
# Epoch 350/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 3.1663 - val_loss: 4.2347
# Epoch 351/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.1485 - val_loss: 4.2283
# Epoch 352/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.1446 - val_loss: 4.2216
# Epoch 353/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.1112 - val_loss: 4.2154
# Epoch 354/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.1174 - val_loss: 4.2089
# Epoch 355/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.0817 - val_loss: 4.2023
# Epoch 356/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 3.0931 - val_loss: 4.1958
# Epoch 357/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.1026 - val_loss: 4.1893
# Epoch 358/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.0327 - val_loss: 4.1828
# Epoch 359/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.0958 - val_loss: 4.1760
# Epoch 360/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0294 - val_loss: 4.1693
# Epoch 361/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0376 - val_loss: 4.1629
# Epoch 362/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.0488 - val_loss: 4.1560
# Epoch 363/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 3.0252 - val_loss: 4.1496
# Epoch 364/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0026 - val_loss: 4.1427
# Epoch 365/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 3.0363 - val_loss: 4.1360
# Epoch 366/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0164 - val_loss: 4.1295
# Epoch 367/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0121 - val_loss: 4.1227
# Epoch 368/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0005 - val_loss: 4.1160
# Epoch 369/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 3.0042 - val_loss: 4.1094
# Epoch 370/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.9779 - val_loss: 4.1025
# Epoch 371/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.9720 - val_loss: 4.0957
# Epoch 372/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 2.9515 - val_loss: 4.0890
# Epoch 373/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.9574 - val_loss: 4.0821
# Epoch 374/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.9536 - val_loss: 4.0753
# Epoch 375/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.9163 - val_loss: 4.0687
# Epoch 376/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 2.8885 - val_loss: 4.0618
# Epoch 377/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.9177 - val_loss: 4.0548
# Epoch 378/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.8734 - val_loss: 4.0480
# Epoch 379/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.8888 - val_loss: 4.0411
# Epoch 380/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8642 - val_loss: 4.0344
# Epoch 381/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8671 - val_loss: 4.0274
# Epoch 382/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8546 - val_loss: 4.0205
# Epoch 383/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8215 - val_loss: 4.0135
# Epoch 384/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8438 - val_loss: 4.0065
# Epoch 385/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8056 - val_loss: 3.9996
# Epoch 386/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8153 - val_loss: 3.9926
# Epoch 387/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 2.7968 - val_loss: 3.9856
# Epoch 388/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8211 - val_loss: 3.9786
# Epoch 389/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8264 - val_loss: 3.9716
# Epoch 390/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.8238 - val_loss: 3.9645
# Epoch 391/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.7851 - val_loss: 3.9575
# Epoch 392/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.7543 - val_loss: 3.9503
# Epoch 393/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.7707 - val_loss: 3.9432
# Epoch 394/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.7596 - val_loss: 3.9362
# Epoch 395/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 2.7776 - val_loss: 3.9291
# Epoch 396/1000
# 25/25 [==============================] - 1s 20ms/step - loss: 2.7268 - val_loss: 3.9220
# Epoch 397/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.7474 - val_loss: 3.9150
# Epoch 398/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.7069 - val_loss: 3.9078
# Epoch 399/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.7247 - val_loss: 3.9004
# Epoch 400/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.7373 - val_loss: 3.8933
# Epoch 401/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.7026 - val_loss: 3.8861
# Epoch 402/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.6596 - val_loss: 3.8790
# Epoch 403/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.7029 - val_loss: 3.8718
# Epoch 404/1000
# 25/25 [==============================] - 1s 21ms/step - loss: 2.6252 - val_loss: 3.8645
# Epoch 405/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 2.6910 - val_loss: 3.8571
# Epoch 406/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.6845 - val_loss: 3.8500
# Epoch 407/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.6671 - val_loss: 3.8429
# Epoch 408/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.6564 - val_loss: 3.8355
# Epoch 409/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.6470 - val_loss: 3.8283
# Epoch 410/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.5996 - val_loss: 3.8211
# Epoch 411/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.6245 - val_loss: 3.8136
# Epoch 412/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.5935 - val_loss: 3.8065
# Epoch 413/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 2.6111 - val_loss: 3.7991
# Epoch 414/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.6074 - val_loss: 3.7917
# Epoch 415/1000
# 25/25 [==============================] - 1s 22ms/step - loss: 2.5568 - val_loss: 3.7844
# Epoch 416/1000
# 25/25 [==============================] - 1s 21ms/step - loss: 2.5941 - val_loss: 3.7770
# Epoch 417/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 2.5615 - val_loss: 3.7698
# Epoch 418/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.5446 - val_loss: 3.7624
# Epoch 419/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.5678 - val_loss: 3.7550
# Epoch 420/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.5586 - val_loss: 3.7475
# Epoch 421/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.5271 - val_loss: 3.7402
# Epoch 422/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.5199 - val_loss: 3.7327
# Epoch 423/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.5292 - val_loss: 3.7254
# Epoch 424/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 2.5117 - val_loss: 3.7180
# Epoch 425/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.5214 - val_loss: 3.7105
# Epoch 426/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.4778 - val_loss: 3.7030
# Epoch 427/1000
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4892 - val_loss: 3.6955
# Epoch 428/1000
# 25/25 [==============================] - 0s 20ms/step - loss: 2.4341 - val_loss: 3.6881
# Epoch 429/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.4614 - val_loss: 3.6808
# Epoch 430/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.4944 - val_loss: 3.6730
# Epoch 431/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.4409 - val_loss: 3.6657
# Epoch 432/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.4593 - val_loss: 3.6580
# Epoch 433/1000
# 25/25 [==============================] - 1s 21ms/step - loss: 2.4631 - val_loss: 3.6506
# Epoch 434/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.4202 - val_loss: 3.6432
# Epoch 435/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.4182 - val_loss: 3.6356
# Epoch 436/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.4144 - val_loss: 3.6281
# Epoch 437/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3762 - val_loss: 3.6206
# Epoch 438/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.3706 - val_loss: 3.6129
# Epoch 439/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 2.4139 - val_loss: 3.6053
# Epoch 440/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.3700 - val_loss: 3.5979
# Epoch 441/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3694 - val_loss: 3.5904
# Epoch 442/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.3560 - val_loss: 3.5826
# Epoch 443/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3343 - val_loss: 3.5751
# Epoch 444/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3459 - val_loss: 3.5676
# Epoch 445/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3401 - val_loss: 3.5598
# Epoch 446/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.3325 - val_loss: 3.5523
# Epoch 447/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.3263 - val_loss: 3.5447
# Epoch 448/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.2924 - val_loss: 3.5371
# Epoch 449/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.2990 - val_loss: 3.5294
# Epoch 450/1000
# 25/25 [==============================] - 0s 14ms/step - loss: 2.3075 - val_loss: 3.5216
# Epoch 451/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2787 - val_loss: 3.5141
# Epoch 452/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2742 - val_loss: 3.5065
# Epoch 453/1000
# 25/25 [==============================] - 0s 15ms/step - loss: 2.2623 - val_loss: 3.4988
# Epoch 454/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.2440 - val_loss: 3.4910
# Epoch 455/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2246 - val_loss: 3.4837
# Epoch 456/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2015 - val_loss: 3.4759
# Epoch 457/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 2.2436 - val_loss: 3.4683
# Epoch 458/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2310 - val_loss: 3.4606
# Epoch 459/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 2.2020 - val_loss: 3.4528
# Epoch 460/1000
# ...
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0327 - val_loss: 1.0922
# Epoch 848/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0250 - val_loss: 1.0888
# Epoch 849/1000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0141 - val_loss: 1.0855
# Epoch 850/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0034 - val_loss: 1.0824
# Epoch 851/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0127 - val_loss: 1.0791
# Epoch 852/1000
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 1.0758
# Epoch 853/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0108 - val_loss: 1.0727
# Epoch 854/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0120 - val_loss: 1.0696
# Epoch 855/1000
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0026 - val_loss: 1.0665
# Epoch 856/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0127 - val_loss: 1.0632
# Epoch 857/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0198 - val_loss: 1.0602
# Epoch 858/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 8.7791e-04 - val_loss: 1.0570
# Epoch 859/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0240 - val_loss: 1.0538
# Epoch 860/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0109 - val_loss: 1.0506
# Epoch 861/1000
# 25/25 [==============================] - 0s 17ms/step - loss: 2.0298e-04 - val_loss: 1.0477
# Epoch 862/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0165 - val_loss: 1.0448
# Epoch 863/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.0181 - val_loss: 1.0415
# Epoch 864/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0273 - val_loss: 1.0384
# Epoch 865/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0347 - val_loss: 1.0354
# Epoch 866/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0152 - val_loss: 1.0324
# Epoch 867/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0320 - val_loss: 1.0295
# Epoch 868/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0362 - val_loss: 1.0263
# Epoch 869/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0386 - val_loss: 1.0234
# Epoch 870/1000
# 25/25 [==============================] - 1s 21ms/step - loss: -0.0318 - val_loss: 1.0205
# Epoch 871/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0379 - val_loss: 1.0174
# Epoch 872/1000
# 25/25 [==============================] - 0s 15ms/step - loss: -0.0207 - val_loss: 1.0144
# Epoch 873/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0462 - val_loss: 1.0118
# Epoch 874/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.0439 - val_loss: 1.0087
# Epoch 875/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0527 - val_loss: 1.0059
# Epoch 876/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0521 - val_loss: 1.0030
# Epoch 877/1000
# 25/25 [==============================] - 0s 15ms/step - loss: -0.0435 - val_loss: 1.0001
# Epoch 878/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.0420 - val_loss: 0.9971
# Epoch 879/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0646 - val_loss: 0.9943
# Epoch 880/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0708 - val_loss: 0.9913
# Epoch 881/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0750 - val_loss: 0.9887
# Epoch 882/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0542 - val_loss: 0.9858
# Epoch 883/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0657 - val_loss: 0.9830
# Epoch 884/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0563 - val_loss: 0.9802
# Epoch 885/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0622 - val_loss: 0.9773
# Epoch 886/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0694 - val_loss: 0.9746
# Epoch 887/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0823 - val_loss: 0.9719
# Epoch 888/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0836 - val_loss: 0.9691
# Epoch 889/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0777 - val_loss: 0.9663
# Epoch 890/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0768 - val_loss: 0.9635
# Epoch 891/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0817 - val_loss: 0.9608
# Epoch 892/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0782 - val_loss: 0.9581
# Epoch 893/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0874 - val_loss: 0.9554
# Epoch 894/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0772 - val_loss: 0.9527
# Epoch 895/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.0849 - val_loss: 0.9501
# Epoch 896/1000
# 25/25 [==============================] - 0s 20ms/step - loss: -0.0909 - val_loss: 0.9474
# Epoch 897/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.0886 - val_loss: 0.9447
# Epoch 898/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0983 - val_loss: 0.9420
# Epoch 899/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1047 - val_loss: 0.9396
# Epoch 900/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1046 - val_loss: 0.9368
# Epoch 901/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1018 - val_loss: 0.9342
# Epoch 902/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1006 - val_loss: 0.9316
# Epoch 903/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1007 - val_loss: 0.9289
# Epoch 904/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.0936 - val_loss: 0.9263
# Epoch 905/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1084 - val_loss: 0.9238
# Epoch 906/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1020 - val_loss: 0.9212
# Epoch 907/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1297 - val_loss: 0.9187
# Epoch 908/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1136 - val_loss: 0.9162
# Epoch 909/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1198 - val_loss: 0.9137
# Epoch 910/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1355 - val_loss: 0.9112
# Epoch 911/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1265 - val_loss: 0.9085
# Epoch 912/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.1397 - val_loss: 0.9062
# Epoch 913/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1490 - val_loss: 0.9037
# Epoch 914/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1344 - val_loss: 0.9012
# Epoch 915/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1200 - val_loss: 0.8989
# Epoch 916/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1438 - val_loss: 0.8964
# Epoch 917/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1392 - val_loss: 0.8939
# Epoch 918/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.1354 - val_loss: 0.8914
# Epoch 919/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1404 - val_loss: 0.8893
# Epoch 920/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1319 - val_loss: 0.8868
# Epoch 921/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1455 - val_loss: 0.8843
# Epoch 922/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1555 - val_loss: 0.8819
# Epoch 923/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1450 - val_loss: 0.8795
# Epoch 924/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1522 - val_loss: 0.8772
# Epoch 925/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1409 - val_loss: 0.8748
# Epoch 926/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1386 - val_loss: 0.8724
# Epoch 927/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1483 - val_loss: 0.8700
# Epoch 928/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1519 - val_loss: 0.8677
# Epoch 929/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1613 - val_loss: 0.8655
# Epoch 930/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1547 - val_loss: 0.8633
# Epoch 931/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1684 - val_loss: 0.8610
# Epoch 932/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1481 - val_loss: 0.8585
# Epoch 933/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1553 - val_loss: 0.8563
# Epoch 934/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1635 - val_loss: 0.8539
# Epoch 935/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1808 - val_loss: 0.8518
# Epoch 936/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1794 - val_loss: 0.8496
# Epoch 937/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1622 - val_loss: 0.8472
# Epoch 938/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.1665 - val_loss: 0.8450
# Epoch 939/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1817 - val_loss: 0.8428
# Epoch 940/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1698 - val_loss: 0.8405
# Epoch 941/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.1637 - val_loss: 0.8383
# Epoch 942/1000
# 25/25 [==============================] - 1s 22ms/step - loss: -0.1974 - val_loss: 0.8363
# Epoch 943/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.1765 - val_loss: 0.8341
# Epoch 944/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1831 - val_loss: 0.8318
# Epoch 945/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1993 - val_loss: 0.8296
# Epoch 946/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.1803 - val_loss: 0.8276
# Epoch 947/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1955 - val_loss: 0.8254
# Epoch 948/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1822 - val_loss: 0.8232
# Epoch 949/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.1854 - val_loss: 0.8210
# Epoch 950/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2018 - val_loss: 0.8189
# Epoch 951/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.1823 - val_loss: 0.8169
# Epoch 952/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1954 - val_loss: 0.8148
# Epoch 953/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.1934 - val_loss: 0.8127
# Epoch 954/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1982 - val_loss: 0.8105
# Epoch 955/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.2064 - val_loss: 0.8086
# Epoch 956/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2082 - val_loss: 0.8065
# Epoch 957/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.1962 - val_loss: 0.8042
# Epoch 958/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2009 - val_loss: 0.8023
# Epoch 959/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2149 - val_loss: 0.8002
# Epoch 960/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2102 - val_loss: 0.7982
# Epoch 961/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2052 - val_loss: 0.7961
# Epoch 962/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2149 - val_loss: 0.7942
# Epoch 963/1000
# 25/25 [==============================] - 1s 22ms/step - loss: -0.2066 - val_loss: 0.7921
# Epoch 964/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2207 - val_loss: 0.7901
# Epoch 965/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.2309 - val_loss: 0.7881
# Epoch 966/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2094 - val_loss: 0.7861
# Epoch 967/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2161 - val_loss: 0.7843
# Epoch 968/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2219 - val_loss: 0.7823
# Epoch 969/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2288 - val_loss: 0.7802
# Epoch 970/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.2254 - val_loss: 0.7782
# Epoch 971/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2433 - val_loss: 0.7763
# Epoch 972/1000
# 25/25 [==============================] - 0s 20ms/step - loss: -0.2374 - val_loss: 0.7744
# Epoch 973/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2286 - val_loss: 0.7724
# Epoch 974/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2374 - val_loss: 0.7705
# Epoch 975/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2494 - val_loss: 0.7687
# Epoch 976/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2209 - val_loss: 0.7668
# Epoch 977/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2293 - val_loss: 0.7647
# Epoch 978/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2475 - val_loss: 0.7630
# Epoch 979/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2484 - val_loss: 0.7612
# Epoch 980/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2454 - val_loss: 0.7591
# Epoch 981/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2469 - val_loss: 0.7573
# Epoch 982/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2404 - val_loss: 0.7555
# Epoch 983/1000
# 25/25 [==============================] - 1s 20ms/step - loss: -0.2397 - val_loss: 0.7535
# Epoch 984/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2537 - val_loss: 0.7517
# Epoch 985/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2561 - val_loss: 0.7499
# Epoch 986/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2534 - val_loss: 0.7480
# Epoch 987/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2547 - val_loss: 0.7463
# Epoch 988/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2516 - val_loss: 0.7444
# Epoch 989/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2555 - val_loss: 0.7427
# Epoch 990/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2469 - val_loss: 0.7409
# Epoch 991/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2640 - val_loss: 0.7390
# Epoch 992/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2684 - val_loss: 0.7372
# Epoch 993/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2581 - val_loss: 0.7356
# Epoch 994/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2690 - val_loss: 0.7338
# Epoch 995/1000
# 25/25 [==============================] - 0s 19ms/step - loss: -0.2615 - val_loss: 0.7319
# Epoch 996/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2571 - val_loss: 0.7302
# Epoch 997/1000
# 25/25 [==============================] - 0s 17ms/step - loss: -0.2629 - val_loss: 0.7286
# Epoch 998/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2689 - val_loss: 0.7266
# Epoch 999/1000
# 25/25 [==============================] - 0s 18ms/step - loss: -0.2729 - val_loss: 0.7250
# Epoch 1000/1000
# 25/25 [==============================] - 0s 16ms/step - loss: -0.2847 - val_loss: 0.7232

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
##그래프저장
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 31), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# 포트폴리오 수익률 (연간):
# crp_rtn      0.072127
# lstm_rtn     0.037553
# sp500_rtn    0.022451
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.022594
# lstm_rtn     0.012480
# sp500_rtn    0.047066
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      3.192322
# lstm_rtn     3.009150
# sp500_rtn    0.477018
# dtype: float64

# %% [markdown]
# ## 가중치 DF 저장 (일자별)

# %%
w_hist_lstm = []
for i in range(0, xc_test.shape[0]):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)

# %%
idx = np.arange(0, len(test_date))
date=test_date[idx]

# %%
len(w_hist_lstm)
# Out:
# 1250

# %%
W_df=pd.DataFrame(w_hist_lstm[:-1],columns=rtn_df.columns,index=list(date)[20:])
W_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 2017-07-17  0.343385  0.312667  0.111111  0.057498  0.068967  0.053228
# 2017-07-18  0.341318  0.308126  0.114742  0.060143  0.068597  0.053166
# 2017-07-19  0.344971  0.308407  0.107130  0.061742  0.068234  0.054351
# 2017-07-20  0.345693  0.309623  0.106365  0.060371  0.069507  0.054186
# 2017-07-21  0.343663  0.310796  0.112430  0.057718  0.069285  0.053055
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.341134  0.308546  0.114146  0.059134  0.069635  0.053625
# 2022-05-05  0.341920  0.308094  0.113916  0.057683  0.072954  0.053126
# 2022-05-06  0.349253  0.315712  0.098672  0.058079  0.068443  0.055076
# 2022-05-09  0.343548  0.312199  0.112139  0.055299  0.071067  0.053298
# 2022-05-10  0.344017  0.310993  0.110045  0.057135  0.070735  0.053903
#
#                nsd로그
# 2017-07-17  0.053144
# 2017-07-18  0.053908
# 2017-07-19  0.055165
# 2017-07-20  0.054255
# 2017-07-21  0.053053
# ...              ...
# 2022-05-04  0.053780
# 2022-05-05  0.052306
# 2022-05-06  0.054765
# 2022-05-09  0.052450
# 2022-05-10  0.053173
#
# [1249 rows x 7 columns]

# %%
W_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치(일자별).csv")

# %% [markdown]
# # 타 펀드 비교(KB)

# %%
kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
kb.일자=pd.to_datetime(kb.일자)
kb=kb.set_index('일자')
#일자설정
kb=kb.loc[perf_df.index[0]:perf_df.index[-1]]
kb['금액']=10000
kb['수익률(%)']=kb['수익률(%)']*0.01
for i in range(1,kb.shape[0]):
    kb.iloc[i,1]=kb.iloc[i,0]*kb.iloc[i-1,1]+kb.iloc[i-1,1]
p_df=perf_df.copy()
p_df=p_df.reset_index()
kb=kb.reset_index()
grp=pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')
grp=grp.set_index('Date')
grp=grp[['crp', 'lstm_markowitz', 'kospi', '금액']]
grp.columns=['crp', 'lstm_markowitz', 'kospi', 'KB펀드']
grp=grp.dropna()

# %% [markdown]
# # 타 펀드 비교 <미래에셋>

# %%
fa=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/미래에셋.csv")
fa=fa.T
fa=fa.iloc[1:]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
fa=fa.set_index('index')
fa.columns=['투자수익률','비교지수']
fa['미래에셋']=fa['투자수익률']*0.01*10000+10000
fa['미래에셋_pct']=fa['미래에셋'].pct_change(1)
#일자설정
fa=fa.loc[perf_df.index[0]:perf_df.index[-1]]
fa['미래에셋']=10000
for i in range(1,fa.shape[0]):
    fa.iloc[i,2]=fa.iloc[i,3]*fa.iloc[i-1,2]+fa.iloc[i-1,2]
fa=fa.reset_index()
fa['index']=pd.to_datetime(fa['index'])
grp=pd.merge(grp.reset_index(),fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
grp=grp[['Date','lstm_markowitz','kospi','미래에셋','KB펀드']]
grp=grp.dropna()
grp=grp.set_index('Date')

# %% [markdown]
# # 차트 이미지 저장

# %%
p = grp.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()

# %% [markdown]
# # 주식 전략 결합

# %%
log_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
log_df = log_df.set_index('Date')
log_df = log_df.loc[:'2019-10-31']

# %%
log_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2019-10-25  0.000004 -0.001182  0.001069  0.002085  0.005782 -0.008568
# 2019-10-28  0.000081 -0.002041  0.002731 -0.009069 -0.003851 -0.006074
# 2019-10-29  0.000023  0.001165 -0.000435 -0.003510 -0.001931  0.006074
# 2019-10-30  0.000061  0.000579 -0.005953  0.007008 -0.006464  0.003605
# 2019-10-31  0.000025  0.000157  0.001542  0.009729 -0.005854 -0.001801
#
#                nsd로그  상승          코스피
# Date
# 2006-03-01 -0.000493   0  1371.589966
# 2006-03-02 -0.012176   0  1367.699951
# 2006-03-03  0.017103   0  1328.949951
# 2006-03-06 -0.018103   0  1344.760010
# 2006-03-07 -0.043212   0  1316.670044
# ...              ...  ..          ...
# 2019-10-25 -0.025676   0  2087.889893
# 2019-10-28  0.003043   0  2093.600098
# 2019-10-29 -0.000912   0  2092.689941
# 2019-10-30  0.014293   0  2080.270020
# 2019-10-31 -0.002902   0  2083.479980
#
# [3543 rows x 9 columns]

# %%
log_df = log_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그',
       'vnq로그', 'nsd로그']]

# %%
log_df.to_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/log데이터셋.csv")

# %%
log_df = pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/log데이터셋.csv")

# %%
log_df['Date']=pd.to_datetime(log_df['Date'])

# %%
log_df.columns
# Out:
# Index(['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그'], dtype='object')

# %%
r_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/주식전략/로그수익률전체_10종목.csv")

# %%
r_df=r_df.fillna(0)

# %%
r_df.columns
# Out:
# Index(['Unnamed: 0', '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
#        '성장성기법', '수익성기법', '시장가치기법', '활동성기법'],
#       dtype='object')

# %%
r_df['Unnamed: 0']=pd.to_datetime(r_df['Unnamed: 0'])
r_df.columns=['Date', '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']

# %% [markdown]
# ## 극안전형

# %%
극안전형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/극안전형.csv")
안전추구형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/안전추구형.csv")
위험중립형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/위험중립형.csv")
적극투자형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/적극투자형.csv")
공격투자형=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/비중DF/투자유형비중총결합/공격투자형.csv")

# %%
극안전형 = 극안전형.drop('Unnamed: 0', axis=1)
극안전형.columns = ['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']

# %%
극안전형
# Out:
#            Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 0    2019-11-01  0.357846  0.350863  0.062167  0.075185  0.050869  0.051566
# 1    2019-11-04  0.355070  0.349667  0.060141  0.084932  0.049446  0.050332
# 2    2019-11-05  0.354140  0.348552  0.058575  0.088817  0.049258  0.050139
# 3    2019-11-06  0.357363  0.350958  0.059128  0.081139  0.049868  0.050622
# 4    2019-11-07  0.357707  0.352224  0.059453  0.079134  0.049905  0.050711
# ..          ...       ...       ...       ...       ...       ...       ...
# 649  2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 650  2022-05-05  0.321733  0.328054  0.062213  0.138679  0.047262  0.050574
# 651  2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 652  2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 653  2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#         nsd로그
# 0    0.051505
# 1    0.050412
# 2    0.050519
# 3    0.050922
# 4    0.050866
# ..        ...
# 649  0.051183
# 650  0.051485
# 651  0.051133
# 652  0.051428
# 653  0.051980
#
# [654 rows x 8 columns]

# %%
극안전형.Date=pd.to_datetime(극안전형.Date)

# %%
극안전형_df=pd.concat([log_df,극안전형], axis=0)
극안전형_df
# Out:
#           Date     단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# 0   2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 1   2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2   2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 3   2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 4   2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ..         ...       ...       ...       ...       ...       ...       ...
# 649 2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 650 2022-05-05  0.321733  0.328054  0.062213  0.138679  0.047262  0.050574
# 651 2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 652 2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 653 2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#         nsd로그
# 0   -0.000493
# 1   -0.012176
# 2    0.017103
# 3   -0.018103
# 4   -0.043212
# ..        ...
# 649  0.051183
# 650  0.051485
# 651  0.051133
# 652  0.051428
# 653  0.051980
#
# [4197 rows x 8 columns]

# %%
#기간별로 정렬
극안전형_df=극안전형_df.sort_values(by=['Date'], ascending=True)

# %%
극안전형_df=극안전형_df.fillna(method='ffill').dropna()

# %%
극안전형_df=pd.merge(극안전형_df,r_df, on='Date', how='outer').dropna()

# %%
극안전형_df = 극안전형_df.set_index('Date')

# %%
극안전형_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# 2006-03-08  0.000203  0.000818 -0.001992 -0.019625 -0.016154  0.005173
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-03  0.330887  0.330873  0.062915  0.125514  0.047841  0.050911
# 2022-05-04  0.321213  0.324599  0.059282  0.146375  0.047149  0.050200
# 2022-05-06  0.341676  0.338979  0.058035  0.110634  0.048454  0.051089
# 2022-05-09  0.346246  0.340667  0.064234  0.096437  0.049179  0.051808
# 2022-05-10  0.351753  0.346155  0.061608  0.086404  0.049717  0.052384
#
#                nsd로그     유동성기법    레버리지기법    그레이엄기법      린치기법      버핏기법  \
# Date
# 2006-03-02 -0.012176 -0.004163  0.003148 -0.004245 -0.009235 -0.004180
# 2006-03-03  0.017103 -0.016589 -0.022778 -0.017546 -0.022754 -0.024339
# 2006-03-06 -0.018103  0.011637  0.011190  0.004478  0.003144  0.012759
# 2006-03-07 -0.043212 -0.016843 -0.028491 -0.011694 -0.002772 -0.025226
# 2006-03-08  0.007549 -0.007919 -0.004598  0.010290  0.001887 -0.014189
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-03  0.051060  0.002114 -0.006505 -0.008353 -0.003740  0.001091
# 2022-05-04  0.051183 -0.009320 -0.003745 -0.006407  0.001788 -0.004029
# 2022-05-06  0.051133  0.001078 -0.013734 -0.006216 -0.013486 -0.012977
# 2022-05-09  0.051428 -0.016910 -0.011615 -0.028295 -0.018643 -0.011348
# 2022-05-10  0.051980 -0.015892 -0.004799 -0.002160 -0.009955 -0.010384
#
#               삼대투자기법     성장성기법     수익성기법    시장가치기법     활동성기법
# Date
# 2006-03-02 -0.002885 -0.011703  0.003138  0.001468  0.007272
# 2006-03-03 -0.019855 -0.019931 -0.023816 -0.042204 -0.022764
# 2006-03-06  0.010315  0.011755  0.010877  0.021549  0.014470
# 2006-03-07 -0.013850 -0.019911 -0.026519 -0.021908 -0.025480
# 2006-03-08 -0.006048 -0.010333 -0.003670  0.000692 -0.003637
# ...              ...       ...       ...       ...       ...
# 2022-05-03 -0.004454 -0.004513 -0.006798 -0.001810 -0.008891
# 2022-05-04 -0.000976  0.000924 -0.002858  0.006830  0.002055
# 2022-05-06 -0.015054 -0.014405 -0.012405 -0.008364 -0.006202
# 2022-05-09 -0.021987 -0.013603 -0.014154 -0.013436 -0.006623
# 2022-05-10 -0.003993 -0.004541 -0.006504 -0.001658 -0.015276
#
# [4001 rows x 17 columns]

# %%
극안전형_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','유동성기법', '레버리지기법','그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']]=극안전형_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그','유동성기법','레버리지기법','그레이엄기법', '린치기법', '버핏기법', '삼대투자기법',
       '성장성기법', '수익성기법', '시장가치기법', '활동성기법']].cumsum()

# %%
극안전형_df['금액']=10000

# %%
극안전형_df
# Out:
#           Date       단기채로그       중기채로그      ksp로그       iau로그      dbc로그  \
# 0   2019-11-01    0.357846    0.350863   0.062167    0.075185   0.050869
# 1   2019-11-04    0.712916    0.700531   0.122307    0.160117   0.100315
# 2   2019-11-05    1.067056    1.049082   0.180882    0.248934   0.149573
# 3   2019-11-06    1.424418    1.400040   0.240010    0.330073   0.199441
# 4   2019-11-07    1.782125    1.752264   0.299463    0.409208   0.249346
# ..         ...         ...         ...        ...         ...        ...
# 618 2022-05-03  146.648074  156.564560  45.243843  108.555898  33.600930
# 619 2022-05-04  146.969286  156.889159  45.303126  108.702273  33.648079
# 620 2022-05-06  147.310963  157.228137  45.361161  108.812906  33.696533
# 621 2022-05-09  147.657208  157.568805  45.425395  108.909344  33.745712
# 622 2022-05-10  148.008962  157.914959  45.487003  108.995747  33.795428
#
#          vnq로그      nsd로그     유동성기법    레버리지기법  ...    시장가치기법     활동성기법  \
# 0     0.051566   0.051505  0.000157  0.014511  ...  0.008100  0.014093
# 1     0.101897   0.101917  0.014559  0.017529  ...  0.016869  0.033270
# 2     0.152037   0.152436  0.029178  0.017005  ...  0.027458  0.038091
# 3     0.202659   0.203359  0.028046  0.012199  ...  0.029495  0.034984
# 4     0.253370   0.254225  0.029493  0.013177  ...  0.034695  0.042584
# ..         ...        ...       ...       ...  ...       ...       ...
# 618  50.255897  81.130798 -0.164537 -0.030700  ...  0.434623  0.034518
# 619  50.306097  81.181981 -0.173857 -0.034445  ...  0.441454  0.036573
# 620  50.357186  81.233114 -0.172779 -0.048179  ...  0.433090  0.030371
# 621  50.408994  81.284542 -0.189689 -0.059794  ...  0.419654  0.023748
# 622  50.461378  81.336522 -0.205581 -0.064594  ...  0.417996  0.008471
#
#          단기채w      중기채w      kspw      iauw      dbcw      vnqw      nsdw  \
# 0    0.357846  0.350863  0.062167  0.075185  0.050869  0.051566  0.051505
# 1    0.355070  0.349667  0.060141  0.084932  0.049446  0.050332  0.050412
# 2    0.354140  0.348552  0.058575  0.088817  0.049258  0.050139  0.050519
# 3    0.357363  0.350958  0.059128  0.081139  0.049868  0.050622  0.050922
# 4    0.357707  0.352224  0.059453  0.079134  0.049905  0.050711  0.050866
# ..        ...       ...       ...       ...       ...       ...       ...
# 618  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 619  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 620  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 621  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
# 622  0.340171  0.332817  0.053358  0.132273  0.047174  0.047073  0.047136
#
#         금액
# 0    10000
# 1    10000
# 2    10000
# 3    10000
# 4    10000
# ..     ...
# 618  10000
# 619  10000
# 620  10000
# 621  10000
# 622  10000
#
# [626 rows x 26 columns]

# %%
log_df['유동성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['유동성기법'])
log_df['레버리지']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['레버리지기법'])
log_df['그레이엄']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['그레이엄기법'])
log_df['린치']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['린치기법'])
log_df['버핏']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['버핏기법'])
log_df['삼대투자']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['삼대투자기법'])
log_df['성장성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['성장성기법'])
log_df['수익성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['수익성기법'])
log_df['시장가치']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['시장가치기법'])
log_df['활동성']=log_df['금액']*log_df['단기채w']*np.exp(log_df['단기채로그'])+log_df['금액']*log_df['중기채w']*np.exp(log_df['중기채로그'])+log_df['금액']*log_df['iauw']*np.exp(log_df['iau로그'])+log_df['금액']*log_df['dbcw']*np.exp(log_df['dbc로그'])+log_df['금액']*log_df['vnqw']*np.exp(log_df['vnq로그'])+log_df['금액']*log_df['nsdw']*np.exp(log_df['nsd로그'])+log_df['금액']*log_df['kspw']*np.exp(log_df['활동성기법'])

# %%
log_df.columns
# Out:
# Index(['Date', '단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그',
#        '유동성기법', '레버리지기법', '그레이엄기법', '린치기법', '버핏기법', '삼대투자기법', '성장성기법', '수익성기법',
#        '시장가치기법', '활동성기법', '단기채w', '중기채w', 'kspw', 'iauw', 'dbcw', 'vnqw',
#        'nsdw', '금액', '유동성', '레버리지', '그레이엄', '린치', '버핏', '삼대투자', '성장성', '수익성',
#        '시장가치', '활동성'],
#       dtype='object')

# %%
grp = grp.drop(['level_0', 'index'], axis=1)

# %%
grp=pd.merge(grp,log_df[['Date','유동성', '레버리지', '그레이엄', '린치', '버핏', '삼대투자',
       '성장성', '수익성', '시장가치', '활동성']],on='Date',how='outer').dropna()

# %%
grp
# Out:
#         Date  lstm_markowitz         kospi          미래에셋          KB펀드  \
# 0 2019-11-01    10187.362432  10393.479515  10227.294524  10080.015967
# 1 2019-11-29    10334.183163  10332.906193  10208.113551  10171.523403
# 2 2019-12-30    10554.629758  10875.839370  10873.693296  10341.156641
# 3 2020-01-28    10723.319220  10772.162152  10450.752853  10398.571566
# 4 2020-02-25    10996.476872  10410.355712   9849.429366  10309.944928
# 5 2020-03-24     7480.303458   7967.427054   7047.089287   9519.046916
#
#         금액         유동성_x        레버리지_x        그레이엄_x          린치_x  ...  \
# 0  10000.0  10005.633421  10014.622593  10011.265371  10008.849871  ...
# 1  10000.0  10007.633854   9997.061891  10006.098425  10008.513379  ...
# 2  10000.0  10107.852540  10109.586143  10135.190078  10119.390367  ...
# 3  10000.0  10144.402212  10153.875840  10132.090062  10102.381538  ...
# 4  10000.0  10157.752961  10181.030486  10125.822446  10109.267991  ...
# 5  10000.0   9618.630957   9643.519709   9553.747163   9547.239428  ...
#
#             유동성          레버리지          그레이엄            린치            버핏  \
# 0  1.315413e+04  1.316312e+04  1.315976e+04  1.315734e+04  1.316140e+04
# 1  1.208665e+07  1.208664e+07  1.208665e+07  1.208665e+07  1.208665e+07
# 2  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10
# 3  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13
# 4  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16
# 5  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19
#
#            삼대투자           성장성           수익성          시장가치           활동성
# 0  1.315880e+04  1.315901e+04  1.316230e+04  1.315909e+04  1.316285e+04
# 1  1.208663e+07  1.208666e+07  1.208665e+07  1.208667e+07  1.208666e+07
# 2  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10  1.397621e+10
# 3  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13  1.735655e+13
# 4  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16  2.216353e+16
# 5  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19  1.600964e+19
#
# [6 rows x 36 columns]

# %%
p = grp[['lstm_markowitz', '미래에셋', 'KB펀드', '유동성',
       '레버리지', '그레이엄', '린치', '버핏', '삼대투자', '성장성', '수익성', '시장가치', '활동성']].plot(figsize=(18, 10), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.savefig("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/차트/기간"+str(perf_df.index[1])[:10]+"-"+str(perf_df.index[-1])[:10]+"감마"+str(GAMMA_CONST)+"REG"+str(REG_CONST)+"가중치.png")
plt.show()

# %%
grp
# Out:
#                      crp  lstm_markowitz         kospi          미래에셋  \
# Date
# 2019-12-31  10000.000000    10000.000000  10000.000000  10000.000000
# 2020-01-29  10036.938181    10224.825144   9943.622596   9629.564297
# 2020-02-26  10005.999563    10295.900080   9449.872335   8954.842124
# 2020-03-25   8402.684397     8137.672903   7757.124911   6931.557594
# 2020-04-22   9057.310134     8708.347455   8628.001892   7832.951138
# 2020-05-20   9362.758662     9051.162397   9053.406951   8273.064032
# 2020-06-17   9824.690125     9496.075493   9742.364072   8539.424943
# 2020-07-15   9957.452690     9693.330050  10019.156475   8721.114835
# 2020-08-12  10371.504093    10128.862742  11067.859069   9440.818487
# 2020-09-09  10292.450094    10063.904103  10810.586408   9187.687423
# 2020-10-07  10275.134080     9984.177318  10861.230422   9319.103898
# 2020-11-04  10237.541204     9981.092303  10726.451888   9218.557065
# 2020-12-02  10597.367513    10321.319603  12176.077380  10275.180808
# 2020-12-31  10894.766691    10518.663007  13075.075297  11180.984301
# 2021-01-29  11152.962972    10823.820056  13542.570389  11487.916740
# 2021-02-26  11372.913887    10954.044864  13709.747406  11794.849180
# 2021-03-26  11325.681680    11101.501111  13837.428358  12222.614218
# 2021-04-23  11839.313048    11778.345831  14474.785528  12817.957312
# 2021-05-21  12021.770849    12011.649133  14362.575064  12713.000529
# 2021-06-18  12277.632671    12309.262421  14869.976147  12985.535368
# 2021-07-16  12426.582998    12415.465402  14910.837517  13082.554242
# 2021-08-13  12453.489541    12646.145731  14430.238170  12573.646146
# 2021-09-10  12541.492616    12927.108612  14223.064067  12628.329511
# 2021-10-08  12507.212782    12833.097990  13451.974837  11965.073205
# 2021-11-05  12761.542320    13370.005194  13510.991755  11899.805962
# 2021-12-03  12483.723393    12989.070543  13506.714764  12004.762745
# 2021-12-31  12894.858341    13492.275383  13549.122517  12262.303757
# 2022-01-28  12169.251869    12293.796849  12118.926784  11074.263539
# 2022-02-25  12386.036159    12415.628222  12179.991104  11158.934556
# 2022-03-25  12836.006161    12819.592352  12422.156545  11382.959958
# 2022-04-22  12913.432618    12896.716753  12307.171036  11360.028224
#
#                     KB펀드
# Date
# 2019-12-31  10000.000000
# 2020-01-29  10001.226413
# 2020-02-26  10003.711958
# 2020-03-25   9384.491606
# 2020-04-22   9915.377562
# 2020-05-20  10137.949590
# 2020-06-17  10302.839218
# 2020-07-15  10403.527375
# 2020-08-12  10647.166535
# 2020-09-09  10601.037559
# 2020-10-07  10595.732142
# 2020-11-04  10556.818433
# 2020-12-02  10927.285521
# 2020-12-31  11241.136501
# 2021-01-29  11444.498132
# 2021-02-26  11676.615631
# 2021-03-26  11856.883786
# 2021-04-23  12055.941048
# 2021-05-21  12026.296586
# 2021-06-18  12186.972527
# 2021-07-16  12302.854271
# 2021-08-13  12365.113572
# 2021-09-10  12259.260034
# 2021-10-08  12097.598061
# 2021-11-05  12153.756683
# 2021-12-03  12070.437716
# 2021-12-31  12189.993461
# 2022-01-28  11746.996099
# 2022-02-25  11705.772804
# 2022-03-25  11867.286281
# 2022-04-22  11849.037618
