# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])

# %%
rtn_df=rtn_df.set_index('Date')

# %%
rtn_df=rtn_df[rtn_df['상승']==1]

# %%
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
rtn_df_test=rtn_df.loc['2020-07-01':'2021-08-31']

# %%
rtn_df_train=rtn_df.loc[:'2020-06-30']

# %%
# rtn_df_train=pd.concat([rtn_df.loc[:'2019-11-30'],rtn_df.loc['2020-04-01':]],axis=0) # 잘라진 데이터 TRAIN 넣기

# %%
rtn_df_train
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2019-08-26  0.000148  0.001032 -0.016556  0.000684 -0.000675  0.007688
# 2019-08-27 -0.000035 -0.001142  0.004317  0.008847  0.006734 -0.002849
# 2019-08-28  0.000038 -0.000103  0.008532 -0.002035  0.008687  0.003286
# 2019-08-29  0.000034  0.000044 -0.003964 -0.007496  0.002658  0.007735
# 2019-08-30  0.000034 -0.000873  0.017626 -0.004112 -0.016054  0.000759
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2019-08-26  0.011723
# 2019-08-27 -0.004062
# 2019-08-28  0.002642
# 2019-08-29  0.012506
# 2019-08-30  0.000701
#
# [3499 rows x 7 columns]

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[df['상승']==1]

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
up_2006=df.loc['2006-10-02':'2007-10-31']
up_2009=df.loc['2009-01-02':'2010-01-29']
up_2012=df.loc['2012-03-01':'2013-09-30']
up_2014=df.loc['2014-09-01':'2015-05-29']
up_2015=df.loc['2015-10-01':'2016-01-29']
up_2016=df.loc['2016-05-02':'2017-06-30']
up_2019=df.loc['2019-12-02':'2020-03-31']
#up_2020=df.loc['2020-07-01':'2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

for i in range(1, len(up_2006) - T + 1):
    d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2009) - T + 1):
    d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2012) - T + 1):
    d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2014) - T + 1):
    d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2015) - T + 1):
    d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2016) - T + 1):
    d = np.expand_dims(np.array(up_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2019) - T + 1):
    d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
#for i in range(0, len(up_2020) - T + 1):
    #d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
    #x_seq = np.concatenate((x_seq, d))

# %%
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100

N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.0
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7,
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 7)                 420
#
#  dense_7 (Dense)             (None, 7)                 56
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 22/22 [==============================] - 2s 29ms/step - loss: -1.0647 - val_loss: -4.4224
# Epoch 2/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.0964 - val_loss: -4.4226
# Epoch 3/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1342 - val_loss: -4.4227
# Epoch 4/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1050 - val_loss: -4.4228
# Epoch 5/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1220 - val_loss: -4.4229
# Epoch 6/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1091 - val_loss: -4.4230
# Epoch 7/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1112 - val_loss: -4.4231
# Epoch 8/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1041 - val_loss: -4.4233
# Epoch 9/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1261 - val_loss: -4.4234
# Epoch 10/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.0964 - val_loss: -4.4235
# Epoch 11/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1232 - val_loss: -4.4236
# Epoch 12/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1202 - val_loss: -4.4237
# Epoch 13/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.0674 - val_loss: -4.4238
# Epoch 14/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.1082 - val_loss: -4.4240
# Epoch 15/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1109 - val_loss: -4.4241
# Epoch 16/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1284 - val_loss: -4.4242
# Epoch 17/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.0815 - val_loss: -4.4243
# Epoch 18/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.0925 - val_loss: -4.4244
# Epoch 19/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1407 - val_loss: -4.4245
# Epoch 20/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.0912 - val_loss: -4.4246
# Epoch 21/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1317 - val_loss: -4.4247
# Epoch 22/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1215 - val_loss: -4.4249
# Epoch 23/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1134 - val_loss: -4.4250
# Epoch 24/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1238 - val_loss: -4.4251
# Epoch 25/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1474 - val_loss: -4.4252
# Epoch 26/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1466 - val_loss: -4.4253
# Epoch 27/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1328 - val_loss: -4.4255
# Epoch 28/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1128 - val_loss: -4.4256
# Epoch 29/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1159 - val_loss: -4.4256
# Epoch 30/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1081 - val_loss: -4.4258
# Epoch 31/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1348 - val_loss: -4.4259
# Epoch 32/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1036 - val_loss: -4.4260
# Epoch 33/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1111 - val_loss: -4.4261
# Epoch 34/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1191 - val_loss: -4.4263
# Epoch 35/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1476 - val_loss: -4.4264
# Epoch 36/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1373 - val_loss: -4.4266
# Epoch 37/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1221 - val_loss: -4.4267
# Epoch 38/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1379 - val_loss: -4.4268
# Epoch 39/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1516 - val_loss: -4.4269
# Epoch 40/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1468 - val_loss: -4.4270
# Epoch 41/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1380 - val_loss: -4.4271
# Epoch 42/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1483 - val_loss: -4.4273
# Epoch 43/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1218 - val_loss: -4.4274
# Epoch 44/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1952 - val_loss: -4.4276
# Epoch 45/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1300 - val_loss: -4.4277
# Epoch 46/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1321 - val_loss: -4.4279
# Epoch 47/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1192 - val_loss: -4.4279
# Epoch 48/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1057 - val_loss: -4.4281
# Epoch 49/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1522 - val_loss: -4.4282
# Epoch 50/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1288 - val_loss: -4.4284
# Epoch 51/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1550 - val_loss: -4.4285
# Epoch 52/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1710 - val_loss: -4.4286
# Epoch 53/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1479 - val_loss: -4.4287
# Epoch 54/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.1471 - val_loss: -4.4288
# Epoch 55/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1851 - val_loss: -4.4290
# Epoch 56/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1215 - val_loss: -4.4291
# Epoch 57/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1418 - val_loss: -4.4292
# Epoch 58/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1228 - val_loss: -4.4294
# Epoch 59/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1323 - val_loss: -4.4295
# Epoch 60/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1554 - val_loss: -4.4296
# Epoch 61/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1612 - val_loss: -4.4298
# Epoch 62/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1299 - val_loss: -4.4299
# Epoch 63/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1722 - val_loss: -4.4300
# Epoch 64/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1499 - val_loss: -4.4302
# Epoch 65/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1210 - val_loss: -4.4303
# Epoch 66/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1292 - val_loss: -4.4304
# Epoch 67/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.1657 - val_loss: -4.4306
# Epoch 68/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1301 - val_loss: -4.4308
# Epoch 69/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1027 - val_loss: -4.4309
# Epoch 70/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1498 - val_loss: -4.4310
# Epoch 71/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1562 - val_loss: -4.4311
# Epoch 72/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1666 - val_loss: -4.4313
# Epoch 73/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1364 - val_loss: -4.4314
# Epoch 74/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1681 - val_loss: -4.4315
# Epoch 75/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1493 - val_loss: -4.4317
# Epoch 76/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1461 - val_loss: -4.4317
# Epoch 77/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1519 - val_loss: -4.4319
# Epoch 78/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1852 - val_loss: -4.4321
# Epoch 79/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1365 - val_loss: -4.4321
# Epoch 80/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1509 - val_loss: -4.4323
# Epoch 81/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1591 - val_loss: -4.4325
# Epoch 82/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1665 - val_loss: -4.4326
# Epoch 83/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1569 - val_loss: -4.4327
# Epoch 84/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1187 - val_loss: -4.4329
# Epoch 85/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1466 - val_loss: -4.4331
# Epoch 86/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1939 - val_loss: -4.4332
# Epoch 87/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1824 - val_loss: -4.4333
# Epoch 88/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1707 - val_loss: -4.4335
# Epoch 89/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1644 - val_loss: -4.4336
# Epoch 90/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1669 - val_loss: -4.4337
# Epoch 91/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1519 - val_loss: -4.4339
# Epoch 92/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1476 - val_loss: -4.4341
# Epoch 93/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1566 - val_loss: -4.4343
# Epoch 94/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.1499 - val_loss: -4.4344
# Epoch 95/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1392 - val_loss: -4.4346
# Epoch 96/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1693 - val_loss: -4.4346
# Epoch 97/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1772 - val_loss: -4.4348
# Epoch 98/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1720 - val_loss: -4.4349
# Epoch 99/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2067 - val_loss: -4.4351
# Epoch 100/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1880 - val_loss: -4.4353
# Epoch 101/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1688 - val_loss: -4.4354
# Epoch 102/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2433 - val_loss: -4.4356
# Epoch 103/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1710 - val_loss: -4.4357
# Epoch 104/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1703 - val_loss: -4.4359
# Epoch 105/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1700 - val_loss: -4.4360
# Epoch 106/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1654 - val_loss: -4.4361
# Epoch 107/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2062 - val_loss: -4.4364
# Epoch 108/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1917 - val_loss: -4.4366
# Epoch 109/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1836 - val_loss: -4.4367
# Epoch 110/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2108 - val_loss: -4.4368
# Epoch 111/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1803 - val_loss: -4.4369
# Epoch 112/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1819 - val_loss: -4.4372
# Epoch 113/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1884 - val_loss: -4.4373
# Epoch 114/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2086 - val_loss: -4.4376
# Epoch 115/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2015 - val_loss: -4.4376
# Epoch 116/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1936 - val_loss: -4.4377
# Epoch 117/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2142 - val_loss: -4.4379
# Epoch 118/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1849 - val_loss: -4.4381
# Epoch 119/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1843 - val_loss: -4.4382
# Epoch 120/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2036 - val_loss: -4.4384
# Epoch 121/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1868 - val_loss: -4.4386
# Epoch 122/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1750 - val_loss: -4.4387
# Epoch 123/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2100 - val_loss: -4.4389
# Epoch 124/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2032 - val_loss: -4.4391
# Epoch 125/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2052 - val_loss: -4.4392
# Epoch 126/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2046 - val_loss: -4.4394
# Epoch 127/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2129 - val_loss: -4.4395
# Epoch 128/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1934 - val_loss: -4.4398
# Epoch 129/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2211 - val_loss: -4.4399
# Epoch 130/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2135 - val_loss: -4.4400
# Epoch 131/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2101 - val_loss: -4.4402
# Epoch 132/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1966 - val_loss: -4.4403
# Epoch 133/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1638 - val_loss: -4.4406
# Epoch 134/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2004 - val_loss: -4.4407
# Epoch 135/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.1801 - val_loss: -4.4408
# Epoch 136/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2364 - val_loss: -4.4410
# Epoch 137/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2067 - val_loss: -4.4412
# Epoch 138/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2028 - val_loss: -4.4413
# Epoch 139/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2207 - val_loss: -4.4416
# Epoch 140/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2351 - val_loss: -4.4417
# Epoch 141/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2216 - val_loss: -4.4419
# Epoch 142/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2226 - val_loss: -4.4420
# Epoch 143/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2253 - val_loss: -4.4422
# Epoch 144/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1841 - val_loss: -4.4423
# Epoch 145/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2022 - val_loss: -4.4426
# Epoch 146/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2006 - val_loss: -4.4428
# Epoch 147/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2273 - val_loss: -4.4429
# Epoch 148/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2256 - val_loss: -4.4431
# Epoch 149/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2300 - val_loss: -4.4433
# Epoch 150/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2244 - val_loss: -4.4434
# Epoch 151/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2525 - val_loss: -4.4436
# Epoch 152/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2177 - val_loss: -4.4438
# Epoch 153/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2508 - val_loss: -4.4440
# Epoch 154/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2319 - val_loss: -4.4441
# Epoch 155/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2353 - val_loss: -4.4442
# Epoch 156/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2779 - val_loss: -4.4445
# Epoch 157/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2118 - val_loss: -4.4447
# Epoch 158/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2264 - val_loss: -4.4449
# Epoch 159/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3041 - val_loss: -4.4451
# Epoch 160/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2229 - val_loss: -4.4452
# Epoch 161/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.1967 - val_loss: -4.4453
# Epoch 162/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2416 - val_loss: -4.4455
# Epoch 163/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2631 - val_loss: -4.4458
# Epoch 164/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2288 - val_loss: -4.4459
# Epoch 165/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2468 - val_loss: -4.4461
# Epoch 166/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2588 - val_loss: -4.4464
# Epoch 167/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2751 - val_loss: -4.4466
# Epoch 168/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2227 - val_loss: -4.4466
# Epoch 169/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2311 - val_loss: -4.4469
# Epoch 170/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2448 - val_loss: -4.4471
# Epoch 171/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2229 - val_loss: -4.4472
# Epoch 172/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2434 - val_loss: -4.4474
# Epoch 173/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2393 - val_loss: -4.4476
# Epoch 174/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2539 - val_loss: -4.4478
# Epoch 175/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2386 - val_loss: -4.4480
# Epoch 176/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3071 - val_loss: -4.4482
# Epoch 177/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2431 - val_loss: -4.4483
# Epoch 178/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2501 - val_loss: -4.4485
# Epoch 179/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2483 - val_loss: -4.4487
# Epoch 180/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2374 - val_loss: -4.4489
# Epoch 181/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.2344 - val_loss: -4.4491
# Epoch 182/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2754 - val_loss: -4.4493
# Epoch 183/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2514 - val_loss: -4.4495
# Epoch 184/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2382 - val_loss: -4.4497
# Epoch 185/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2139 - val_loss: -4.4499
# Epoch 186/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2598 - val_loss: -4.4500
# Epoch 187/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -1.2765 - val_loss: -4.4503
# Epoch 188/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2797 - val_loss: -4.4504
# Epoch 189/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2310 - val_loss: -4.4506
# Epoch 190/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2188 - val_loss: -4.4508
# Epoch 191/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2546 - val_loss: -4.4510
# Epoch 192/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2468 - val_loss: -4.4513
# Epoch 193/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3285 - val_loss: -4.4515
# Epoch 194/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3314 - val_loss: -4.4516
# Epoch 195/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2545 - val_loss: -4.4518
# Epoch 196/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2628 - val_loss: -4.4520
# Epoch 197/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2529 - val_loss: -4.4522
# Epoch 198/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2812 - val_loss: -4.4524
# Epoch 199/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2709 - val_loss: -4.4526
# Epoch 200/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2744 - val_loss: -4.4528
# Epoch 201/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2932 - val_loss: -4.4530
# Epoch 202/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2945 - val_loss: -4.4533
# Epoch 203/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.2748 - val_loss: -4.4534
# Epoch 204/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2749 - val_loss: -4.4536
# Epoch 205/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2253 - val_loss: -4.4538
# Epoch 206/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2504 - val_loss: -4.4540
# Epoch 207/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2909 - val_loss: -4.4542
# Epoch 208/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2640 - val_loss: -4.4544
# Epoch 209/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3101 - val_loss: -4.4546
# Epoch 210/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2824 - val_loss: -4.4548
# Epoch 211/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2814 - val_loss: -4.4550
# Epoch 212/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2900 - val_loss: -4.4553
# Epoch 213/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3248 - val_loss: -4.4555
# Epoch 214/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2916 - val_loss: -4.4556
# Epoch 215/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2841 - val_loss: -4.4558
# Epoch 216/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3057 - val_loss: -4.4560
# Epoch 217/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2639 - val_loss: -4.4562
# Epoch 218/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2452 - val_loss: -4.4564
# Epoch 219/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3031 - val_loss: -4.4566
# Epoch 220/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2954 - val_loss: -4.4568
# Epoch 221/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2543 - val_loss: -4.4570
# Epoch 222/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3213 - val_loss: -4.4572
# Epoch 223/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2875 - val_loss: -4.4574
# Epoch 224/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2924 - val_loss: -4.4577
# Epoch 225/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3171 - val_loss: -4.4578
# Epoch 226/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3729 - val_loss: -4.4581
# Epoch 227/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2792 - val_loss: -4.4583
# Epoch 228/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3446 - val_loss: -4.4586
# Epoch 229/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.3501 - val_loss: -4.4587
# Epoch 230/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3109 - val_loss: -4.4589
# Epoch 231/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2585 - val_loss: -4.4591
# Epoch 232/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2955 - val_loss: -4.4593
# Epoch 233/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3143 - val_loss: -4.4596
# Epoch 234/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3242 - val_loss: -4.4597
# Epoch 235/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2978 - val_loss: -4.4600
# Epoch 236/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2995 - val_loss: -4.4602
# Epoch 237/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2976 - val_loss: -4.4604
# Epoch 238/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3165 - val_loss: -4.4606
# Epoch 239/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2868 - val_loss: -4.4608
# Epoch 240/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3068 - val_loss: -4.4611
# Epoch 241/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2979 - val_loss: -4.4612
# Epoch 242/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2777 - val_loss: -4.4614
# Epoch 243/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3177 - val_loss: -4.4617
# Epoch 244/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.2851 - val_loss: -4.4619
# Epoch 245/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3006 - val_loss: -4.4621
# Epoch 246/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3456 - val_loss: -4.4623
# Epoch 247/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3374 - val_loss: -4.4626
# Epoch 248/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3240 - val_loss: -4.4628
# Epoch 249/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3298 - val_loss: -4.4630
# Epoch 250/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3088 - val_loss: -4.4633
# Epoch 251/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.2965 - val_loss: -4.4634
# Epoch 252/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.2852 - val_loss: -4.4637
# Epoch 253/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3335 - val_loss: -4.4638
# Epoch 254/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3354 - val_loss: -4.4641
# Epoch 255/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3114 - val_loss: -4.4644
# Epoch 256/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3371 - val_loss: -4.4646
# Epoch 257/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3259 - val_loss: -4.4648
# Epoch 258/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3142 - val_loss: -4.4649
# Epoch 259/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3343 - val_loss: -4.4652
# Epoch 260/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3543 - val_loss: -4.4655
# Epoch 261/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3086 - val_loss: -4.4656
# Epoch 262/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3434 - val_loss: -4.4658
# Epoch 263/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3048 - val_loss: -4.4661
# Epoch 264/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3313 - val_loss: -4.4663
# Epoch 265/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3596 - val_loss: -4.4666
# Epoch 266/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3810 - val_loss: -4.4668
# Epoch 267/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3568 - val_loss: -4.4670
# Epoch 268/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3507 - val_loss: -4.4673
# Epoch 269/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3423 - val_loss: -4.4674
# Epoch 270/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3448 - val_loss: -4.4676
# Epoch 271/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3691 - val_loss: -4.4679
# Epoch 272/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3397 - val_loss: -4.4681
# Epoch 273/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3183 - val_loss: -4.4684
# Epoch 274/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3102 - val_loss: -4.4686
# Epoch 275/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3525 - val_loss: -4.4688
# Epoch 276/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3358 - val_loss: -4.4691
# Epoch 277/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3739 - val_loss: -4.4693
# Epoch 278/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3356 - val_loss: -4.4694
# Epoch 279/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3633 - val_loss: -4.4697
# Epoch 280/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3646 - val_loss: -4.4700
# Epoch 281/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3854 - val_loss: -4.4702
# Epoch 282/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3494 - val_loss: -4.4704
# Epoch 283/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3868 - val_loss: -4.4706
# Epoch 284/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3944 - val_loss: -4.4709
# Epoch 285/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3180 - val_loss: -4.4711
# Epoch 286/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3551 - val_loss: -4.4713
# Epoch 287/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3425 - val_loss: -4.4716
# Epoch 288/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3573 - val_loss: -4.4718
# Epoch 289/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3184 - val_loss: -4.4720
# Epoch 290/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.4016 - val_loss: -4.4723
# Epoch 291/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3992 - val_loss: -4.4726
# Epoch 292/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3457 - val_loss: -4.4728
# Epoch 293/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3422 - val_loss: -4.4730
# Epoch 294/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3891 - val_loss: -4.4732
# Epoch 295/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3634 - val_loss: -4.4735
# Epoch 296/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3333 - val_loss: -4.4737
# Epoch 297/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3350 - val_loss: -4.4739
# Epoch 298/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3768 - val_loss: -4.4741
# Epoch 299/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3561 - val_loss: -4.4744
# Epoch 300/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3856 - val_loss: -4.4747
# Epoch 301/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3918 - val_loss: -4.4749
# Epoch 302/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3745 - val_loss: -4.4751
# Epoch 303/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4157 - val_loss: -4.4755
# Epoch 304/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4228 - val_loss: -4.4757
# Epoch 305/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3704 - val_loss: -4.4759
# Epoch 306/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3532 - val_loss: -4.4761
# Epoch 307/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3580 - val_loss: -4.4764
# Epoch 308/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3843 - val_loss: -4.4767
# Epoch 309/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3676 - val_loss: -4.4769
# Epoch 310/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.3325 - val_loss: -4.4771
# Epoch 311/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3787 - val_loss: -4.4773
# Epoch 312/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3816 - val_loss: -4.4776
# Epoch 313/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3765 - val_loss: -4.4779
# Epoch 314/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3912 - val_loss: -4.4781
# Epoch 315/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4161 - val_loss: -4.4783
# Epoch 316/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4005 - val_loss: -4.4786
# Epoch 317/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3926 - val_loss: -4.4789
# Epoch 318/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3912 - val_loss: -4.4791
# Epoch 319/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3761 - val_loss: -4.4794
# Epoch 320/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4065 - val_loss: -4.4796
# Epoch 321/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3760 - val_loss: -4.4798
# Epoch 322/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4079 - val_loss: -4.4802
# Epoch 323/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4042 - val_loss: -4.4804
# Epoch 324/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3886 - val_loss: -4.4807
# Epoch 325/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.3881 - val_loss: -4.4809
# Epoch 326/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4031 - val_loss: -4.4811
# Epoch 327/1000
# 22/22 [==============================] - 0s 6ms/step - loss: -1.4103 - val_loss: -4.4815
# Epoch 328/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4059 - val_loss: -4.4816
# Epoch 329/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3758 - val_loss: -4.4819
# Epoch 330/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4024 - val_loss: -4.4821
# Epoch 331/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3821 - val_loss: -4.4824
# Epoch 332/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4914 - val_loss: -4.4828
# Epoch 333/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3882 - val_loss: -4.4830
# Epoch 334/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3964 - val_loss: -4.4833
# Epoch 335/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4118 - val_loss: -4.4836
# Epoch 336/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4112 - val_loss: -4.4837
# Epoch 337/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4081 - val_loss: -4.4841
# Epoch 338/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3950 - val_loss: -4.4843
# Epoch 339/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4169 - val_loss: -4.4846
# Epoch 340/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4278 - val_loss: -4.4849
# Epoch 341/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3982 - val_loss: -4.4851
# Epoch 342/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4232 - val_loss: -4.4854
# Epoch 343/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3979 - val_loss: -4.4857
# Epoch 344/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4383 - val_loss: -4.4859
# Epoch 345/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4068 - val_loss: -4.4863
# Epoch 346/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4164 - val_loss: -4.4865
# Epoch 347/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4195 - val_loss: -4.4868
# Epoch 348/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4263 - val_loss: -4.4870
# Epoch 349/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4139 - val_loss: -4.4874
# Epoch 350/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4263 - val_loss: -4.4875
# Epoch 351/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4235 - val_loss: -4.4879
# Epoch 352/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4018 - val_loss: -4.4882
# Epoch 353/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3952 - val_loss: -4.4885
# Epoch 354/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4309 - val_loss: -4.4888
# Epoch 355/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4741 - val_loss: -4.4890
# Epoch 356/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4035 - val_loss: -4.4893
# Epoch 357/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4154 - val_loss: -4.4895
# Epoch 358/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4006 - val_loss: -4.4898
# Epoch 359/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4708 - val_loss: -4.4902
# Epoch 360/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4020 - val_loss: -4.4904
# Epoch 361/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4472 - val_loss: -4.4906
# Epoch 362/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4629 - val_loss: -4.4909
# Epoch 363/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4524 - val_loss: -4.4912
# Epoch 364/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4437 - val_loss: -4.4915
# Epoch 365/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4587 - val_loss: -4.4917
# Epoch 366/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4733 - val_loss: -4.4921
# Epoch 367/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4372 - val_loss: -4.4923
# Epoch 368/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4442 - val_loss: -4.4926
# Epoch 369/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4292 - val_loss: -4.4929
# Epoch 370/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4371 - val_loss: -4.4931
# Epoch 371/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4088 - val_loss: -4.4936
# Epoch 372/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4140 - val_loss: -4.4938
# Epoch 373/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4448 - val_loss: -4.4941
# Epoch 374/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4309 - val_loss: -4.4943
# Epoch 375/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4482 - val_loss: -4.4947
# Epoch 376/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.3931 - val_loss: -4.4949
# Epoch 377/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4286 - val_loss: -4.4953
# Epoch 378/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4840 - val_loss: -4.4954
# Epoch 379/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4555 - val_loss: -4.4958
# Epoch 380/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -1.4611 - val_loss: -4.4962
# Epoch 381/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4527 - val_loss: -4.4963
# Epoch 382/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4665 - val_loss: -4.4967
# Epoch 383/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4370 - val_loss: -4.4970
# Epoch 384/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4256 - val_loss: -4.4973
# Epoch 385/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4540 - val_loss: -4.4977
# Epoch 386/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4611 - val_loss: -4.4979
# Epoch 387/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4589 - val_loss: -4.4982
# Epoch 388/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4953 - val_loss: -4.4984
# Epoch 389/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4320 - val_loss: -4.4988
# Epoch 390/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4628 - val_loss: -4.4992
# Epoch 391/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4520 - val_loss: -4.4994
# Epoch 392/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4505 - val_loss: -4.4997
# Epoch 393/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4070 - val_loss: -4.5000
# Epoch 394/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4535 - val_loss: -4.5003
# Epoch 395/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4590 - val_loss: -4.5006
# Epoch 396/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4539 - val_loss: -4.5008
# Epoch 397/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4820 - val_loss: -4.5012
# Epoch 398/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4367 - val_loss: -4.5015
# Epoch 399/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4721 - val_loss: -4.5018
# Epoch 400/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4292 - val_loss: -4.5021
# Epoch 401/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4644 - val_loss: -4.5024
# Epoch 402/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5168 - val_loss: -4.5028
# Epoch 403/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4920 - val_loss: -4.5031
# Epoch 404/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4487 - val_loss: -4.5033
# Epoch 405/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4829 - val_loss: -4.5038
# Epoch 406/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4718 - val_loss: -4.5040
# Epoch 407/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4673 - val_loss: -4.5043
# Epoch 408/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5006 - val_loss: -4.5047
# Epoch 409/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4977 - val_loss: -4.5050
# Epoch 410/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4109 - val_loss: -4.5053
# Epoch 411/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4844 - val_loss: -4.5056
# Epoch 412/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4361 - val_loss: -4.5059
# Epoch 413/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5038 - val_loss: -4.5063
# Epoch 414/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4829 - val_loss: -4.5066
# Epoch 415/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4971 - val_loss: -4.5068
# Epoch 416/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.5133 - val_loss: -4.5072
# Epoch 417/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4744 - val_loss: -4.5076
# Epoch 418/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4785 - val_loss: -4.5079
# Epoch 419/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4692 - val_loss: -4.5082
# Epoch 420/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4769 - val_loss: -4.5086
# Epoch 421/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5496 - val_loss: -4.5089
# Epoch 422/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5116 - val_loss: -4.5092
# Epoch 423/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4745 - val_loss: -4.5095
# Epoch 424/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4913 - val_loss: -4.5097
# Epoch 425/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4918 - val_loss: -4.5101
# Epoch 426/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4854 - val_loss: -4.5104
# Epoch 427/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5043 - val_loss: -4.5108
# Epoch 428/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4689 - val_loss: -4.5112
# Epoch 429/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4730 - val_loss: -4.5114
# Epoch 430/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5182 - val_loss: -4.5117
# Epoch 431/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4917 - val_loss: -4.5121
# Epoch 432/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4952 - val_loss: -4.5125
# Epoch 433/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5056 - val_loss: -4.5128
# Epoch 434/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4916 - val_loss: -4.5132
# Epoch 435/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4900 - val_loss: -4.5134
# Epoch 436/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5036 - val_loss: -4.5137
# Epoch 437/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5166 - val_loss: -4.5141
# Epoch 438/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5074 - val_loss: -4.5145
# Epoch 439/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5169 - val_loss: -4.5148
# Epoch 440/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5056 - val_loss: -4.5152
# Epoch 441/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.5485 - val_loss: -4.5155
# Epoch 442/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.4831 - val_loss: -4.5158
# Epoch 443/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5681 - val_loss: -4.5162
# Epoch 444/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5111 - val_loss: -4.5166
# Epoch 445/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.5307 - val_loss: -4.5169
# Epoch 446/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4931 - val_loss: -4.5172
# Epoch 447/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.5139 - val_loss: -4.5176
# Epoch 448/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.5525 - val_loss: -4.5179
# Epoch 449/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5209 - val_loss: -4.5183
# Epoch 450/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5322 - val_loss: -4.5187
# Epoch 451/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5111 - val_loss: -4.5191
# Epoch 452/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5283 - val_loss: -4.5194
# Epoch 453/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.4965 - val_loss: -4.5197
# Epoch 454/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.5110 - val_loss: -4.5201
# Epoch 455/1000
# ...
# Epoch 848/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9300 - val_loss: -4.7458
# Epoch 849/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9629 - val_loss: -4.7465
# Epoch 850/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9244 - val_loss: -4.7471
# Epoch 851/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9048 - val_loss: -4.7478
# Epoch 852/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9143 - val_loss: -4.7483
# Epoch 853/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9252 - val_loss: -4.7490
# Epoch 854/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9643 - val_loss: -4.7498
# Epoch 855/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9224 - val_loss: -4.7504
# Epoch 856/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9132 - val_loss: -4.7511
# Epoch 857/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9164 - val_loss: -4.7517
# Epoch 858/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9363 - val_loss: -4.7524
# Epoch 859/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9179 - val_loss: -4.7530
# Epoch 860/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9494 - val_loss: -4.7538
# Epoch 861/1000
# 22/22 [==============================] - 0s 10ms/step - loss: -1.9034 - val_loss: -4.7544
# Epoch 862/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9515 - val_loss: -4.7551
# Epoch 863/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0039 - val_loss: -4.7557
# Epoch 864/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9570 - val_loss: -4.7563
# Epoch 865/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9519 - val_loss: -4.7571
# Epoch 866/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9606 - val_loss: -4.7575
# Epoch 867/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9232 - val_loss: -4.7583
# Epoch 868/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9483 - val_loss: -4.7590
# Epoch 869/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9823 - val_loss: -4.7598
# Epoch 870/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9500 - val_loss: -4.7603
# Epoch 871/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9415 - val_loss: -4.7609
# Epoch 872/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9488 - val_loss: -4.7616
# Epoch 873/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9457 - val_loss: -4.7622
# Epoch 874/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9164 - val_loss: -4.7628
# Epoch 875/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9495 - val_loss: -4.7636
# Epoch 876/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9381 - val_loss: -4.7643
# Epoch 877/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9493 - val_loss: -4.7649
# Epoch 878/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9751 - val_loss: -4.7654
# Epoch 879/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9734 - val_loss: -4.7662
# Epoch 880/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9691 - val_loss: -4.7668
# Epoch 881/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9411 - val_loss: -4.7675
# Epoch 882/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9794 - val_loss: -4.7681
# Epoch 883/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0268 - val_loss: -4.7688
# Epoch 884/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9283 - val_loss: -4.7695
# Epoch 885/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9523 - val_loss: -4.7701
# Epoch 886/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9849 - val_loss: -4.7707
# Epoch 887/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9488 - val_loss: -4.7714
# Epoch 888/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9650 - val_loss: -4.7721
# Epoch 889/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0092 - val_loss: -4.7728
# Epoch 890/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9979 - val_loss: -4.7733
# Epoch 891/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0004 - val_loss: -4.7741
# Epoch 892/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0031 - val_loss: -4.7748
# Epoch 893/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9717 - val_loss: -4.7755
# Epoch 894/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9459 - val_loss: -4.7759
# Epoch 895/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9676 - val_loss: -4.7765
# Epoch 896/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9422 - val_loss: -4.7773
# Epoch 897/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9773 - val_loss: -4.7777
# Epoch 898/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9860 - val_loss: -4.7785
# Epoch 899/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0210 - val_loss: -4.7790
# Epoch 900/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9392 - val_loss: -4.7797
# Epoch 901/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9884 - val_loss: -4.7804
# Epoch 902/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9713 - val_loss: -4.7812
# Epoch 903/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9509 - val_loss: -4.7816
# Epoch 904/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9882 - val_loss: -4.7822
# Epoch 905/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9984 - val_loss: -4.7830
# Epoch 906/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9951 - val_loss: -4.7837
# Epoch 907/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9941 - val_loss: -4.7843
# Epoch 908/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9575 - val_loss: -4.7849
# Epoch 909/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9782 - val_loss: -4.7855
# Epoch 910/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9843 - val_loss: -4.7860
# Epoch 911/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0253 - val_loss: -4.7868
# Epoch 912/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0023 - val_loss: -4.7874
# Epoch 913/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9806 - val_loss: -4.7881
# Epoch 914/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0050 - val_loss: -4.7886
# Epoch 915/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9858 - val_loss: -4.7893
# Epoch 916/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9559 - val_loss: -4.7898
# Epoch 917/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9945 - val_loss: -4.7905
# Epoch 918/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9989 - val_loss: -4.7912
# Epoch 919/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9959 - val_loss: -4.7919
# Epoch 920/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9957 - val_loss: -4.7925
# Epoch 921/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0064 - val_loss: -4.7930
# Epoch 922/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9829 - val_loss: -4.7937
# Epoch 923/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0278 - val_loss: -4.7944
# Epoch 924/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0679 - val_loss: -4.7951
# Epoch 925/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0561 - val_loss: -4.7957
# Epoch 926/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9756 - val_loss: -4.7962
# Epoch 927/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0106 - val_loss: -4.7968
# Epoch 928/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9711 - val_loss: -4.7975
# Epoch 929/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9894 - val_loss: -4.7982
# Epoch 930/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0395 - val_loss: -4.7987
# Epoch 931/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9626 - val_loss: -4.7994
# Epoch 932/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0233 - val_loss: -4.8000
# Epoch 933/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9872 - val_loss: -4.8007
# Epoch 934/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9987 - val_loss: -4.8012
# Epoch 935/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9841 - val_loss: -4.8018
# Epoch 936/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9932 - val_loss: -4.8024
# Epoch 937/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -1.9975 - val_loss: -4.8031
# Epoch 938/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0036 - val_loss: -4.8038
# Epoch 939/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9807 - val_loss: -4.8044
# Epoch 940/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0213 - val_loss: -4.8050
# Epoch 941/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -2.0221 - val_loss: -4.8057
# Epoch 942/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9954 - val_loss: -4.8063
# Epoch 943/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0082 - val_loss: -4.8069
# Epoch 944/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0678 - val_loss: -4.8075
# Epoch 945/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0931 - val_loss: -4.8082
# Epoch 946/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -2.0206 - val_loss: -4.8089
# Epoch 947/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -1.9651 - val_loss: -4.8095
# Epoch 948/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0312 - val_loss: -4.8099
# Epoch 949/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0591 - val_loss: -4.8107
# Epoch 950/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0144 - val_loss: -4.8114
# Epoch 951/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0772 - val_loss: -4.8119
# Epoch 952/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0419 - val_loss: -4.8125
# Epoch 953/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0643 - val_loss: -4.8130
# Epoch 954/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0477 - val_loss: -4.8138
# Epoch 955/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0602 - val_loss: -4.8142
# Epoch 956/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0093 - val_loss: -4.8150
# Epoch 957/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0174 - val_loss: -4.8153
# Epoch 958/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -2.0368 - val_loss: -4.8161
# Epoch 959/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0188 - val_loss: -4.8167
# Epoch 960/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0169 - val_loss: -4.8174
# Epoch 961/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0014 - val_loss: -4.8180
# Epoch 962/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0054 - val_loss: -4.8187
# Epoch 963/1000
# 22/22 [==============================] - 0s 9ms/step - loss: -2.0570 - val_loss: -4.8194
# Epoch 964/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0603 - val_loss: -4.8199
# Epoch 965/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0455 - val_loss: -4.8206
# Epoch 966/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0812 - val_loss: -4.8212
# Epoch 967/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0061 - val_loss: -4.8217
# Epoch 968/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0308 - val_loss: -4.8223
# Epoch 969/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0467 - val_loss: -4.8230
# Epoch 970/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0489 - val_loss: -4.8234
# Epoch 971/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0673 - val_loss: -4.8241
# Epoch 972/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0918 - val_loss: -4.8249
# Epoch 973/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0589 - val_loss: -4.8254
# Epoch 974/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0740 - val_loss: -4.8261
# Epoch 975/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0245 - val_loss: -4.8266
# Epoch 976/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0467 - val_loss: -4.8272
# Epoch 977/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0683 - val_loss: -4.8278
# Epoch 978/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0613 - val_loss: -4.8284
# Epoch 979/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0141 - val_loss: -4.8291
# Epoch 980/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0339 - val_loss: -4.8296
# Epoch 981/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0607 - val_loss: -4.8303
# Epoch 982/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0800 - val_loss: -4.8310
# Epoch 983/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0325 - val_loss: -4.8316
# Epoch 984/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0364 - val_loss: -4.8320
# Epoch 985/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0639 - val_loss: -4.8328
# Epoch 986/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0612 - val_loss: -4.8332
# Epoch 987/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0739 - val_loss: -4.8340
# Epoch 988/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0585 - val_loss: -4.8345
# Epoch 989/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0238 - val_loss: -4.8351
# Epoch 990/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0400 - val_loss: -4.8357
# Epoch 991/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.1073 - val_loss: -4.8365
# Epoch 992/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0400 - val_loss: -4.8369
# Epoch 993/1000
# 22/22 [==============================] - 0s 7ms/step - loss: -2.0346 - val_loss: -4.8374
# Epoch 994/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0395 - val_loss: -4.8380
# Epoch 995/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0386 - val_loss: -4.8387
# Epoch 996/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0287 - val_loss: -4.8391
# Epoch 997/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0626 - val_loss: -4.8398
# Epoch 998/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0824 - val_loss: -4.8403
# Epoch 999/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0484 - val_loss: -4.8410
# Epoch 1000/1000
# 22/22 [==============================] - 0s 8ms/step - loss: -2.0577 - val_loss: -4.8416

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 20), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 포트폴리오 수익률 (연간):
# crp_rtn      0.165705
# lstm_rtn     0.178505
# sp500_rtn    0.279014
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.016439
# lstm_rtn     0.019782
# sp500_rtn    0.040725
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      10.080051
# lstm_rtn      9.023409
# sp500_rtn     6.851110
# dtype: float64
