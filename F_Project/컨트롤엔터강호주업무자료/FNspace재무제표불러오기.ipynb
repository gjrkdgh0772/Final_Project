# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set()

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %%
코스피A리스트 = pd.read_csv('/content/drive/MyDrive/컨트롤엔터산악회/코스피A리스트.csv')

# %%
코스피A리스트
# Out:
#         code  company
# 0    A095570   AJ네트웍스
# 1    A006840    AK홀딩스
# 2    A027410      BGF
# 3    A282330   BGF리테일
# 4    A138930  BNK금융지주
# ..       ...      ...
# 808  A005870      휴니드
# 809  A079980      휴비스
# 810  A005010      휴스틸
# 811  A000540     흥국화재
# 812  A003280     흥아해운
#
# [813 rows x 2 columns]

# %%
# A138040,A008560,A000060,A088260

# %%
리츠리스트 = 코스피A리스트[코스피A리스트['company'].str.contains('리츠')]['code'].tolist()

# %%
리츠리스트= ['A365550',
 'A400760',
 'A338100',
 'A395400',
 'A377190',
 'A330590',
 'A204210',
 'A396690',
 'A357250',
 'A404990',
 'A293940',
 'A140910',
 'A350520',
 'A334890',
 'A348950',
 'A145270',
 'A417310',
 'A357120']

# %%
def 리츠종목버리기(코스피A리스트):
        
    for 리츠 in 리츠리스트:
        
        행 = 코스피A리스트[코스피A리스트['code'] == 리츠].index.tolist()
        코스피A리스트 = 코스피A리스트.drop(행,axis=0)
    return 코스피A리스트

# %%
리츠종목버리기(코스피A리스트)
# Out:
#         code  company
# 0    A095570   AJ네트웍스
# 1    A006840    AK홀딩스
# 2    A027410      BGF
# 3    A282330   BGF리테일
# 4    A138930  BNK금융지주
# ..       ...      ...
# 808  A005870      휴니드
# 809  A079980      휴비스
# 810  A005010      휴스틸
# 811  A000540     흥국화재
# 812  A003280     흥아해운
#
# [795 rows x 2 columns]

# %%
코스피A리스트[코스피A리스트['code']=='A334890'] # 잘지워진것 확인
# Out:
#         code  company
# 544  A334890  이지스밸류리츠

# %%
코스피최종리스트 = 코스피A리스트['code'].tolist()

# %%
코스피최종리스트[:3]
# Out:
# ['A095570', 'A006840', 'A027410']

# %% [markdown]
# ## FNSPACE 2003년 부터 호출 가능

# %%
# https://www.fnspace.com/Api/FinanceApi?key=5A2CB417DA795E28F5E0&format=json&code=A005930&item=M382100,M431800,M382500,M362000,M383300,M382900,M123955&consolgb=M&annualgb=A&fraccyear=2002&toaccyear=2021

# %%
# dd = {"key":"5A2CB417DA795E28F5E0","format":"json","success":"true","errcd":"","errmsg":"","code":"A005930","item":"M382100,M431800,M382500,M362000,M383300,M382900,M123955","consolgb":"M","annualgb":"A","fraccyear":"2005","toaccyear":"2021","dataset":[{"CODE":"A005930","NAME":"삼성전자","DATA":[{"DATE":"2005  ","YYMM":"200512","FS_YEAR":2005,"FS_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"개별/별도","M382100":14.67465,"M431800":0.834598,"M382500":2.51382,"M362000":-28.662,"M383300":1.9513,
_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"연결","M382100":9.4001,"M431800":1.667975,"M382500":1.67483,"M362000":98.202,"M383300":1.6222,"M382900":6.2521,"M123955":20180228},{"DATE":"2018  ","YYMM":"201812","FS_YEAR":2018,"FS_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"연결","M382100":6.42413,"M431800":3.658915,"M382500":1.095,"M362000":11.122,"M383300":1.15666,"M382900":4.20637,"M123955":20190228},{"DATE":"2019  ","YYMM":"201912","FS_YEAR":2019,"FS_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"연결","M382100":17.6252,"M431800":2.537634,"M382500":1.48689,"M362000":-47.446,"M383300":1.64509,"M382900":8.35184,"M123955":20200224},{"DATE":"2020  ","YYMM":"202012","FS_YEAR":2020,"FS_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"연결","M382100":21.08809,"M431800":3.696296,"M382500":2.05554,"M362000":21.324,"M383300":2.32344,"M382900":8.4275,"M123955":20210218},{"DATE":"2021  ","YYMM":"202112","FS_YEAR":2021,"FS_MONTH":12,"FS_QTR":"Annual","MAIN_TERM":"연결","M382100":13.55287,"M431800":1.844189,"M382500":1.7954,"M362000":50.412,"M383300":1.90221,"M382900":8.1693,"M123955":20220217}]}]}

# %%
dsf_data = dd
df=pd.DataFrame(dsf_data['dataset'])
df2=pd.DataFrame(df['DATA'][0])
df2.columns=['DATE', 'YYMM', 'FS_YEAR','FS_MONTH', 'FS_QTR', 'MAIN_TERM', 'per', '현금배당수익률', 'pbr', 'esp증가율', 'psr', 'pcr', '실적보고발표일']
df2['code'] = dsf_data['code']
df2
# Out:
#       DATE    YYMM  FS_YEAR  FS_MONTH  FS_QTR MAIN_TERM       per   현금배당수익률  \
# 0   2005    200512     2005        12  Annual     개별/별도  14.67465  0.834598
# 1   2006    200612     2006        12  Annual     개별/별도  13.17395  0.897227
# 2   2007    200712     2007        12  Annual     개별/별도  12.73990  1.438849
# 3   2008    200812     2008        12  Annual     개별/별도  13.88550  1.219512
# 4   2009    200912     2009        12  Annual     개별/별도  14.08740  1.001252
# 5   2010    201012     2010        12  Annual        연결  10.21935  1.053741
# 6   2011    201112     2011        12  Annual        연결  13.45030  0.519849
# 7   2012    201212     2012        12  Annual        연결  11.16835  0.525624
# 8   2013    201312     2013        12  Annual        연결   7.82740  1.042274
# 9   2014    201412     2014        12  Annual        연결   9.78085  1.507159
# 10  2015    201512     2015        12  Annual        연결  11.46680  1.666667
# ...

# %%
코스피3개 = 코스피최종리스트[:3]

# %%
def call_api(코스피3개):

    
    for stockcode in 코스피3개:
            
        dsf_data = pd.read_json("https://www.fnspace.com/Api/FinanceApi?key=5A2CB417DA795E28F5E0&format=json&code="+stockcode+"&item=M382100,M431800,M382500,M362000,M383300,M382900,M123955&consolgb=M&annualgb=A&fraccyear=2003&toaccyear=2021",typ='series')
        df=pd.DataFrame(dsf_data['dataset'])
        df2=pd.DataFrame(df['DATA'][0])
        df2.columns=['DATE', 'YYMM', 'FS_YEAR','FS_MONTH', 'FS_QTR', 'MAIN_TERM', 'per', '현금배당수익률', 'pbr', 'esp증가율', 'psr', 'pcr', '실적보고발표일']
        df2['code'] = dsf_data['code']

        코스피재무제표 = pd.concat([코스피재무제표, df2])
    return 코스피재무제표

# %%
코스피재무제표 = pd.DataFrame()

# %%
len(코스피최종리스트)
# Out:
# 813

# %%
for stockcode in 코스피최종리스트:
        
    dsf_data = pd.read_json("https://www.fnspace.com/Api/FinanceApi?key=5A2CB417DA795E28F5E0&format=json&code="+stockcode+"&item=M223000,M241000,M122700&consolgb=M&annualgb=A&fraccyear=2003&toaccyear=2021",typ='series')
    df=pd.DataFrame(dsf_data['dataset'])
    df2=pd.DataFrame(df['DATA'][0])
    df2.columns=['DATE', 'YYMM', 'FS_YEAR','FS_MONTH', 'FS_QTR', 'MAIN_TERM', '자본유보율','총자산회전율','당기순이익']
    df2['code'] = dsf_data['code']

    코스피재무제표 = pd.concat([코스피재무제표, df2])

# %%
코스피재무제표.to_csv('코스피추가옵션.csv',index=True)

# %%
코스피재무제표
# Out:
#       DATE    YYMM  FS_YEAR  FS_MONTH  FS_QTR MAIN_TERM    자본유보율   총자산회전율  \
# 0   2003    200312     2003        12  Annual     개별/별도   21.046  0.75988
# 1   2004    200412     2004        12  Annual     개별/별도   39.159  0.75058
# 2   2005    200512     2005        12  Annual     개별/별도   59.356  0.76187
# 3   2006    200612     2006        12  Annual     개별/별도   90.183  0.65345
# 4   2007    200712     2007        12  Annual     개별/별도  142.073  0.67337
# ..     ...     ...      ...       ...     ...       ...      ...      ...
# 14  2017    201712     2017        12  Annual        연결  151.638  0.91316
# 15  2018    201812     2018        12  Annual        연결   13.003  0.12023
# 16  2019    201912     2019        12  Annual        연결   12.978   0.1655
# 17  2020    202012     2020        12  Annual        연결  -74.754  0.24783
# 18  2021    202112     2021        12  Annual        연결   13.693  0.30604
#
#           당기순이익     code
# 0     1228127.0  A095570
# 1     1761727.0  A095570
# ...

# %%
코스피추가재무제표 = pd.read_csv('/content/코스피추가재무제표.csv')

# %%
코스피추가재무제표['code'].nunique()
# Out:
# 795

# %% [markdown]
# # 추가로 불러오기

# %%
코스피재무제표 = pd.DataFrame()

# %%
len(코스피최종리스트)
# Out:
# 813

# %%
for stockcode in 코스피최종리스트:
        
    dsf_data = pd.read_json("https://www.fnspace.com/Api/FinanceApi?key=5A2CB417DA795E28F5E0&format=json&code="+stockcode+"&item=M382100,M431800,M382500,M362000,M383300,M382900,M123955&consolgb=M&annualgb=A&fraccyear=2003&toaccyear=2021",typ='series')
    df=pd.DataFrame(dsf_data['dataset'])
    df2=pd.DataFrame(df['DATA'][0])
    df2.columns=['DATE', 'YYMM', 'FS_YEAR','FS_MONTH', 'FS_QTR', 'MAIN_TERM', 'per', '현금배당수익률', 'pbr', 'esp증가율', 'psr', 'pcr', '실적보고발표일']
    df2['code'] = dsf_data['code']

    코스피재무제표 = pd.concat([코스피재무제표, df2])

# %%
코스피재무제표.to_csv('코스피추가재무제표.csv',index=True)

# %%
코스피추가재무제표 = pd.read_csv('/content/코스피추가재무제표.csv')

# %%
코스피추가재무제표['code'].nunique()
# Out:
# 795
