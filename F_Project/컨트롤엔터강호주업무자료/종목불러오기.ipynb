# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set()

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %%
코스피 = pd.read_csv('/content/drive/MyDrive/컨트롤엔터산악회/코스피A리스트.csv')

# %%
코스피
# Out:
#         code  company
# 0    A095570   AJ네트웍스
# 1    A006840    AK홀딩스
# 2    A027410      BGF
# 3    A282330   BGF리테일
# 4    A138930  BNK금융지주
# ..       ...      ...
# 808  A005870      휴니드
# 809  A079980      휴비스
# 810  A005010      휴스틸
# 811  A000540     흥국화재
# 812  A003280     흥아해운
#
# [813 rows x 2 columns]

# %%
종목코드 = 코스피.iloc[601:]['code'].tolist()
종목리스트 = 코스피.iloc[601:]['company'].tolist()

# %%
내가할코스피 = 코스피.iloc[601:]['code'] + 코스피.iloc[601:]['company']

# %%
코스피.iloc[399:402]
# Out:
#         code company
# 399  A021050      서원
# 400  A008490      서흥
# 401  A136490      선진

# %%
강호리스트 = 내가할코스피.tolist()

# %% [markdown]
# * 천일고속 데이터 로드 실패
# * 카프로 데이터 로드 실패
# * 케이카 로드 실패
# * 코람코더원리츠 로드 실패
# * 태원물산 로드 실패
# * 한국ANKOR유전 로드실패  (진짶없음)
# * 한국쉘석유 로드실패
# * 한국종합기술 로드실패
# * 한국주강 로드실패
# * 한국특강 로드실패
# * 한국패러랠 로드실패(집합투자기관)
# * 한농화성 로드실패
# * 한양증권 로드실패
# * 화인베스틸 로드실패

# %%
강호리스트
# Out:
# ['A002780진흥기업',
#  'A009310참엔지니어링',
#  'A000650천일고속',
#  'A033250체시스',
#  'A118000초록뱀헬스케어',
#  'A035720카카오',
#  'A323410카카오뱅크',
#  'A377300카카오페이',
#  'A006380카프로',
#  'A109070컨버즈',
#  'A001620케이비아이동국실업',
#  'A029460케이씨',
#  'A281820케이씨텍',
#  'A381970케이카',
#  'A145270케이탑리츠',
#  'A417310코람코더원리츠',
#  'A357120코람코에너지리츠',
#  'A007810코리아써키트',
#  'A003690코리안리',
#  'A192820코스맥스',
#  'A044820코스맥스비티아이',
#  'A005070코스모신소재',
#  'A005420코스모화학',
#  'A071950코아스',
#  'A002020코오롱',
#  'A003070코오롱글로벌',
#  'A120110코오롱인더',
#  'A138490코오롱플라스틱',
#  'A021240코웨이',
#  'A036420콘텐트리중앙',
#  'A031820콤텍시스템',
#  'A192400쿠쿠홀딩스',
#  'A284740쿠쿠홈시스',
#  'A015590큐로',
#  'A264900크라운제과',
#  'A005740크라운해태홀딩스',
#  'A259960크래프톤',
#  'A020120키다리스튜디오',
#  'A039490키움증권',
#  'A014580태경비케이',
#  'A015890태경산업',
#  'A006890태경케미컬',
#  'A003240태광산업',
#  'A011280태림포장',
#  'A004100태양금속',
#  'A009410태영건설',
#  'A001420태원물산',
#  'A007980태평양물산',
#  'A055490테이팩스',
#  'A078000텔코웨어',
#  'A214420토니모리',
#  'A019180티에이치엔',
#  'A363280티와이홀딩스',
#  'A091810티웨이항공',
#  'A004870티웨이홀딩스',
#  'A005690파미셀',
#  'A036580팜스코',
#  'A004720팜젠사이언스',
#  'A028670팬오션',
#  'A010820퍼스텍',
#  'A016800퍼시스',
#  'A001020페이퍼코리아',
#  'A090080평화산업',
#  'A010770평화홀딩스',
#  'A058430포스코스틸리온',
#  'A047050포스코인터내셔널',
#  'A003670포스코케미칼',
#  'A017810풀무원',
#  'A103140풍산',
#  'A005810풍산홀딩스',
#  'A950210프레스티지바이오파마',
#  'A009810플레이그램',
#  'A086790하나금융지주',
#  'A293480하나제약',
#  'A039130하나투어',
#  'A352820하이브',
#  'A071090하이스틸',
#  'A000080하이트진로',
#  'A000140하이트진로홀딩스',
#  'A152550한국ANKOR유전',
#  'A036460한국가스공사',
#  'A005430한국공항',
#  'A071050한국금융지주',
#  'A010040한국내화',
#  'A025540한국단자',
#  'A004090한국석유',
#  'A002200한국수출포장',
#  'A002960한국쉘석유',
#  'A000240한국앤컴퍼니',
#  'A123890한국자산신탁',
#  'A015760한국전력',
#  'A006200한국전자홀딩스',
#  'A009540한국조선해양',
#  'A023350한국종합기술',
#  'A025890한국주강',
#  'A000970한국주철관',
#  'A104700한국철강',
#  'A017960한국카본',
#  'A161890한국콜마',
#  'A024720한국콜마홀딩스',
#  'A161390한국타이어앤테크놀로지',
#  'A034830한국토지신탁',
#  'A007280한국특강',
#  'A168490한국패러랠',
#  'A010100한국프랜지',
#  'A047810한국항공우주',
#  'A123690한국화장품',
#  'A003350한국화장품제조',
#  'A011500한농화성',
#  'A002390한독',
#  'A014790한라',
#  'A060980한라홀딩스',
#  'A053690한미글로벌',
#  'A042700한미반도체',
#  'A008930한미사이언스',
#  'A128940한미약품',
#  'A009240한샘',
#  'A020000한섬',
#  'A003680한성기업',
#  'A105630한세실업',
#  'A069640한세엠케이',
#  'A016450한세예스24홀딩스',
#  'A010420한솔PNS',
#  'A009180한솔로지스틱스',
#  'A213500한솔제지',
#  'A014680한솔케미칼',
#  'A004710한솔테크닉스',
#  'A004150한솔홀딩스',
#  'A025750한솔홈데코',
#  'A004960한신공영',
#  'A011700한신기계',
#  'A001750한양증권',
#  'A018880한온시스템',
#  'A009420한올바이오파마',
#  'A014130한익스프레스',
#  'A300720한일시멘트',
#  'A002220한일철강',
#  'A006390한일현대시멘트',
#  'A003300한일홀딩스',
#  'A051600한전KPS',
#  'A052690한전기술',
#  'A130660한전산업',
#  'A002320한진',
#  'A003480한진중공업홀딩스',
#  'A180640한진칼',
#  'A005110한창',
#  'A009460한창제지',
#  'A372910한컴라이프케어',
#  'A000880한화',
#  'A088350한화생명',
#  'A000370한화손해보험',
#  'A009830한화솔루션',
#  'A272210한화시스템',
#  'A012450한화에어로스페이스',
#  'A003530한화투자증권',
#  'A195870해성디에스',
#  'A101530해태제과식품',
#  'A143210핸즈코퍼레이션',
#  'A000720현대건설',
#  'A267270현대건설기계',
#  'A005440현대그린푸드',
#  'A086280현대글로비스',
#  'A042670현대두산인프라코어',
#  'A064350현대로템',
#  'A079430현대리바트',
#  'A012330현대모비스',
#  'A010620현대미포조선',
#  'A069960현대백화점',
#  'A004560현대비앤지스틸',
#  'A004310현대약품',
#  'A322000현대에너지솔루션',
#  'A017800현대엘리베이',
#  'A307950현대오토에버',
#  'A011210현대위아',
#  'A267260현대일렉트릭',
#  'A004020현대제철',
#  'A329180현대중공업',
#  'A005380현대차',
#  'A001500현대차증권',
#  'A011760현대코퍼레이션',
#  'A227840현대코퍼레이션홀딩스',
#  'A126560현대퓨처넷',
#  'A001450현대해상',
#  'A057050현대홈쇼핑',
#  'A093240형지엘리트',
#  'A003010혜인',
#  'A111110호전실업',
#  'A008770호텔신라',
#  'A002460화성산업',
#  'A378850화승알앤에이',
#  'A241590화승엔터프라이즈',
#  'A006060화승인더',
#  'A013520화승코퍼레이션',
#  'A010690화신',
#  'A133820화인베스틸',
#  'A010660화천기계',
#  'A000850화천기공',
#  'A016580환인제약',
#  'A032560황금에스티',
#  'A004800효성',
#  'A094280효성ITX',
#  'A298040효성중공업',
#  'A298050효성첨단소재',
#  'A298020효성티앤씨',
#  'A298000효성화학',
#  'A093370후성',
#  'A081660휠라홀딩스',
#  'A005870휴니드',
#  'A079980휴비스',
#  'A005010휴스틸',
#  'A000540흥국화재',
#  'A003280흥아해운']
