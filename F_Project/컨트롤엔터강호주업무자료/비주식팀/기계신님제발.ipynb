# %% [markdown]
# # IMPORT

# %%
import pandas as pd

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pickle
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# NanumBarunGothic

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # DATA LOAD

# %%
rtn_df=pd.read_csv("/content/gdrive/MyDrive/컨트롤엔터산악회/비주식팀/최종데이터셋.csv")

# %%
df3=rtn_df[['Date','코스피']]
df3.Date=pd.to_datetime(df3.Date)
df3=df3.set_index('Date')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
rtn_df['Date']=pd.to_datetime(rtn_df['Date'])
rtn_df=rtn_df.set_index('Date')

# %%
rtn_df=rtn_df[rtn_df['상승']==0]
rtn_df
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-04  0.000084 -0.000864 -0.001079  0.009819  0.030728  0.011425
# 2022-05-05  0.000000  0.000000  0.000000 -0.004196 -0.005292 -0.027030
# 2022-05-06  0.000109  0.001001 -0.012424  0.001961  0.001061 -0.011940
# 2022-05-09  0.000202  0.002147  0.000000 -0.014940 -0.046284 -0.045043
# 2022-05-10  0.000063  0.000674 -0.018298 -0.008557 -0.005939 -0.018388
#
#                nsd로그  상승          코스피
# Date
# 2006-03-01 -0.000493   0  1371.589966
# 2006-03-02 -0.012176   0  1367.699951
# 2006-03-03  0.017103   0  1328.949951
# 2006-03-06 -0.018103   0  1344.760010
# 2006-03-07 -0.043212   0  1316.670044
# ...              ...  ..          ...
# 2022-05-04  0.014217   0  2677.570068
# 2022-05-05 -0.033019   0  2677.570068
# 2022-05-06 -0.016993   0  2644.510010
# 2022-05-09 -0.040948   0  2644.510010
# 2022-05-10 -0.002740   0  2596.560059
#
# [2258 rows x 9 columns]

# %%
rtn_df=rtn_df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
rtn_df_train=rtn_df.loc[:'2017-07-02']
rtn_df_test=rtn_df.loc['2017-07-03':]

# %%
rtn_df_train
# Out:
#                단기채로그     중기채로그     ksp로그     iau로그     dbc로그     vnq로그  \
# Date
# 2006-03-01  0.000000  0.000000  0.000000  0.001961 -0.002149  0.005808
# 2006-03-02  0.000263 -0.000102 -0.002840  0.011332  0.017911 -0.001220
# 2006-03-03  0.000105  0.000438 -0.028741 -0.007067  0.009256 -0.005508
# 2006-03-06  0.000326 -0.000830  0.011826 -0.018973 -0.016041  0.017942
# 2006-03-07  0.000094 -0.000840 -0.021110 -0.005072 -0.017601 -0.012129
# ...              ...       ...       ...       ...       ...       ...
# 2016-04-25  0.000143  0.000567 -0.000466  0.001678 -0.000712  0.008278
# 2016-04-26  0.000051  0.000142  0.002518  0.005017  0.012730  0.003872
# 2016-04-27  0.000043 -0.000138 -0.002097  0.002499  0.009094 -0.000604
# 2016-04-28  0.000043  0.000220 -0.007206  0.017320  0.005556 -0.002056
# 2016-04-29  0.000044 -0.000117 -0.003394  0.020235  0.009649 -0.009245
#
#                nsd로그
# Date
# 2006-03-01 -0.000493
# 2006-03-02 -0.012176
# 2006-03-03  0.017103
# 2006-03-06 -0.018103
# 2006-03-07 -0.043212
# ...              ...
# 2016-04-25  0.002809
# 2016-04-26  0.003733
# 2016-04-27 -0.004357
# 2016-04-28 -0.020002
# 2016-04-29 -0.018464
#
# [1387 rows x 7 columns]

# %% [markdown]
# # 학습 데이터 생성

# %%
# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
#
# 1. 학습 데이터와 평가 데이터 생성 모듈.
#
# 참고 : https://blog.naver.com/chunjein/222492404960
#        https://blog.naver.com/chunjein/222494724278
#        https://blog.naver.com/chunjein/222496640766
#
# 2021.08.27   blog.naver.com/chunjein (조성현)
# ------------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle


N_STOCKS = 7  # 포트폴리오를 구성할 주식 종목 개수
N_TIME = 20    # look back window size
N_FUTURE = 20  # 미래 20 기간의 최적 포트폴리오를 추정할 예정이다.


# 1. 학습과 performance-test에 사용할 데이터를 생성한다.
# --------------------------------------------------
# 수익률 sequence 데이터를 생성한다.
def make_sequence(x):
    T = N_TIME + N_FUTURE
    x_seq = np.expand_dims(np.array(x.iloc[0:T, :]), 0)
    
    for i in range(1, len(x) - T + 1):
        d = np.expand_dims(np.array(x.iloc[i:(i+T), :]), 0)
        x_seq = np.concatenate((x_seq, d))
        
    return x_seq

# 학습 데이터와 시험 데이터를 생성한다. 시험 데이터는 향후 performance test용으로
# 사용한다. 학습 데이터 80%, 시험 데이터 20%
n = int(rtn_df.shape[0] * 0.9)
rtn_train = make_sequence(rtn_df_train)
rtn_test = make_sequence(rtn_df_test)   # 이 데이터는 학습에 사용하지 않는다.
 
print("# 수익률 sequence 데이터를 생성했습니다.")

# 2. 학습에 사용할 데이터를 생성한다.
# -------------------------------
# 다음 기간 (N_FUTURE 기간)을 학습/예측하도록 데이터를 구성한다.
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])
                     
xc_test = np.array([x[:N_TIME] for x in rtn_test])
xf_test = np.array([x[-N_FUTURE:] for x in rtn_test])

# 4.performace_test.py에서 성과 차트를 그릴 때 x축 인덱스로 사용하기 위해
# xf_test[0][0] 위치부터 끝까지 날짜를 기록해 둔다.
test_date = rtn_df_test[N_TIME:].index
# Out:
# # 수익률 sequence 데이터를 생성했습니다.

# %% [markdown]
# ## 데이터셋 나눠서 만들기(상승)

# %%
df=pd.read_csv("/content/gdrive/MyDrive/컨트롤엔터산악회/비주식팀/최종데이터셋.csv")
df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')

# %%
df=df[df['상승']==0]

# %%
df=df[['단기채로그', '중기채로그', 'ksp로그', 'iau로그', 'dbc로그', 'vnq로그', 'nsd로그']]

# %%
up_2006=df.loc['2006-10-02':'2007-10-31']
up_2009=df.loc['2009-01-02':'2010-01-29']
up_2012=df.loc['2012-03-01':'2013-09-30']
up_2014=df.loc['2014-09-01':'2015-05-29']
up_2015=df.loc['2015-10-01':'2016-01-29']
up_2016=df.loc['2016-05-02':'2017-06-30']
up_2019=df.loc['2019-12-02':'2020-03-31']
#up_2020=df.loc['2020-07-01':'2021-08-31']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(up_2006.iloc[0:T, :]), 0)

for i in range(1, len(up_2006) - T + 1):
    d = np.expand_dims(np.array(up_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2009) - T + 1):
    d = np.expand_dims(np.array(up_2009.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2012) - T + 1):
    d = np.expand_dims(np.array(up_2012.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2014) - T + 1):
    d = np.expand_dims(np.array(up_2014.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2015) - T + 1):
    d = np.expand_dims(np.array(up_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2016) - T + 1):
    d = np.expand_dims(np.array(up_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(up_2019) - T + 1):
    d = np.expand_dims(np.array(up_2019.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
#for i in range(0, len(up_2020) - T + 1):
    #d = np.expand_dims(np.array(up_2020.iloc[i:(i+T), :]), 0)
    #x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# ##  데이터셋 나눠서 만들기(하강)

# %%
down_2006=df.loc['2006-03-01':'2006-09-29']
down_2007=df.loc['2007-11-01':'2008-12-31']
down_2010=df.loc['2010-02-01':'2012-02-29']
down_2013=df.loc['2013-10-01':'2014-08-29']
down_2015=df.loc['2015-06-01':'2015-09-30']
down_2016=df.loc['2016-02-01':'2016-04-29']
down_2017=df.loc['2017-07-03':'2019-11-29']
down_2020=df.loc['2020-04-01':'2020-06-30']
#down_2021=df.loc['2021-09-01':'2022-05-10']

# %%
#기간별 잘라서 train셋 만들기
T = N_TIME + N_FUTURE
x_seq = np.expand_dims(np.array(down_2006.iloc[0:T, :]), 0)

for i in range(1, len(down_2006) - T + 1):
    d = np.expand_dims(np.array(down_2006.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2007) - T + 1):
    d = np.expand_dims(np.array(down_2007.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2010) - T + 1):
    d = np.expand_dims(np.array(down_2010.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2013) - T + 1):
    d = np.expand_dims(np.array(down_2013.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2015) - T + 1):
    d = np.expand_dims(np.array(down_2015.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2016) - T + 1):
    d = np.expand_dims(np.array(down_2016.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2017) - T + 1):
    d = np.expand_dims(np.array(down_2017.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
for i in range(0, len(down_2020) - T + 1):
    d = np.expand_dims(np.array(down_2020.iloc[i:(i+T), :]), 0)
    x_seq = np.concatenate((x_seq, d))
# for i in range(0, len(down_2021) - T + 1):
#     d = np.expand_dims(np.array(down_2021.iloc[i:(i+T), :]), 0)
#     x_seq = np.concatenate((x_seq, d))

# %% [markdown]
# # rtn_train 구성하기

# %%
# rtn_train 값에 기간별로 자른 값 집어넣기
rtn_train = x_seq
xc_train = np.array([x[:N_TIME] for x in rtn_train])
xf_train = np.array([x[-N_FUTURE:] for x in rtn_train])

# %% [markdown]
# # 모델 학습

# %%
# random seed 값 고정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') *100
xf_train = xf_train.astype('float32') *100
xc_test = xc_test.astype('float32') *100
xf_test = xf_test.astype('float32') *100

# %%
N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
#xc_train, xf_train = shuffle(xc_train, xf_train)

# Markowitz Network를 생성한다.
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.01
REG_CONST = 0.0
SAVE_MODEL = 'data/3-1.MPN_LSTM.h5'

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# Markowitz Network에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)   # W = (None, 1, 50)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2) # R = (None, 50, 1)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_sum(objective, axis=0)


lstm = LSTM( units = 7, # units의 값은 layer 통일이 제일 효과적이다.
             input_shape=(N_TIME, N_STOCKS),  #(4980, 20, 5)  --> (20,5),    
             dropout=0.0,
             recurrent_dropout=0.0,
             return_sequences=False
      )
model = Sequential()
model.add( lstm )
model.add( Dense(N_STOCKS, activation='tanh') )
model.add(Activation('softmax'))


# 마코비츠의 최적 weights
with tf.device("/device:GPU:0"):
    #y_output = Activation('softmax')(y_output)

    
    model.compile(loss = markowitz_objective, 
                optimizer = Adam(learning_rate = 1e-5),
                )
    stop = EarlyStopping(patience=10, monitor='val_loss')

    model.summary()

    # MPN을 학습하고 결과를 저장한다.
    hist = model.fit(xc_train, xf_train, epochs=1000, batch_size = 64, 
                     #callbacks=[stop],
                    validation_data = (xc_test, xf_test))
    #model.save(SAVE_MODEL)

# loss trajectory를 확인한다.
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(np.negative(hist.history['loss']), label='Train loss')
plt.plot(np.negative(hist.history['val_loss']), label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 확인용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()
    
check_w(0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7)                 420
#
#  dense (Dense)               (None, 7)                 56
#
#  activation (Activation)     (None, 7)                 0
#
# =================================================================
# Total params: 476
# Trainable params: 476
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 28/28 [==============================] - 7s 23ms/step - loss: -0.0151 - val_loss: -1.5750
# Epoch 2/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0448 - val_loss: -1.5751
# Epoch 3/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0352 - val_loss: -1.5751
# Epoch 4/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0211 - val_loss: -1.5751
# Epoch 5/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0161 - val_loss: -1.5751
# Epoch 6/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0393 - val_loss: -1.5751
# Epoch 7/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0170 - val_loss: -1.5751
# Epoch 8/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0377 - val_loss: -1.5751
# Epoch 9/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0199 - val_loss: -1.5751
# Epoch 10/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0190 - val_loss: -1.5752
# Epoch 11/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0397 - val_loss: -1.5752
# Epoch 12/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0358 - val_loss: -1.5752
# Epoch 13/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0284 - val_loss: -1.5752
# Epoch 14/1000
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: -1.5752
# Epoch 15/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0487 - val_loss: -1.5753
# Epoch 16/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0544 - val_loss: -1.5753
# Epoch 17/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0206 - val_loss: -1.5753
# Epoch 18/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0276 - val_loss: -1.5753
# Epoch 19/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0613 - val_loss: -1.5753
# Epoch 20/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0606 - val_loss: -1.5753
# Epoch 21/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0490 - val_loss: -1.5754
# Epoch 22/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0244 - val_loss: -1.5754
# Epoch 23/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0125 - val_loss: -1.5754
# Epoch 24/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0403 - val_loss: -1.5754
# Epoch 25/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0599 - val_loss: -1.5754
# Epoch 26/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0354 - val_loss: -1.5754
# Epoch 27/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0628 - val_loss: -1.5754
# Epoch 28/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0582 - val_loss: -1.5755
# Epoch 29/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0467 - val_loss: -1.5755
# Epoch 30/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0643 - val_loss: -1.5755
# Epoch 31/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0556 - val_loss: -1.5755
# Epoch 32/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0428 - val_loss: -1.5755
# Epoch 33/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0629 - val_loss: -1.5755
# Epoch 34/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0511 - val_loss: -1.5755
# Epoch 35/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0427 - val_loss: -1.5756
# Epoch 36/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0363 - val_loss: -1.5756
# Epoch 37/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0540 - val_loss: -1.5756
# Epoch 38/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0660 - val_loss: -1.5756
# Epoch 39/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0412 - val_loss: -1.5756
# Epoch 40/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0533 - val_loss: -1.5756
# Epoch 41/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0631 - val_loss: -1.5757
# Epoch 42/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0637 - val_loss: -1.5757
# Epoch 43/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0575 - val_loss: -1.5757
# Epoch 44/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0713 - val_loss: -1.5757
# Epoch 45/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0531 - val_loss: -1.5757
# Epoch 46/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0828 - val_loss: -1.5757
# Epoch 47/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1017 - val_loss: -1.5757
# Epoch 48/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0896 - val_loss: -1.5758
# Epoch 49/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0785 - val_loss: -1.5758
# Epoch 50/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0564 - val_loss: -1.5758
# Epoch 51/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0691 - val_loss: -1.5758
# Epoch 52/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0799 - val_loss: -1.5758
# Epoch 53/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0826 - val_loss: -1.5758
# Epoch 54/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0595 - val_loss: -1.5758
# Epoch 55/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0769 - val_loss: -1.5759
# Epoch 56/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0839 - val_loss: -1.5759
# Epoch 57/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0978 - val_loss: -1.5759
# Epoch 58/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0879 - val_loss: -1.5759
# Epoch 59/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0959 - val_loss: -1.5759
# Epoch 60/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0943 - val_loss: -1.5760
# Epoch 61/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.0713 - val_loss: -1.5760
# Epoch 62/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0843 - val_loss: -1.5760
# Epoch 63/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0874 - val_loss: -1.5760
# Epoch 64/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0702 - val_loss: -1.5760
# Epoch 65/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1053 - val_loss: -1.5761
# Epoch 66/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0800 - val_loss: -1.5761
# Epoch 67/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0978 - val_loss: -1.5761
# Epoch 68/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0824 - val_loss: -1.5761
# Epoch 69/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1030 - val_loss: -1.5762
# Epoch 70/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0919 - val_loss: -1.5762
# Epoch 71/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0778 - val_loss: -1.5762
# Epoch 72/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1138 - val_loss: -1.5762
# Epoch 73/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1109 - val_loss: -1.5762
# Epoch 74/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1256 - val_loss: -1.5763
# Epoch 75/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0781 - val_loss: -1.5763
# Epoch 76/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0891 - val_loss: -1.5763
# Epoch 77/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.0877 - val_loss: -1.5763
# Epoch 78/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1387 - val_loss: -1.5763
# Epoch 79/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1140 - val_loss: -1.5764
# Epoch 80/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.1501 - val_loss: -1.5764
# Epoch 81/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1340 - val_loss: -1.5764
# Epoch 82/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.1237 - val_loss: -1.5764
# Epoch 83/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1592 - val_loss: -1.5764
# Epoch 84/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.0931 - val_loss: -1.5765
# Epoch 85/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1167 - val_loss: -1.5765
# Epoch 86/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1161 - val_loss: -1.5765
# Epoch 87/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1180 - val_loss: -1.5765
# Epoch 88/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1096 - val_loss: -1.5765
# Epoch 89/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1180 - val_loss: -1.5766
# Epoch 90/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1273 - val_loss: -1.5766
# Epoch 91/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1364 - val_loss: -1.5766
# Epoch 92/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1185 - val_loss: -1.5766
# Epoch 93/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1272 - val_loss: -1.5767
# Epoch 94/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1282 - val_loss: -1.5767
# Epoch 95/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1274 - val_loss: -1.5767
# Epoch 96/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1247 - val_loss: -1.5767
# Epoch 97/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1091 - val_loss: -1.5768
# Epoch 98/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1407 - val_loss: -1.5768
# Epoch 99/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1320 - val_loss: -1.5768
# Epoch 100/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1324 - val_loss: -1.5768
# Epoch 101/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1552 - val_loss: -1.5768
# Epoch 102/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1193 - val_loss: -1.5769
# Epoch 103/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1425 - val_loss: -1.5769
# Epoch 104/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1575 - val_loss: -1.5769
# Epoch 105/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1330 - val_loss: -1.5769
# Epoch 106/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1550 - val_loss: -1.5770
# Epoch 107/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1548 - val_loss: -1.5770
# Epoch 108/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1379 - val_loss: -1.5770
# Epoch 109/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1468 - val_loss: -1.5770
# Epoch 110/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1281 - val_loss: -1.5770
# Epoch 111/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1731 - val_loss: -1.5771
# Epoch 112/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1528 - val_loss: -1.5771
# Epoch 113/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1462 - val_loss: -1.5771
# Epoch 114/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1535 - val_loss: -1.5772
# Epoch 115/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1677 - val_loss: -1.5772
# Epoch 116/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1688 - val_loss: -1.5772
# Epoch 117/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1469 - val_loss: -1.5772
# Epoch 118/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1353 - val_loss: -1.5772
# Epoch 119/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1621 - val_loss: -1.5773
# Epoch 120/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1674 - val_loss: -1.5773
# Epoch 121/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1844 - val_loss: -1.5773
# Epoch 122/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1563 - val_loss: -1.5773
# Epoch 123/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1604 - val_loss: -1.5774
# Epoch 124/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1455 - val_loss: -1.5774
# Epoch 125/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1635 - val_loss: -1.5774
# Epoch 126/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1657 - val_loss: -1.5775
# Epoch 127/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1477 - val_loss: -1.5775
# Epoch 128/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1819 - val_loss: -1.5775
# Epoch 129/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1616 - val_loss: -1.5775
# Epoch 130/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1869 - val_loss: -1.5776
# Epoch 131/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1581 - val_loss: -1.5776
# Epoch 132/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1777 - val_loss: -1.5776
# Epoch 133/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1751 - val_loss: -1.5776
# Epoch 134/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1595 - val_loss: -1.5777
# Epoch 135/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1502 - val_loss: -1.5777
# Epoch 136/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1707 - val_loss: -1.5778
# Epoch 137/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1694 - val_loss: -1.5778
# Epoch 138/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1903 - val_loss: -1.5778
# Epoch 139/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1857 - val_loss: -1.5778
# Epoch 140/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1866 - val_loss: -1.5779
# Epoch 141/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2103 - val_loss: -1.5779
# Epoch 142/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1740 - val_loss: -1.5780
# Epoch 143/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1955 - val_loss: -1.5780
# Epoch 144/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1868 - val_loss: -1.5780
# Epoch 145/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2279 - val_loss: -1.5780
# Epoch 146/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1768 - val_loss: -1.5781
# Epoch 147/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2133 - val_loss: -1.5781
# Epoch 148/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1843 - val_loss: -1.5781
# Epoch 149/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1763 - val_loss: -1.5782
# Epoch 150/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2132 - val_loss: -1.5782
# Epoch 151/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1848 - val_loss: -1.5782
# Epoch 152/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1845 - val_loss: -1.5783
# Epoch 153/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2049 - val_loss: -1.5783
# Epoch 154/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1975 - val_loss: -1.5783
# Epoch 155/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1948 - val_loss: -1.5784
# Epoch 156/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1779 - val_loss: -1.5784
# Epoch 157/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1953 - val_loss: -1.5784
# Epoch 158/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.1882 - val_loss: -1.5785
# Epoch 159/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1808 - val_loss: -1.5785
# Epoch 160/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1866 - val_loss: -1.5785
# Epoch 161/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.2093 - val_loss: -1.5786
# Epoch 162/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1944 - val_loss: -1.5786
# Epoch 163/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2105 - val_loss: -1.5786
# Epoch 164/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2190 - val_loss: -1.5787
# Epoch 165/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1970 - val_loss: -1.5787
# Epoch 166/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2148 - val_loss: -1.5787
# Epoch 167/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2048 - val_loss: -1.5788
# Epoch 168/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2064 - val_loss: -1.5788
# Epoch 169/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2025 - val_loss: -1.5789
# Epoch 170/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2101 - val_loss: -1.5789
# Epoch 171/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2350 - val_loss: -1.5789
# Epoch 172/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2117 - val_loss: -1.5790
# Epoch 173/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.1978 - val_loss: -1.5790
# Epoch 174/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.1801 - val_loss: -1.5790
# Epoch 175/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2163 - val_loss: -1.5791
# Epoch 176/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2205 - val_loss: -1.5791
# Epoch 177/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2366 - val_loss: -1.5792
# Epoch 178/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2067 - val_loss: -1.5792
# Epoch 179/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2411 - val_loss: -1.5793
# Epoch 180/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2121 - val_loss: -1.5793
# Epoch 181/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2326 - val_loss: -1.5793
# Epoch 182/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2202 - val_loss: -1.5794
# Epoch 183/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2369 - val_loss: -1.5794
# Epoch 184/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2417 - val_loss: -1.5795
# Epoch 185/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2332 - val_loss: -1.5795
# Epoch 186/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2281 - val_loss: -1.5795
# Epoch 187/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2222 - val_loss: -1.5796
# Epoch 188/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2485 - val_loss: -1.5796
# Epoch 189/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2369 - val_loss: -1.5797
# Epoch 190/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2458 - val_loss: -1.5797
# Epoch 191/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2213 - val_loss: -1.5798
# Epoch 192/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2350 - val_loss: -1.5798
# Epoch 193/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2282 - val_loss: -1.5798
# Epoch 194/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2663 - val_loss: -1.5799
# Epoch 195/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2472 - val_loss: -1.5800
# Epoch 196/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2450 - val_loss: -1.5800
# Epoch 197/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2496 - val_loss: -1.5800
# Epoch 198/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2391 - val_loss: -1.5801
# Epoch 199/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2384 - val_loss: -1.5801
# Epoch 200/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2578 - val_loss: -1.5802
# Epoch 201/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2376 - val_loss: -1.5802
# Epoch 202/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2608 - val_loss: -1.5803
# Epoch 203/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2623 - val_loss: -1.5803
# Epoch 204/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2446 - val_loss: -1.5803
# Epoch 205/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2588 - val_loss: -1.5804
# Epoch 206/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2548 - val_loss: -1.5805
# Epoch 207/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2528 - val_loss: -1.5805
# Epoch 208/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2806 - val_loss: -1.5806
# Epoch 209/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2508 - val_loss: -1.5806
# Epoch 210/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2698 - val_loss: -1.5807
# Epoch 211/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2430 - val_loss: -1.5807
# Epoch 212/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2604 - val_loss: -1.5807
# Epoch 213/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2566 - val_loss: -1.5808
# Epoch 214/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2757 - val_loss: -1.5809
# Epoch 215/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2620 - val_loss: -1.5809
# Epoch 216/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3198 - val_loss: -1.5810
# Epoch 217/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2909 - val_loss: -1.5810
# Epoch 218/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2500 - val_loss: -1.5810
# Epoch 219/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2712 - val_loss: -1.5811
# Epoch 220/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2694 - val_loss: -1.5812
# Epoch 221/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2835 - val_loss: -1.5812
# Epoch 222/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2696 - val_loss: -1.5813
# Epoch 223/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2738 - val_loss: -1.5813
# Epoch 224/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2738 - val_loss: -1.5814
# Epoch 225/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2750 - val_loss: -1.5814
# Epoch 226/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2701 - val_loss: -1.5815
# Epoch 227/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2786 - val_loss: -1.5815
# Epoch 228/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2856 - val_loss: -1.5816
# Epoch 229/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.2710 - val_loss: -1.5816
# Epoch 230/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2853 - val_loss: -1.5817
# Epoch 231/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2858 - val_loss: -1.5817
# Epoch 232/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.2894 - val_loss: -1.5818
# Epoch 233/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.2801 - val_loss: -1.5818
# Epoch 234/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2725 - val_loss: -1.5819
# Epoch 235/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2691 - val_loss: -1.5819
# Epoch 236/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2849 - val_loss: -1.5820
# Epoch 237/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2853 - val_loss: -1.5821
# Epoch 238/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3031 - val_loss: -1.5821
# Epoch 239/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2925 - val_loss: -1.5822
# Epoch 240/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2972 - val_loss: -1.5822
# Epoch 241/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3086 - val_loss: -1.5823
# Epoch 242/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3025 - val_loss: -1.5823
# Epoch 243/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2990 - val_loss: -1.5824
# Epoch 244/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2997 - val_loss: -1.5825
# Epoch 245/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3081 - val_loss: -1.5825
# Epoch 246/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.2987 - val_loss: -1.5826
# Epoch 247/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3021 - val_loss: -1.5826
# Epoch 248/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.2954 - val_loss: -1.5827
# Epoch 249/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3400 - val_loss: -1.5828
# Epoch 250/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3038 - val_loss: -1.5828
# Epoch 251/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3062 - val_loss: -1.5829
# Epoch 252/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3430 - val_loss: -1.5829
# Epoch 253/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3253 - val_loss: -1.5830
# Epoch 254/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3242 - val_loss: -1.5831
# Epoch 255/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3009 - val_loss: -1.5831
# Epoch 256/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3400 - val_loss: -1.5832
# Epoch 257/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3136 - val_loss: -1.5832
# Epoch 258/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3066 - val_loss: -1.5833
# Epoch 259/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3214 - val_loss: -1.5833
# Epoch 260/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3289 - val_loss: -1.5834
# Epoch 261/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3102 - val_loss: -1.5835
# Epoch 262/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3241 - val_loss: -1.5835
# Epoch 263/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3246 - val_loss: -1.5836
# Epoch 264/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3096 - val_loss: -1.5837
# Epoch 265/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3186 - val_loss: -1.5837
# Epoch 266/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3384 - val_loss: -1.5838
# Epoch 267/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3157 - val_loss: -1.5839
# Epoch 268/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3161 - val_loss: -1.5839
# Epoch 269/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3221 - val_loss: -1.5840
# Epoch 270/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3270 - val_loss: -1.5841
# Epoch 271/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.3381 - val_loss: -1.5841
# Epoch 272/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3170 - val_loss: -1.5842
# Epoch 273/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3299 - val_loss: -1.5843
# Epoch 274/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3176 - val_loss: -1.5843
# Epoch 275/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3249 - val_loss: -1.5844
# Epoch 276/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3313 - val_loss: -1.5845
# Epoch 277/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3495 - val_loss: -1.5845
# Epoch 278/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3600 - val_loss: -1.5846
# Epoch 279/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3334 - val_loss: -1.5847
# Epoch 280/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3526 - val_loss: -1.5847
# Epoch 281/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3474 - val_loss: -1.5848
# Epoch 282/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3279 - val_loss: -1.5849
# Epoch 283/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3545 - val_loss: -1.5849
# Epoch 284/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3362 - val_loss: -1.5850
# Epoch 285/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3386 - val_loss: -1.5851
# Epoch 286/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3568 - val_loss: -1.5852
# Epoch 287/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3665 - val_loss: -1.5852
# Epoch 288/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3480 - val_loss: -1.5853
# Epoch 289/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3370 - val_loss: -1.5854
# Epoch 290/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3406 - val_loss: -1.5854
# Epoch 291/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3456 - val_loss: -1.5855
# Epoch 292/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3597 - val_loss: -1.5856
# Epoch 293/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3519 - val_loss: -1.5856
# Epoch 294/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3863 - val_loss: -1.5857
# Epoch 295/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3453 - val_loss: -1.5858
# Epoch 296/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3530 - val_loss: -1.5859
# Epoch 297/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3749 - val_loss: -1.5859
# Epoch 298/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3443 - val_loss: -1.5860
# Epoch 299/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3581 - val_loss: -1.5861
# Epoch 300/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3582 - val_loss: -1.5862
# Epoch 301/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3579 - val_loss: -1.5862
# Epoch 302/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3629 - val_loss: -1.5863
# Epoch 303/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3633 - val_loss: -1.5864
# Epoch 304/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3617 - val_loss: -1.5864
# Epoch 305/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3544 - val_loss: -1.5865
# Epoch 306/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.3619 - val_loss: -1.5866
# Epoch 307/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3767 - val_loss: -1.5867
# Epoch 308/1000
# 28/28 [==============================] - 0s 6ms/step - loss: -0.3607 - val_loss: -1.5868
# Epoch 309/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3655 - val_loss: -1.5868
# Epoch 310/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3740 - val_loss: -1.5869
# Epoch 311/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3668 - val_loss: -1.5870
# Epoch 312/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3618 - val_loss: -1.5871
# Epoch 313/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3736 - val_loss: -1.5871
# Epoch 314/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3853 - val_loss: -1.5872
# Epoch 315/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3738 - val_loss: -1.5873
# Epoch 316/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3833 - val_loss: -1.5874
# Epoch 317/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3761 - val_loss: -1.5875
# Epoch 318/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3778 - val_loss: -1.5875
# Epoch 319/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3740 - val_loss: -1.5876
# Epoch 320/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3831 - val_loss: -1.5877
# Epoch 321/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3957 - val_loss: -1.5878
# Epoch 322/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3839 - val_loss: -1.5879
# Epoch 323/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3950 - val_loss: -1.5879
# Epoch 324/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3878 - val_loss: -1.5880
# Epoch 325/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3680 - val_loss: -1.5881
# Epoch 326/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4140 - val_loss: -1.5882
# Epoch 327/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3884 - val_loss: -1.5883
# Epoch 328/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4007 - val_loss: -1.5883
# Epoch 329/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3934 - val_loss: -1.5884
# Epoch 330/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3973 - val_loss: -1.5885
# Epoch 331/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4152 - val_loss: -1.5886
# Epoch 332/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3847 - val_loss: -1.5887
# Epoch 333/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3979 - val_loss: -1.5888
# Epoch 334/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4218 - val_loss: -1.5889
# Epoch 335/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4150 - val_loss: -1.5889
# Epoch 336/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4065 - val_loss: -1.5890
# Epoch 337/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3778 - val_loss: -1.5891
# Epoch 338/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4076 - val_loss: -1.5892
# Epoch 339/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3929 - val_loss: -1.5893
# Epoch 340/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4161 - val_loss: -1.5894
# Epoch 341/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4160 - val_loss: -1.5895
# Epoch 342/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4102 - val_loss: -1.5895
# Epoch 343/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3990 - val_loss: -1.5896
# Epoch 344/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4209 - val_loss: -1.5897
# Epoch 345/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.3909 - val_loss: -1.5898
# Epoch 346/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4359 - val_loss: -1.5899
# Epoch 347/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4062 - val_loss: -1.5900
# Epoch 348/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.3978 - val_loss: -1.5901
# Epoch 349/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4331 - val_loss: -1.5902
# Epoch 350/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4153 - val_loss: -1.5902
# Epoch 351/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4340 - val_loss: -1.5904
# Epoch 352/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4360 - val_loss: -1.5905
# Epoch 353/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4440 - val_loss: -1.5905
# Epoch 354/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4221 - val_loss: -1.5906
# Epoch 355/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4239 - val_loss: -1.5907
# Epoch 356/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4097 - val_loss: -1.5908
# Epoch 357/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4387 - val_loss: -1.5909
# Epoch 358/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4179 - val_loss: -1.5910
# Epoch 359/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4169 - val_loss: -1.5911
# Epoch 360/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4159 - val_loss: -1.5912
# Epoch 361/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4422 - val_loss: -1.5913
# Epoch 362/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4395 - val_loss: -1.5914
# Epoch 363/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4390 - val_loss: -1.5914
# Epoch 364/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4186 - val_loss: -1.5915
# Epoch 365/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4350 - val_loss: -1.5916
# Epoch 366/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4283 - val_loss: -1.5917
# Epoch 367/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4148 - val_loss: -1.5918
# Epoch 368/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4198 - val_loss: -1.5919
# Epoch 369/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4328 - val_loss: -1.5920
# Epoch 370/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4284 - val_loss: -1.5921
# Epoch 371/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4340 - val_loss: -1.5922
# Epoch 372/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4418 - val_loss: -1.5923
# Epoch 373/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4483 - val_loss: -1.5924
# Epoch 374/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4313 - val_loss: -1.5925
# Epoch 375/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4384 - val_loss: -1.5926
# Epoch 376/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4742 - val_loss: -1.5927
# Epoch 377/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4340 - val_loss: -1.5928
# Epoch 378/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4501 - val_loss: -1.5929
# Epoch 379/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4375 - val_loss: -1.5930
# Epoch 380/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4583 - val_loss: -1.5931
# Epoch 381/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4694 - val_loss: -1.5932
# Epoch 382/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4506 - val_loss: -1.5933
# Epoch 383/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4545 - val_loss: -1.5934
# Epoch 384/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4683 - val_loss: -1.5935
# Epoch 385/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4506 - val_loss: -1.5936
# Epoch 386/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4461 - val_loss: -1.5937
# Epoch 387/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4832 - val_loss: -1.5938
# Epoch 388/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4680 - val_loss: -1.5939
# Epoch 389/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4631 - val_loss: -1.5940
# Epoch 390/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4556 - val_loss: -1.5941
# Epoch 391/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4707 - val_loss: -1.5942
# Epoch 392/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4690 - val_loss: -1.5943
# Epoch 393/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4722 - val_loss: -1.5944
# Epoch 394/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4651 - val_loss: -1.5945
# Epoch 395/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4663 - val_loss: -1.5946
# Epoch 396/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4790 - val_loss: -1.5947
# Epoch 397/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4969 - val_loss: -1.5948
# Epoch 398/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4824 - val_loss: -1.5949
# Epoch 399/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4712 - val_loss: -1.5950
# Epoch 400/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4709 - val_loss: -1.5951
# Epoch 401/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4954 - val_loss: -1.5953
# Epoch 402/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5118 - val_loss: -1.5954
# Epoch 403/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4670 - val_loss: -1.5955
# Epoch 404/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4714 - val_loss: -1.5956
# Epoch 405/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4775 - val_loss: -1.5957
# Epoch 406/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4908 - val_loss: -1.5958
# Epoch 407/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5001 - val_loss: -1.5959
# Epoch 408/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4756 - val_loss: -1.5960
# Epoch 409/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4962 - val_loss: -1.5961
# Epoch 410/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5101 - val_loss: -1.5962
# Epoch 411/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5137 - val_loss: -1.5964
# Epoch 412/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4729 - val_loss: -1.5965
# Epoch 413/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4848 - val_loss: -1.5966
# Epoch 414/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4848 - val_loss: -1.5967
# Epoch 415/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4867 - val_loss: -1.5968
# Epoch 416/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5001 - val_loss: -1.5969
# Epoch 417/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5049 - val_loss: -1.5970
# Epoch 418/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5117 - val_loss: -1.5972
# Epoch 419/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5047 - val_loss: -1.5972
# Epoch 420/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.4918 - val_loss: -1.5973
# Epoch 421/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5006 - val_loss: -1.5975
# Epoch 422/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.4937 - val_loss: -1.5976
# Epoch 423/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5100 - val_loss: -1.5977
# Epoch 424/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5122 - val_loss: -1.5978
# Epoch 425/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.4886 - val_loss: -1.5979
# Epoch 426/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5217 - val_loss: -1.5980
# Epoch 427/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5174 - val_loss: -1.5982
# Epoch 428/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5130 - val_loss: -1.5983
# Epoch 429/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5071 - val_loss: -1.5984
# Epoch 430/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5137 - val_loss: -1.5985
# Epoch 431/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5077 - val_loss: -1.5986
# Epoch 432/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5131 - val_loss: -1.5988
# Epoch 433/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5144 - val_loss: -1.5989
# Epoch 434/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5060 - val_loss: -1.5990
# Epoch 435/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5032 - val_loss: -1.5991
# Epoch 436/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5093 - val_loss: -1.5992
# Epoch 437/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5547 - val_loss: -1.5994
# Epoch 438/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5090 - val_loss: -1.5995
# Epoch 439/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5119 - val_loss: -1.5996
# Epoch 440/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5605 - val_loss: -1.5997
# Epoch 441/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5272 - val_loss: -1.5999
# Epoch 442/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5367 - val_loss: -1.6000
# Epoch 443/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.5323 - val_loss: -1.6001
# Epoch 444/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5232 - val_loss: -1.6002
# Epoch 445/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5550 - val_loss: -1.6003
# Epoch 446/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5412 - val_loss: -1.6004
# Epoch 447/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5429 - val_loss: -1.6006
# Epoch 448/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5310 - val_loss: -1.6007
# Epoch 449/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5515 - val_loss: -1.6008
# Epoch 450/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.5277 - val_loss: -1.6009
# Epoch 451/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5206 - val_loss: -1.6011
# Epoch 452/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5254 - val_loss: -1.6012
# Epoch 453/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.5207 - val_loss: -1.6013
# Epoch 454/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.5357 - val_loss: -1.6014
# Epoch 455/1000
# ...
# Epoch 849/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9575 - val_loss: -1.6442
# Epoch 850/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9494 - val_loss: -1.6443
# Epoch 851/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9667 - val_loss: -1.6443
# Epoch 852/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9520 - val_loss: -1.6444
# Epoch 853/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9680 - val_loss: -1.6445
# Epoch 854/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9691 - val_loss: -1.6446
# Epoch 855/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9539 - val_loss: -1.6447
# Epoch 856/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9569 - val_loss: -1.6447
# Epoch 857/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9734 - val_loss: -1.6448
# Epoch 858/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9504 - val_loss: -1.6449
# Epoch 859/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.9420 - val_loss: -1.6449
# Epoch 860/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9518 - val_loss: -1.6450
# Epoch 861/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9723 - val_loss: -1.6451
# Epoch 862/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9723 - val_loss: -1.6452
# Epoch 863/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -0.9740 - val_loss: -1.6453
# Epoch 864/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9581 - val_loss: -1.6453
# Epoch 865/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9733 - val_loss: -1.6454
# Epoch 866/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9745 - val_loss: -1.6455
# Epoch 867/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9773 - val_loss: -1.6456
# Epoch 868/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9785 - val_loss: -1.6457
# Epoch 869/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9601 - val_loss: -1.6457
# Epoch 870/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9858 - val_loss: -1.6458
# Epoch 871/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9630 - val_loss: -1.6459
# Epoch 872/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9700 - val_loss: -1.6460
# Epoch 873/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9537 - val_loss: -1.6461
# Epoch 874/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9755 - val_loss: -1.6461
# Epoch 875/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9527 - val_loss: -1.6462
# Epoch 876/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9657 - val_loss: -1.6463
# Epoch 877/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9814 - val_loss: -1.6464
# Epoch 878/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9849 - val_loss: -1.6465
# Epoch 879/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9740 - val_loss: -1.6466
# Epoch 880/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9728 - val_loss: -1.6466
# Epoch 881/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9726 - val_loss: -1.6467
# Epoch 882/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9695 - val_loss: -1.6468
# Epoch 883/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9930 - val_loss: -1.6469
# Epoch 884/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9869 - val_loss: -1.6470
# Epoch 885/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9668 - val_loss: -1.6471
# Epoch 886/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9846 - val_loss: -1.6472
# Epoch 887/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9728 - val_loss: -1.6472
# Epoch 888/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9751 - val_loss: -1.6473
# Epoch 889/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9947 - val_loss: -1.6474
# Epoch 890/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9876 - val_loss: -1.6475
# Epoch 891/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9842 - val_loss: -1.6476
# Epoch 892/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9847 - val_loss: -1.6477
# Epoch 893/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9894 - val_loss: -1.6478
# Epoch 894/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9833 - val_loss: -1.6479
# Epoch 895/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9966 - val_loss: -1.6479
# Epoch 896/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9978 - val_loss: -1.6481
# Epoch 897/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9975 - val_loss: -1.6482
# Epoch 898/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9787 - val_loss: -1.6482
# Epoch 899/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9746 - val_loss: -1.6483
# Epoch 900/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0143 - val_loss: -1.6484
# Epoch 901/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0013 - val_loss: -1.6485
# Epoch 902/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9926 - val_loss: -1.6486
# Epoch 903/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0014 - val_loss: -1.6487
# Epoch 904/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9920 - val_loss: -1.6488
# Epoch 905/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -0.9860 - val_loss: -1.6489
# Epoch 906/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0162 - val_loss: -1.6490
# Epoch 907/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9863 - val_loss: -1.6491
# Epoch 908/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0058 - val_loss: -1.6492
# Epoch 909/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0047 - val_loss: -1.6493
# Epoch 910/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9896 - val_loss: -1.6494
# Epoch 911/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0075 - val_loss: -1.6495
# Epoch 912/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9802 - val_loss: -1.6496
# Epoch 913/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0139 - val_loss: -1.6497
# Epoch 914/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0055 - val_loss: -1.6498
# Epoch 915/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -0.9989 - val_loss: -1.6499
# Epoch 916/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0113 - val_loss: -1.6500
# Epoch 917/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0059 - val_loss: -1.6501
# Epoch 918/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0143 - val_loss: -1.6502
# Epoch 919/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0372 - val_loss: -1.6503
# Epoch 920/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9921 - val_loss: -1.6504
# Epoch 921/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0056 - val_loss: -1.6505
# Epoch 922/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0040 - val_loss: -1.6506
# Epoch 923/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0032 - val_loss: -1.6507
# Epoch 924/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -0.9940 - val_loss: -1.6508
# Epoch 925/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0109 - val_loss: -1.6509
# Epoch 926/1000
# 28/28 [==============================] - 0s 14ms/step - loss: -1.0111 - val_loss: -1.6510
# Epoch 927/1000
# 28/28 [==============================] - 0s 12ms/step - loss: -1.0264 - val_loss: -1.6511
# Epoch 928/1000
# 28/28 [==============================] - 0s 13ms/step - loss: -1.0142 - val_loss: -1.6512
# Epoch 929/1000
# 28/28 [==============================] - 0s 14ms/step - loss: -1.0401 - val_loss: -1.6513
# Epoch 930/1000
# 28/28 [==============================] - 0s 13ms/step - loss: -1.0256 - val_loss: -1.6515
# Epoch 931/1000
# 28/28 [==============================] - 0s 14ms/step - loss: -1.0212 - val_loss: -1.6516
# Epoch 932/1000
# 28/28 [==============================] - 0s 15ms/step - loss: -1.0388 - val_loss: -1.6517
# Epoch 933/1000
# 28/28 [==============================] - 0s 11ms/step - loss: -1.0099 - val_loss: -1.6518
# Epoch 934/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -1.0344 - val_loss: -1.6519
# Epoch 935/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0179 - val_loss: -1.6520
# Epoch 936/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -1.0228 - val_loss: -1.6521
# Epoch 937/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0266 - val_loss: -1.6522
# Epoch 938/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0334 - val_loss: -1.6524
# Epoch 939/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0238 - val_loss: -1.6525
# Epoch 940/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0458 - val_loss: -1.6526
# Epoch 941/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0506 - val_loss: -1.6527
# Epoch 942/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0349 - val_loss: -1.6528
# Epoch 943/1000
# 28/28 [==============================] - 0s 7ms/step - loss: -1.0281 - val_loss: -1.6529
# Epoch 944/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0344 - val_loss: -1.6531
# Epoch 945/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0421 - val_loss: -1.6532
# Epoch 946/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0497 - val_loss: -1.6533
# Epoch 947/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0455 - val_loss: -1.6534
# Epoch 948/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0504 - val_loss: -1.6536
# Epoch 949/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0441 - val_loss: -1.6537
# Epoch 950/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0449 - val_loss: -1.6538
# Epoch 951/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0676 - val_loss: -1.6539
# Epoch 952/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0575 - val_loss: -1.6540
# Epoch 953/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0480 - val_loss: -1.6542
# Epoch 954/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0393 - val_loss: -1.6543
# Epoch 955/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0471 - val_loss: -1.6544
# Epoch 956/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0417 - val_loss: -1.6545
# Epoch 957/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0233 - val_loss: -1.6547
# Epoch 958/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0234 - val_loss: -1.6548
# Epoch 959/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0481 - val_loss: -1.6549
# Epoch 960/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0397 - val_loss: -1.6550
# Epoch 961/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0742 - val_loss: -1.6552
# Epoch 962/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0458 - val_loss: -1.6553
# Epoch 963/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0556 - val_loss: -1.6554
# Epoch 964/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0399 - val_loss: -1.6556
# Epoch 965/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0486 - val_loss: -1.6557
# Epoch 966/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0635 - val_loss: -1.6559
# Epoch 967/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0446 - val_loss: -1.6560
# Epoch 968/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0590 - val_loss: -1.6561
# Epoch 969/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0633 - val_loss: -1.6563
# Epoch 970/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0536 - val_loss: -1.6564
# Epoch 971/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0563 - val_loss: -1.6566
# Epoch 972/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0694 - val_loss: -1.6567
# Epoch 973/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0552 - val_loss: -1.6568
# Epoch 974/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0553 - val_loss: -1.6570
# Epoch 975/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0930 - val_loss: -1.6571
# Epoch 976/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0539 - val_loss: -1.6572
# Epoch 977/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0855 - val_loss: -1.6574
# Epoch 978/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0589 - val_loss: -1.6576
# Epoch 979/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0650 - val_loss: -1.6577
# Epoch 980/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0563 - val_loss: -1.6579
# Epoch 981/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0608 - val_loss: -1.6580
# Epoch 982/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0663 - val_loss: -1.6581
# Epoch 983/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0719 - val_loss: -1.6583
# Epoch 984/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0757 - val_loss: -1.6584
# Epoch 985/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0472 - val_loss: -1.6586
# Epoch 986/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0806 - val_loss: -1.6587
# Epoch 987/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0666 - val_loss: -1.6589
# Epoch 988/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0696 - val_loss: -1.6590
# Epoch 989/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0590 - val_loss: -1.6592
# Epoch 990/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.1093 - val_loss: -1.6594
# Epoch 991/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0931 - val_loss: -1.6595
# Epoch 992/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0787 - val_loss: -1.6597
# Epoch 993/1000
# 28/28 [==============================] - 0s 10ms/step - loss: -1.0926 - val_loss: -1.6599
# Epoch 994/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0804 - val_loss: -1.6600
# Epoch 995/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0848 - val_loss: -1.6601
# Epoch 996/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0825 - val_loss: -1.6603
# Epoch 997/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0830 - val_loss: -1.6605
# Epoch 998/1000
# 28/28 [==============================] - 0s 9ms/step - loss: -1.0891 - val_loss: -1.6607
# Epoch 999/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.0805 - val_loss: -1.6608
# Epoch 1000/1000
# 28/28 [==============================] - 0s 8ms/step - loss: -1.1094 - val_loss: -1.6610
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # 백테스팅

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Markowitz's Portfolio Network (MPN)을 이용해서 최적 포트폴리오를 구축한다.
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model


N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 모델을 가져온다.
lstm_model = model

# MPN을 이용해서 백 테스트를 수행한다.
# --------------------------------
lstm_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_hist_lstm = []
for i in range(0, xc_test.shape[0], N_FUTURE):
    # LSTM으로 W를 추정한다.
    x = xc_test[i][np.newaxis,:, :]
    w_lstm = lstm_model.predict(x)[0]
    w_hist_lstm.append(w_lstm)
    
    # 다음 기의 누적 수익률
    m_rtn = np.sum(xf_test[i]/100, axis = 0)
    
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    lstm_value.append(lstm_value[-1] * np.exp(np.dot(w_lstm, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))

print('\nBack test를 완료했습니다.')
# Out:
# Back test를 완료했습니다.

# %% [markdown]
# # 포트폴리오 성과 평가

# %%
# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, len(test_date), N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 
                        'lstm_markowitz':lstm_value
                        }, 
                       index=test_date[idx])

# S&P500 index와 포트폴리오 성과를 비교해 본다.
sp500 = pd.DataFrame(df3['코스피'])

# 수익률을 계산해서 perf_df와 시작 위치를 맞춘다 (초기 value를 맞춘다).
sp500 = sp500[test_date[0]:]
sp_trans = lstm_value[0] / sp500['코스피'][0]
perf_df['kospi'] = sp500['코스피'] * sp_trans

# S&P500 index (시장), CRP, 그리고 MPN의 성과를 비교한다.
p = perf_df.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.show()

# weights history를 확인한다.
w_hist_lstm = np.array(w_hist_lstm)

# 종목 이름을 읽어온다.
symbol = rtn_df.columns

n = 7
plt.figure(figsize=(12, 4))
for i in range(n):
    plt.plot(w_hist_lstm[:, i], label=symbol[i])
plt.legend(loc='upper left')
plt.title('W history by LSTM')
plt.xticks(np.arange(0, 31), list(perf_df.index[1:]), rotation='vertical')
plt.show()

# 포트폴리오 수익률, 위험, SR을 측정한다.
rp_df = perf_df.copy()
rp_df['crp_rtn'] = np.log(rp_df['crp']) - np.log(rp_df['crp'].shift(1))
rp_df['lstm_rtn'] = np.log(rp_df['lstm_markowitz']) - np.log(rp_df['lstm_markowitz'].shift(1))
rp_df['sp500_rtn'] = np.log(rp_df['kospi']) - np.log(rp_df['kospi'].shift(1))
rp_df = rp_df.dropna()

# 포트폴리오 수익률 (연간)
rp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].mean()
# 20일 = 약 1개월, 1년 = 12개월
rp*=12
print('\n포트폴리오 수익률 (연간):')
print(rp)

# 포트폴리오 위험 (연간 표준편차)
sp = rp_df[['crp_rtn', 'lstm_rtn', 'sp500_rtn']].std()
print('\n포트폴리오 위험 (연간):')
print(sp)

# Sharp ratio
print('\nSharp Ratio :')
print(rp / sp)

# 최적 포트폴리오 결과 확인용 코드 (참고용)
def check_w(n = 0):
    plt.figure(figsize=(14,5))
    x = xc_test[n][np.newaxis,:,:] * 20.0
    w_lstm = lstm_model.predict(x)[0]
    plt.bar(np.arange(N_STOCKS), w_lstm, alpha = 0.7)
    plt.xticks(np.arange(7), list(symbol), rotation='vertical')
    plt.title('W by LSTM')
    plt.show()
    
check_w(0)
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52292 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 포트폴리오 수익률 (연간):
# crp_rtn      0.063114
# lstm_rtn     0.063704
# sp500_rtn    0.029957
# dtype: float64
#
# 포트폴리오 위험 (연간):
# crp_rtn      0.017785
# lstm_rtn     0.016667
# sp500_rtn    0.074454
# dtype: float64
#
# Sharp Ratio :
# crp_rtn      3.548628
# lstm_rtn     3.822174
# sp500_rtn    0.402351
# dtype: float64

# %%
perf_df
# Out:
#                      crp  lstm_markowitz         kospi
# Date
# 2017-07-31  10000.000000    10000.000000  10000.000000
# 2017-08-28  10018.583971    10062.158108   9865.111010
# 2017-09-25  10116.171578    10128.917631   9907.146268
# 2017-10-23  10106.608929    10060.336257  10363.506579
# 2017-11-20  10288.884137    10215.864403  10520.079256
# 2017-12-18  10227.794625    10127.348551  10329.502616
# 2018-01-17  10405.028340    10408.409188  10469.136819
# 2018-02-14  10151.721297    10217.960148  10079.577300
# 2018-03-14  10387.396500    10387.290951  10346.983692
# 2018-04-11  10456.744078    10467.247978  10172.763298
# 2018-05-09  10560.590009    10490.637861  10171.764467
# 2018-06-06  10676.688010    10552.302784  10212.468628
# 2018-07-04  10482.701336    10344.869083   9428.770005
# 2018-08-01  10494.116855    10305.813496   9601.949906
# 2018-08-29  10580.806108    10349.750084   9610.107199
# 2018-09-26  10487.189236    10238.871555   9735.548443
# 2018-10-24  10179.903095     9998.567228   8730.059442
# 2018-11-21  10154.768287    10030.809913   8642.533150
# 2018-12-19  10030.310023     9991.181041   8652.064218
# 2019-01-18  10188.209795    10155.247021   8841.183763
# 2019-02-15  10499.514243    10400.207044   9140.054870
# 2019-03-15  10444.437243    10319.859242   9056.898847
# 2019-04-12  10618.171110    10434.037477   9295.545395
# 2019-05-10  10514.111423    10386.723890   8773.593456
# 2019-06-07  10627.698274    10603.789199   8624.969771
# 2019-07-05  10937.325343    10980.228034   8784.206676
# 2019-08-02  10782.959915    10951.606639   8316.151501
# 2019-08-30  10894.835913    11193.080679   8189.877559
# 2019-09-27  11071.352512    11242.957531   8531.741096
# 2019-10-25  11115.831780    11262.790772   8689.729208
# 2019-11-22  11099.505690    11181.975230   8748.288371
# 2020-04-21  11646.955092    11782.600261   7821.917899
# 2020-05-19  11834.857010    11986.630386   8243.233755
# 2020-06-16  12248.495519    12302.572661   8898.494132
# 2021-09-14  12309.356961    12373.720902  13105.327440
# 2021-10-12  12281.038409    12292.869778  12137.877356
# 2021-11-09  12591.951033    12608.561733  12329.661129
# 2021-12-07  12312.747596    12356.123194  12451.440329
# 2022-01-04  12575.197186    12574.818677  12441.118732
# 2022-02-01  12137.596630    12255.423744  11084.734034
# 2022-03-01  12234.220175    12381.703314  11233.898288
# 2022-03-29  12555.050257    12605.093613  11408.243662
# 2022-04-26  12471.961637    12497.751469  11105.418889

# %% [markdown]
# # 타 펀드 비교 <KB>

# %%
kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
kb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-6c6889fe9983> in <module>()
# ----> 1 kb=pd.read_excel("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx")
#       2 kb
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/kb아무것도못하쥬.xlsx'

# %%
kb.일자=pd.to_datetime(kb.일자)
kb=kb.set_index('일자')
kb
# Out:
#             수익률(%)
# 일자
# 2017-05-13   -0.25
# 2017-05-14    0.00
# 2017-05-15    0.00
# 2017-05-16    0.08
# 2017-05-17   -0.13
# ...            ...
# 2022-05-09    0.01
# 2022-05-10   -0.48
# 2022-05-11   -0.10
# 2022-05-12    0.12
# 2022-05-13   -0.32
#
# [1827 rows x 1 columns]

# %%
#일자설정
kb=kb.loc[perf_df.index[0]:perf_df.index[-1]]

# %%
kb['금액']=10000
kb['수익률(%)']=kb['수익률(%)']*0.01
kb.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             수익률(%)     금액
# 일자
# 2017-07-31  0.0000  10000
# 2017-08-01 -0.0014  10000
# 2017-08-02  0.0024  10000
# 2017-08-03 -0.0008  10000
# 2017-08-04 -0.0053  10000

# %%
perf_df
# Out:
#                      crp  lstm_markowitz         kospi
# Date
# 2017-07-31  10000.000000    10000.000000  10000.000000
# 2017-08-28  10018.583971    10049.041510   9865.111010
# 2017-09-25  10116.171578    10127.766473   9907.146268
# 2017-10-23  10106.608929    10023.366162  10363.506579
# 2017-11-20  10288.884137    10249.648641  10520.079256
# ...                  ...             ...           ...
# 2021-12-23  14507.437680    15376.021960  12478.284814
# 2022-01-20  14242.702880    15202.650081  11914.379922
# 2022-02-17  14126.719593    14892.890446  11420.812884
# 2022-03-17  14280.582738    14943.366016  11214.462226
# 2022-04-14  14812.223678    15353.571585  11306.857694
#
# [62 rows x 3 columns]

# %%
for i in range(1,kb.shape[0]):
    kb.iloc[i,1]=kb.iloc[i,0]*kb.iloc[i-1,1]+kb.iloc[i-1,1]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
p_df=perf_df.copy()

# %%
p_df=p_df.reset_index()
kb=kb.reset_index()
grp=pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')

# %%
pd.merge(p_df,kb,left_on='Date',right_on='일자',how='outer')
# Out:
#            Date           crp  lstm_markowitz         kospi         일자  \
# 0    2017-07-31  10000.000000    10000.000000  10000.000000 2017-07-31
# 1    2017-08-28  10018.583971    10049.041510   9865.111010 2017-08-28
# 2    2017-09-25  10116.171578    10127.766473   9907.146268 2017-09-25
# 3    2017-10-23  10106.608929    10023.366162  10363.506579 2017-10-23
# 4    2017-11-20  10288.884137    10249.648641  10520.079256 2017-11-20
# ...         ...           ...             ...           ...        ...
# 1714        NaT           NaN             NaN           NaN 2022-04-09
# 1715        NaT           NaN             NaN           NaN 2022-04-10
# 1716        NaT           NaN             NaN           NaN 2022-04-11
# 1717        NaT           NaN             NaN           NaN 2022-04-12
# 1718        NaT           NaN             NaN           NaN 2022-04-13
#
#       수익률(%)            금액
# 0     0.0000  10000.000000
# 1     0.0000   9901.169700
# 2     0.0000   9811.207082
# 3     0.0000   9885.809888
# 4     0.0000  10040.044475
# ...      ...           ...
# 1714 -0.0010  13749.991787
# 1715  0.0000  13749.991787
# 1716  0.0000  13749.991787
# 1717 -0.0013  13732.116798
# 1718 -0.0033  13686.800813
#
# [1719 rows x 7 columns]

# %%
grp=grp.set_index('Date')

# %%
grp=grp[['crp', 'lstm_markowitz', 'kospi', '금액']]
grp.columns=['crp', 'lstm_markowitz', 'kospi', 'KB펀드']
grp=grp.dropna()

# %%
p = grp.plot(figsize=(12, 7), style = '-o', fontsize=12)
p.legend(fontsize=12)
plt.show()

# %% [markdown]
# # 타 펀드 비교 <미래에셋>

# %%
fa=pd.read_csv("/content/gdrive/My Drive/FINAL TEAM/파이널프로젝트/비주식팀/Data/미래에셋.csv")
fa=fa.T

# %%
fa=fa.iloc[1:]
fa.columns=['투자수익률','비교지수']
fa[['미래에셋','비교지수']]=fa[['투자수익률','비교지수']]
fa
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#             투자수익률   비교지수   미래에셋
# 2017-01-23      0      0      0
# 2017-01-24   -0.1  -0.01   -0.1
# 2017-01-25    0.1   0.05    0.1
# 2017-01-26    0.7   0.85    0.7
# 2017-01-27    0.7   0.85    0.7
# ...           ...    ...    ...
# 2022-05-08  26.12   28.0  26.12
# 2022-05-09  24.52  26.37  24.52
# 2022-05-10  23.67  25.68  23.67
# 2022-05-11  23.31  25.47  23.31
# 2022-05-12  21.38  23.43  21.38
#
# [1908 rows x 3 columns]

# %%
fa=fa.reset_index()
fa['index']
grp=pd.merge(p_df,fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-ff4485e64e43> in <module>()
#       1 fa=fa.reset_index()
# ----> 2 grp=pd.merge(p_df,fa[['index','미래에셋']],left_on='Date',right_on='index',how='outer')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     701         # validate the merge keys dtypes. We may need to coerce
#     702         # to avoid incompatible dtypes
# --> 703         self._maybe_coerce_merge_keys()
#     704
#     705         # If argument passed to validate,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1258             # datetimelikes must match exactly
#    1259             elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
# -> 1260                 raise ValueError(msg)
#    1261             elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
#    1262                 raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns] and object columns. If you wish to proceed you should use pd.concat

# %%
grp['미래에셋']=grp['미래에셋']*0.01*10000+10000
