# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set()

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %%
코스피재무제표 = pd.read_csv('/content/drive/MyDrive/컨트롤엔터산악회/코스피전체재무제표.csv')

# %%
코스피재무제표[코스피재무제표['name_ko'] =='현금']
# Out:
#                date      symbol entity_name type_id report_id  account_id  \
# 1        2018-12-31  KRX:000020        동화약품       K        11        1110
# 126      2018-12-31  KRX:000020        동화약품       K        11        9120
# 389      2019-12-31  KRX:000020        동화약품       K        11        1110
# 519      2019-12-31  KRX:000020        동화약품       K        11        9120
# 803      2020-12-31  KRX:000020        동화약품       K        11        1110
# ...             ...         ...         ...     ...       ...         ...
# 5690817  2019-12-31  KRX:267270      현대건설기계       K        11        9120
# 5691196  2020-12-31  KRX:267270      현대건설기계       K        11        1110
# 5691394  2020-12-31  KRX:267270      현대건설기계       K        11        9120
# 5691778  2021-12-31  KRX:267270      현대건설기계       K        11        1110
# 5691992  2021-12-31  KRX:267270      현대건설기계       K        11        9120
#
#         name_ko        value
# 1            현금   50144000.0
# ...

# %%
신세계 = 코스피재무제표[코스피재무제표['entity_name']== '신세계']

# %%
재무제표항목 = 신세계[신세계['date']=='2021-12-31']

# %%
재무제표항목
# Out:
#                date      symbol entity_name type_id report_id  account_id  \
# 3266430  2021-12-31  KRX:004170         신세계       K        11        1100
# 3266431  2021-12-31  KRX:004170         신세계       K        11        1110
# 3266432  2021-12-31  KRX:004170         신세계       K        11        1130
# 3266433  2021-12-31  KRX:004170         신세계       K        11        1134
# 3266434  2021-12-31  KRX:004170         신세계       K        11        1147
# ...             ...         ...         ...     ...       ...         ...
# 3266959  2021-12-31  KRX:004170         신세계       K        19        4110
# 3266960  2021-12-31  KRX:004170         신세계       K        19        4120
# 3266961  2021-12-31  KRX:004170         신세계       K        19        4130
# 3266962  2021-12-31  KRX:004170         신세계       K        19        4140
# 3266963  2021-12-31  KRX:004170         신세계       K        19        4150
#
#           name_ko         value
# 3266430  현금및현금등가물  5.777879e+11
# ...

# %%
df  = 재무제표항목[재무제표항목['name_ko']== '유동자산(계)']
# Out:
#                date      symbol entity_name type_id report_id  account_id  \
# 3266475  2021-12-31  KRX:004170         신세계       K        11        2000
#
#          name_ko         value
# 3266475  유동자산(계)  1.910371e+12

# %%
def 신세계재무요소검색(키워드):

    이름 = 재무제표항목['name_ko'][재무제표항목['name_ko']== 키워드]
    return 이름

# %%
신세계재무요소검색('당기순이익')
# Out:
# Series([], Name: name_ko, dtype: object)

# %%
재무제표항목['name_ko'].unique().tolist()
# Out:
# ['현금및현금등가물',
#  '현금',
#  '예금',
#  '기타예금',
#  '원화매출채권',
#  '[기타단기투자증권]',
#  '매출채권',
#  '(매출채권대손충당금)',
#  '단기대여금',
#  '기타단기대여금',
#  '미수금',
#  '기타미수금',
#  '(미수금대손충당금)',
#  '미수수익',
#  '원화미수수익',
#  '기타당좌자산',
#  '단기금융상품',
#  '[사용제한단기금융상품]',
#  '기타단기금융상품',
#  '당좌자산(계)',
#  '(당좌자산대손충당금(계))',
#  '상품',
#  '기타상품',
#  '제품',
#  '기타제품',
#  '재공품',
#  '기타재공품',
#  '원재료',
#  '기타원재료',
#  '저장품',
#  '미착품',
#  '기타미착품',
#  '(재고자산평가손실충당금)',
#  '재고자산(계)',
#  '선급금',
#  '기타선급금',
#  '선급비용',
#  '선급법인세',
#  '보증금',
#  '파생상품',
#  '기타파생상품',
#  '리스채권',
#  '(리스채권현재가치할인차금)',
#  '금융리스채권',
#  '(금융리스채권현재가치할인차금)',
#  '유동자산(계)',
#  '별단예금',
#  '기타장기금융상품',
#  '장기금융상품',
#  '[사용제한장기금융상품]',
#  '장기투자증권',
#  '매도가능증권',
#  '토지',
#  '건물',
#  '지분법적용주식',
#  '투자부동산',
#  '장기대여금',
#  '기타장기대여금',
#  '장기미수금',
#  '장기선급금',
#  '장기선급비용',
#  '이연법인세자산',
#  '기타리스자산',
#  '투자자산(계)',
#  '(건물감가상각누계액)',
#  '(건물국고보조금)',
#  '(기타유형자산감액손실누계액)',
#  '기타유형자산',
#  '(기타유형자산감가상각누계액)',
#  '(기타유형자산국고보조금)',
#  '건설중인자산',
#  '유형자산(계)',
#  '(유형자산감가상각누계액계)',
# ...
