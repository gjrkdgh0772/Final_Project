# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set()

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %%
# A_list =['A000020.xlsx','A000040.xlsx','A000050.xlsx','A000060.xlsx']

# %%
import os
os.listdir('/content/drive/MyDrive/컨트롤엔터산악회/코스피A재무제표800개')
# Out:
# ['A001880.xlsx',
#  'A058860.xlsx',
#  'A178920.xlsx',
#  'A001770.xlsx',
#  'A214390.xlsx',
#  'A037710.xlsx',
#  'A083420.xlsx',
#  'A000660.xlsx',
#  'A000500.xlsx',
#  'A000590.xlsx',
#  'A000050.xlsx',
#  'A000120.xlsx',
#  'A000320.xlsx',
#  'A000270.xlsx',
#  'A000040.xlsx',
#  'A000210.xlsx',
#  'A001390.xlsx',
#  'A001530.xlsx',
#  'A000860.xlsx',
#  'A001510.xlsx',
#  'A001120.xlsx',
#  'A002100.xlsx',
#  'A002350.xlsx',
#  'A002140.xlsx',
#  'A000680.xlsx',
#  'A001250.xlsx',
#  'A001380.xlsx',
#  'A001140.xlsx',
#  'A000990.xlsx',
#  'A001060.xlsx',
#  'A001740.xlsx',
#  'A001940.xlsx',
#  'A001040.xlsx',
#  'A002240.xlsx',
#  'A001260.xlsx',
#  'A001570.xlsx',
#  'A001210.xlsx',
#  'A001460.xlsx',
#  'A002710.xlsx',
#  'A005610.xlsx',
#  'A004270.xlsx',
#  'A005720.xlsx',
#  'A002820.xlsx',
#  'A003580.xlsx',
#  'A005250.xlsx',
#  'A004540.xlsx',
#  'A004370.xlsx',
#  'A002720.xlsx',
#  'A002380.xlsx',
#  'A003550.xlsx',
#  'A003570.xlsx',
#  'A005490.xlsx',
# ...

# %%
forders= os.listdir('/content/drive/MyDrive/컨트롤엔터산악회/코스피A재무제표800개')

# %%
forders[:10]
# Out:
# ['A001880.xlsx',
#  'A058860.xlsx',
#  'A178920.xlsx',
#  'A001770.xlsx',
#  'A214390.xlsx',
#  'A037710.xlsx',
#  'A083420.xlsx',
#  'A000660.xlsx',
#  'A000500.xlsx',
#  'A000590.xlsx']

# %%
cd /content/drive/MyDrive/컨트롤엔터산악회
# Out:
# /content/drive/MyDrive/컨트롤엔터산악회

# %%
코스피재무제표 = pd.DataFrame()

# %%
for i,files in enumerate(forders):
    df = pd.read_excel('/content/drive/MyDrive/컨트롤엔터산악회/코스피A재무제표800개/'+files+'',sheet_name='#03 Computed Result')
    코스피재무제표 = pd.concat([코스피재무제표, df])

# %%
코스피재무제표.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5664794 entries, 0 to 2734
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   date         object
#  1   symbol       object
#  2   entity_name  object
#  3   type_id      object
#  4   report_id    object
#  5   account_id   int64
#  6   name_ko      object
#  7   value        float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 389.0+ MB

# %%
코스피재무제표
# Out:
#             date      symbol entity_name type_id report_id  account_id  \
# 0     1996-12-31  KRX:001880        DL건설       K        11        1100
# 1     1996-12-31  KRX:001880        DL건설       K        11        1130
# 2     1996-12-31  KRX:001880        DL건설       K        11        1131
# 3     1996-12-31  KRX:001880        DL건설       K        11        1134
# 4     1996-12-31  KRX:001880        DL건설       K        11        1140
# ...          ...         ...         ...     ...       ...         ...
# 2730  2021-12-31  KRX:267270      현대건설기계       K        17        1800
# 2731  2021-12-31  KRX:267270      현대건설기계       K        17        1810
# 2732  2021-12-31  KRX:267270      현대건설기계       K        17        1820
# 2733  2021-12-31  KRX:267270      현대건설기계       K        17        1920
# 2734  2021-12-31  KRX:267270      현대건설기계       K        17        1960
#
#             name_ko         value
# 0          현금및현금등가물  2.002153e+09
# 1                예금  2.002153e+09
# ...

# %%
코스피재무제표.to_csv('코스피전체재무제표최종.csv',index=False)

# %%
# 코스피재무제표.isna().sum()

# %%
# A000020 = pd.read_excel('/content/drive/MyDrive/컨트롤엔터산악회/코스피A재무제표/A000020.xlsx',sheet_name='#03 Computed Result')
