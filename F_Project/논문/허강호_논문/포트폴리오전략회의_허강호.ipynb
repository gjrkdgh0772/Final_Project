# %% [markdown]
# # 포트폴리오 전략정리 - 허강호

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
#plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
sns.set()

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# ## 재무비율을 활용한 (주식)포트폴리오 최적화
#
# * BM/PSR/POR/PER 로 구성되는 단일 재무비율과 단일재무비율의 조합인 결합재무비율을 활용해 랭킹을 통하여 십분위 포트폴리오를 구성
#
# * ex) KOSPI 상장기업이 700개->각재무비율이 우수한순으로 70개씩 분위생성
#
# * 유전자 알고리즘을 활용하여 결합재무비율을 가지고 다양한 가중방식으로 포트폴리오수익률
# 측정
#
# * 다수의 결합지표를 활용한 포트폴리오가 성과 대비 수익률 변
# 동성이 낮기 때문에 이것이 투자결정에 용이하다.
#
# * 유전자 알고라즘 최적화 또한 적극적으로 활용하여 고평가된
# 주식의 보유는 최소화 하고 저평가 되고 비교적 큰 규모의 기업에
# 자본을 보다 적극적으로 배분할 수 있게 되었다.

# %% [markdown]
# ## 투자심리 민감도가 주가수익률 변동성에 미치는 영향
#
# * 투자심리 민감도가 높은 기업일수록 기업 고유변동성의 크기가 커진다
# 이러한 관계는 개인투자자 거래비중이 큰 경우 강하게 나타난다.
#
# * 정보의 비대칭성이 심한경우에도 강한 효과가 나타났다.
#
# * 이러한 요인을 기업의 자산운용 리벨런싱에 이용할수 있다면?? 월단위로?

# %% [markdown]
# # 주식/채권/금/부동산
#
# * 주식 - 경기민감주/경기방어주/성장주/현금/테마별/업종별/
# * 재무비율기준/투자심리/수급/실적/거래량/등등 리벨런싱요소
# * 예측하기 어려운 세계적 불황 전쟁,코로나->오히려 적극적매수
# * 상대적으로 하락이 적은 종목을 손절 --> 클폭하락한 종목을 매도한돈으로 매수
# * 이런식으로 포트폴리오에 변화를 준다면?

# %% [markdown]
# # 채권투자전략
#
# * 채권투자 목표설정
# * 채권 포트폴리오의 유동성, 수익성, 리스크 허용도를 기준으로 삼는다.
# * 적극적(전술석)수익성/소극적(전략적)안정성,유동성 투자방번에 따라 종류가 다양하다.
# * 자세하게 구성하려면 나의머리로는 시간이 매우 많이 필요할듯....

# %% [markdown]
# # 거시경제 --> 산업분석 --> 종목분석 (우리는 이쪽으로)
# # 종목분석 --> 산업분석 --> 거시경제
#
# * 금리, 환율, GDP, 유가, 인플레이션 (유기적 상호작용이 일어남)
# * 금리->주식->환율->금리->주식 연관성 에 따른 포트폴리오 종목별 비중 변화에만 큰틀로 고정 시켜놓기만 하면 어떨까? (정확한 상황과 예측은 자세하게 분석하기 힘들다)

# %% [markdown]
# # 예시
#
# * 금리가 높고 유동성회수율이 높은 시기 의 우리 팀 프로젝트에서의 포트폴리오 비중(주식 20% 채권 40% 금 10% 부동산 30%)
#
# * 금리가 낮고 유동성이 높은 시기 의 우리 팀 프로젝트에서의 포트폴리오 비중(주식 50% 채권 20% 금 15% 부동산 15%)
#
# * 이런식으로 큰틀의 비중만 정하고 각 포트폴리오 종목에서는 종목만의
# 세부적인 포트폴리오와 리벨런싱으로 들어가보자?!

# %% [markdown]
# <img src = "https://miro.medium.com/max/1200/1*k64qz82aKpZtexq5q-RyVg.png" height = 500 width = 700>

# %% [markdown]
# # 주식과 채권을 포트폴리오에 어떤 비중으로 담아야 할까?
# # 예측불가능한 시기를 모면하기위한 방법으로써? 참고해볼만한것 같다.
#
# ref: https://www.iruda.io/blog/1187
#
# # 글로벌 기관투자가 자산 보니…채권 줄이고 대체자산 담았다
# https://www.hankyung.com/finance/article/2021121479131
#
# # 자산배분 포트폴리오 만들기 기초
# http://www.dentalnews.or.kr/mobile/article.html?no=30533
